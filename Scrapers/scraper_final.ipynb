# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import warnings
import re
import csv
import os
from datetime import datetime
import glob
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
# !rm -rf data-raw

# %%
# Prep

### Clear data-raw directory
directory_path = './data-raw/'
for root, dirs, files in os.walk(directory_path, topdown=False):
    for file in files:
        file_path = os.path.join(root, file)
        os.remove(file_path)
    for dir in dirs:
        dir_path = os.path.join(root, dir)
        os.rmdir(dir_path)

### Create directories and csv files
directories = ['./data-raw/fighters/', './data-raw/git/']
for directory in directories:
    if not os.path.exists(directory):
        os.makedirs(directory)
csv_files = ['./data-raw/event_urls_sherdog.csv', './data-raw/event_data_sherdog.csv', './data-raw/fighter_id_sherdog.csv', './data-raw/fighter_info.csv']
for file_path in csv_files:
    if not os.path.exists(file_path):
        open(file_path, 'a').close()

### Download github data
files = ["ufc_event_details.csv", "ufc_fight_results.csv", "ufc_fight_stats.csv", "ufc_fighter_tott.csv"]
base_url = "https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/"
directory = "./data-raw/git/"
os.makedirs(directory, exist_ok=True)
for file in files:
    response = requests.get(base_url + file)
    if response.status_code == 200:
        with open(os.path.join(directory, file), 'wb') as f:
            f.write(response.content)
    else:
        print(f"Failed to download {file}")

### event_urls_sherdog.csv
columns = ['Event_URL']
file_path = './data-raw/event_urls_sherdog.csv'
if os.path.isfile(file_path):
    if os.path.getsize(file_path) == 0:
        df = pd.DataFrame(columns=columns)
        df.to_csv(file_path, index=False)
else:
    df = pd.DataFrame(columns=columns)
    df.to_csv(file_path, index=False)

### figher_id_sherdog.csv
columns = ['Fighter', 'Fighter_ID']
file_path = './data-raw/fighter_id_sherdog.csv'
if os.path.isfile(file_path):
    if os.path.getsize(file_path) == 0:
        df = pd.DataFrame(columns=columns)
        df.to_csv(file_path, index=False)
else:
    df = pd.DataFrame(columns=columns)
    df.to_csv(file_path, index=False)

### event_data_sherdog.csv
columns = ['Event Name', 'Event Location', 'Event Date', 'Fighter 1', 'Fighter 2', 'Weight Class', 'Winning Fighter', 'Winning Method', 'Winning Round', 'Winning Time', 'Referee']
file_path = './data-raw/event_data_sherdog.csv'
if os.path.isfile(file_path):
    if os.path.getsize(file_path) == 0:
        df = pd.DataFrame(columns=columns)
        df.to_csv(file_path, index=False)
else:
    df = pd.DataFrame(columns=columns)
    df.to_csv(file_path, index=False)

### fighter_info.csv
columns = ['Fighter', 'Nickname', 'Birth Date', 'Nationality', 'Hometown', 'Association', 'Weight Class', 'Height', 'REACH', 'STANCE', 'Wins', 'Losses', 'Win_Decision', 'Win_KO', 'Win_Sub', 'Loss_Decision', 'Loss_KO', 'Loss_Sub', 'Sherdog URL', 'BFO URL']
file_path = './data-raw/fighter_info.csv'
if os.path.isfile(file_path):
    if os.path.getsize(file_path) == 0:
        df = pd.DataFrame(columns=columns)
        df.to_csv(file_path, index=False)
else:
    df = pd.DataFrame(columns=columns)
    df.to_csv(file_path, index=False)

# %%
# Get UFC event urls from sherdog

def scrape_event_urls_sherdog():
    file_path = './data-raw/event_urls_sherdog.csv'
    urls = [
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/1',
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/2',
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/3',
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/4',
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/5',
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/6',
        'https://www.sherdog.com/organizations/Ultimate-Fighting-Championship-UFC-2/recent-events/7'
    ]

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    if os.path.isfile(file_path):
        df = pd.read_csv(file_path)
    else:
        df = pd.DataFrame(columns=['Event_URL'])

    progress_bar = tqdm(urls, desc="Scraping URLs", unit="URL",
                        bar_format="{desc}: {percentage:3.0f}%|{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}, {postfix}]")

    for index, url in enumerate(progress_bar, start=1):
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')

        specific_div = soup.find('div', {'class': 'single_tab', 'id': 'recent_tab'})
        new_urls = []
        for a in specific_div.find_all('a', itemprop='url'):
            href = a.get('href')
            if href and href not in df['Event_URL'].values:
                new_urls.append(href)

        new_urls_df = pd.DataFrame(new_urls, columns=['Event_URL'])
        df = pd.concat([df, new_urls_df], ignore_index=True)

        progress_bar.set_postfix({"Total URLs": len(df), "Current URL": url})

    df.to_csv(file_path, index=False)
    print(df)
    
## Call the function
scrape_event_urls_sherdog()
# Out:
# Scraping URLs:   0%|          | 0/7 [00:00<?, ]
#                                              Event_URL
# 0    /events/UFC-on-ABC-6-Whittaker-vs-Aliskerov-10...
# 1         /events/UFC-on-ESPN-58-Perez-vs-Taira-102196
# 2    /events/UFC-on-ESPN-57-Cannonier-vs-Imavov-102220
# 3          /events/UFC-302-Makhachev-vs-Poirier-101617
# 4    /events/UFC-Road-to-UFC-Season-3-Shanghai-Quar...
# ..                                                 ...
# 695                 /events/UFC-175-Ultimate-Brazil-27
# 696                       /events/UFC-17-Redemption-26
# 697              /events/UFC-16-Battle-in-the-Bayou-25
# 698                /events/UFC-155-Ultimate-Japan-1-24
# 699                 /events/UFC-15-Collision-Course-23
#
# [700 rows x 1 columns]

# %%
# Broken URL's 
#/events/UFC-233-Ultimate-Fighting-Championship-233-72021
#/events/UFC-Fight-Night-97-Lamas-vs-Penn-90890
#/events/UFC-176-Aldo-vs-Mendes-2-37609
#/events/UFC-151-Jones-vs-Henderson-25809

urls_to_delete = [
    "/events/UFC-233-Ultimate-Fighting-Championship-233-72021",
    "/events/UFC-Fight-Night-97-Lamas-vs-Penn-90890",
    "/events/UFC-176-Aldo-vs-Mendes-2-37609",
    "/events/UFC-151-Jones-vs-Henderson-25809"
]

input_file = "./data-raw/event_urls_sherdog.csv"
output_file = "./data-raw/event_urls_sherdog.csv"

with open(input_file, "r") as csvfile:
    reader = csv.DictReader(csvfile)
    rows = [row for row in reader if row["Event_URL"] not in urls_to_delete]

fieldnames = ["Event_URL", "Event Date"]

with open(output_file, "w", newline="") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows)

print("URLs deleted successfully.")
# Out:
# URLs deleted successfully.

# %%
# ###



# USE NEW SITEMAP.XML TO GET THEM 



# ###

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

def fetch_event_date(session, url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    try:
        response = session.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')

        event_date_meta = soup.find('meta', itemprop='startDate')
        if event_date_meta and 'content' in event_date_meta.attrs:
            return event_date_meta['content'].strip()
        else:
            return 'Not Found'
    except Exception as e:
        print(f"An error occurred while processing URL {url}: {e}")
        return "Error"

def scrape_event_date():
    df = pd.read_csv('./data-raw/event_urls_sherdog.csv')
    df['Event_URL'] = 'https://sherdog.com' + df['Event_URL']

    event_dates = []

    with requests.Session() as session:
        with concurrent.futures.ThreadPoolExecutor(max_workers=40) as executor:
            # Map fetch_event_date function to URLs
            future_to_url = {executor.submit(fetch_event_date, session, url): url for url in df['Event_URL']}
            for future in tqdm(concurrent.futures.as_completed(future_to_url), total=len(df['Event_URL']), desc="Scraping Events", unit="Event"):
                url = future_to_url[future]
                try:
                    event_date = future.result()
                    event_dates.append(event_date)
                except Exception as e:
                    print(f"An error occurred while processing URL {url}: {e}")
                    event_dates.append("Error")

    # Add the 'Event Date' column and assign the event_dates list to it
    df['Event Date'] = event_dates

    # Save the modified DataFrame back to the CSV file
    df.to_csv('./data-raw/event_urls_sherdog.csv', index=False)

    print("Event dates appended successfully.")

# Call the function
scrape_event_date()
# Out:
# Scraping Events:   0%|          | 0/696 [00:00<?, ?Event/s]
# Event dates appended successfully.

# %%
df = pd.read_csv('./data-raw/event_urls_sherdog.csv')
print(f"Total number of rows including the header in event_urls_sherdog.csv: {len(df)}")
print(f"Column names: {list(df.columns)}")
# Out:
# Total number of rows including the header in event_urls_sherdog.csv: 696
# Column names: ['Event_URL', 'Event Date']

# %%
file_path = './data-raw/event_urls_sherdog.csv' # Replace your_file_name.csv with your actual file name
specified_line_to_remove = "/events/UFC-302-June-29-101243"

# Read the original file and exclude the line containing the specified text
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# Filter out the specified line
filtered_lines = [line for line in lines if specified_line_to_remove not in line]

# Write the filtered lines back to the same file or a new file as needed
with open(file_path, 'w', encoding='utf-8') as file:  # Replace file_path if you want to write to a new file
    for line in filtered_lines:
        file.write(line)

print("Specified line has been removed.")
# Out:
# Specified line has been removed.

# %% [markdown]
# ---
#
# # Event Data

# %%
# !rm ./data-raw/event_data_sherdog.csv

# %%
# Final Loop 

warnings.filterwarnings("ignore", category=FutureWarning)

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

urls_df = pd.read_csv('data-raw/event_urls_sherdog.csv')
all_data = []

def fetch_event_data(url, session):
    full_url = f'https://sherdog.com{url}' if not url.startswith('http') else url
    event_data = []
    try:
        with session.get(full_url, headers=headers) as response:
            if response.status_code == 200:
                soup = BeautifulSoup(response.content, 'html.parser')
                event_name = soup.find('span', itemprop='name').text.strip()
                event_location = soup.find('span', itemprop='location').text.strip()
                event_date = soup.find('meta', itemprop='startDate')['content'].strip()

                # Main Event
                main_event_fighters = soup.find_all('div', class_='fighter')
                if main_event_fighters:
                    fighter1 = main_event_fighters[0].find('span', itemprop='name').text.strip()
                    fighter2 = main_event_fighters[1].find('span', itemprop='name').text.strip()
                    fighter1_id = main_event_fighters[0].find('a', itemprop='url')['href'].split('-')[-1]
                    fighter2_id = main_event_fighters[1].find('a', itemprop='url')['href'].split('-')[-1]
                    weight_class = soup.find('span', class_='weight_class').text.strip()
                    winning_fighter = fighter1  # Assuming fighter1 as the winner, adjust as necessary
                    winning_method_em = soup.find('em', string='Method').parent
                    winning_method = winning_method_em.contents[2].strip()
                    winning_round_em = soup.find('em', string='Round').parent
                    winning_round = winning_round_em.contents[2].strip()
                    winning_time_em = soup.find('em', string='Time').parent
                    winning_time = winning_time_em.contents[2].strip()
                    referee_em = soup.find('em', string='Referee').parent
                    referee = referee_em.find('a').text.strip()
                    event_data.append({
                        'Event Name': event_name,
                        'Event Location': event_location,
                        'Event Date': event_date,
                        'Fighter 1': fighter1,
                        'Fighter 2': fighter2,
                        'Fighter 1 ID': fighter1_id,
                        'Fighter 2 ID': fighter2_id,
                        'Weight Class': weight_class,
                        'Winning Fighter': winning_fighter,
                        'Winning Method': winning_method,
                        'Winning Round': winning_round,
                        'Winning Time': winning_time,
                        'Referee': referee,
                        'Fight Type': 'Main Event'
                    })
                    
                # Other Bouts
                other_bouts = soup.find_all('tr', itemprop='subEvent')
                for bout in other_bouts:
                    fighters = bout.find_all('div', class_='fighter_list')
                    if len(fighters) >= 2:
                        fighter1 = fighters[0].find('img')['title']
                        fighter2 = fighters[1].find('img')['title']
                        fighter1_url = fighters[0].find('a', itemprop='url')['href']
                        fighter2_url = fighters[1].find('a', itemprop='url')['href']
                        fighter1_id = fighter1_url.split('-')[-1]
                        fighter2_id = fighter2_url.split('-')[-1]
                        weight_class = bout.find('span', class_='weight_class')
                        weight_class = weight_class.text.strip() if weight_class else "Unknown"
                        winning_method = bout.find('td', class_='winby').find('b').get_text(strip=True)
                        winning_round = bout.find_all('td')[-2].get_text(strip=True)
                        winning_time = bout.find_all('td')[-1].get_text(strip=True)
                        referee = bout.find('td', class_='winby').find('a').get_text(strip=True)
                        event_data.append({
                            'Event Name': event_name,
                            'Event Location': event_location,
                            'Event Date': event_date,
                            'Fighter 1': fighter1,
                            'Fighter 2': fighter2,
                            'Fighter 1 ID': fighter1_id,
                            'Fighter 2 ID': fighter2_id,
                            'Weight Class': weight_class,
                            'Winning Fighter': fighter1,  # Adjust as necessary
                            'Winning Method': winning_method,
                            'Winning Round': winning_round,
                            'Winning Time': winning_time,
                            'Referee': referee,
                            'Fight Type': 'Undercard'
                        })
                        
        return event_data
    except Exception as e:
        print(f"Request failed for {full_url}: {e}")
        return None

session = requests.Session()
total_urls = len(urls_df['Event_URL'])
completed_requests = 0

with concurrent.futures.ThreadPoolExecutor(max_workers=30) as executor:
    futures = [executor.submit(fetch_event_data, url, session) for url in urls_df['Event_URL']]
    for future in concurrent.futures.as_completed(futures):
        data = future.result()
        completed_requests += 1
        progress_percentage = (completed_requests / total_urls) * 100
        print(f"Completed {completed_requests}/{total_urls} requests ({progress_percentage:.2f}%)")
        if data:
            all_data.extend(data)

df = pd.DataFrame(all_data)

file_path = './data-raw/event_data_sherdog.csv'
write_mode = 'a' if os.path.isfile(file_path) else 'w'

df.to_csv(file_path, mode=write_mode, header=not os.path.isfile(file_path), index=False)
# Out:
# Completed 1/696 requests (0.14%)
# Completed 2/696 requests (0.29%)
# Completed 3/696 requests (0.43%)
# Completed 4/696 requests (0.57%)
# Completed 5/696 requests (0.72%)
# Completed 6/696 requests (0.86%)
# Completed 7/696 requests (1.01%)
# Completed 8/696 requests (1.15%)
# Completed 9/696 requests (1.29%)
# Completed 10/696 requests (1.44%)
# Completed 11/696 requests (1.58%)
# Completed 12/696 requests (1.72%)
# Completed 13/696 requests (1.87%)
# Completed 14/696 requests (2.01%)
# Completed 15/696 requests (2.16%)
# Completed 16/696 requests (2.30%)
# Completed 17/696 requests (2.44%)
# Completed 18/696 requests (2.59%)
# Completed 19/696 requests (2.73%)
# Completed 20/696 requests (2.87%)
# Completed 21/696 requests (3.02%)
# Completed 22/696 requests (3.16%)
# Completed 23/696 requests (3.30%)
# Completed 24/696 requests (3.45%)
# Completed 25/696 requests (3.59%)
# Completed 26/696 requests (3.74%)
# Completed 27/696 requests (3.88%)
# Completed 28/696 requests (4.02%)
# Completed 29/696 requests (4.17%)
# Completed 30/696 requests (4.31%)
# Completed 31/696 requests (4.45%)
# Completed 32/696 requests (4.60%)
# Completed 33/696 requests (4.74%)
# Completed 34/696 requests (4.89%)
# Completed 35/696 requests (5.03%)
# Completed 36/696 requests (5.17%)
# Completed 37/696 requests (5.32%)
# Completed 38/696 requests (5.46%)
# Completed 39/696 requests (5.60%)
# Completed 40/696 requests (5.75%)
# Completed 41/696 requests (5.89%)
# Completed 42/696 requests (6.03%)
# Completed 43/696 requests (6.18%)
# Completed 44/696 requests (6.32%)
# Completed 45/696 requests (6.47%)
# Completed 46/696 requests (6.61%)
# Completed 47/696 requests (6.75%)
# Completed 48/696 requests (6.90%)
# Completed 49/696 requests (7.04%)
# Completed 50/696 requests (7.18%)
# Completed 51/696 requests (7.33%)
# Completed 52/696 requests (7.47%)
# Completed 53/696 requests (7.61%)
# Completed 54/696 requests (7.76%)
# Completed 55/696 requests (7.90%)
# Completed 56/696 requests (8.05%)
# Completed 57/696 requests (8.19%)
# Completed 58/696 requests (8.33%)
# Completed 59/696 requests (8.48%)
# Completed 60/696 requests (8.62%)
# Completed 61/696 requests (8.76%)
# Completed 62/696 requests (8.91%)
# Completed 63/696 requests (9.05%)
# Completed 64/696 requests (9.20%)
# Completed 65/696 requests (9.34%)
# Completed 66/696 requests (9.48%)
# Completed 67/696 requests (9.63%)
# Completed 68/696 requests (9.77%)
# Completed 69/696 requests (9.91%)
# Completed 70/696 requests (10.06%)
# Completed 71/696 requests (10.20%)
# Completed 72/696 requests (10.34%)
# Completed 73/696 requests (10.49%)
# Completed 74/696 requests (10.63%)
# Completed 75/696 requests (10.78%)
# Completed 76/696 requests (10.92%)
# Completed 77/696 requests (11.06%)
# Completed 78/696 requests (11.21%)
# Completed 79/696 requests (11.35%)
# Completed 80/696 requests (11.49%)
# Completed 81/696 requests (11.64%)
# Completed 82/696 requests (11.78%)
# Completed 83/696 requests (11.93%)
# Completed 84/696 requests (12.07%)
# Completed 85/696 requests (12.21%)
# Completed 86/696 requests (12.36%)
# Completed 87/696 requests (12.50%)
# Completed 88/696 requests (12.64%)
# Completed 89/696 requests (12.79%)
# Completed 90/696 requests (12.93%)
# Completed 91/696 requests (13.07%)
# Completed 92/696 requests (13.22%)
# Completed 93/696 requests (13.36%)
# Completed 94/696 requests (13.51%)
# Completed 95/696 requests (13.65%)
# Completed 96/696 requests (13.79%)
# Completed 97/696 requests (13.94%)
# Completed 98/696 requests (14.08%)
# Completed 99/696 requests (14.22%)
# Completed 100/696 requests (14.37%)
# Completed 101/696 requests (14.51%)
# Completed 102/696 requests (14.66%)
# Completed 103/696 requests (14.80%)
# Completed 104/696 requests (14.94%)
# Completed 105/696 requests (15.09%)
# Completed 106/696 requests (15.23%)
# Completed 107/696 requests (15.37%)
# Completed 108/696 requests (15.52%)
# Completed 109/696 requests (15.66%)
# Completed 110/696 requests (15.80%)
# Completed 111/696 requests (15.95%)
# Completed 112/696 requests (16.09%)
# Completed 113/696 requests (16.24%)
# Completed 114/696 requests (16.38%)
# Completed 115/696 requests (16.52%)
# Completed 116/696 requests (16.67%)
# Completed 117/696 requests (16.81%)
# Completed 118/696 requests (16.95%)
# Completed 119/696 requests (17.10%)
# Completed 120/696 requests (17.24%)
# Completed 121/696 requests (17.39%)
# Completed 122/696 requests (17.53%)
# Completed 123/696 requests (17.67%)
# Completed 124/696 requests (17.82%)
# Completed 125/696 requests (17.96%)
# Completed 126/696 requests (18.10%)
# Completed 127/696 requests (18.25%)
# Completed 128/696 requests (18.39%)
# Completed 129/696 requests (18.53%)
# Completed 130/696 requests (18.68%)
# Completed 131/696 requests (18.82%)
# Completed 132/696 requests (18.97%)
# Completed 133/696 requests (19.11%)
# Completed 134/696 requests (19.25%)
# Completed 135/696 requests (19.40%)
# Completed 136/696 requests (19.54%)
# Completed 137/696 requests (19.68%)
# Completed 138/696 requests (19.83%)
# Completed 139/696 requests (19.97%)
# Completed 140/696 requests (20.11%)
# Completed 141/696 requests (20.26%)
# Completed 142/696 requests (20.40%)
# Completed 143/696 requests (20.55%)
# Completed 144/696 requests (20.69%)
# Completed 145/696 requests (20.83%)
# Completed 146/696 requests (20.98%)
# Completed 147/696 requests (21.12%)
# Completed 148/696 requests (21.26%)
# Completed 149/696 requests (21.41%)
# Completed 150/696 requests (21.55%)
# Completed 151/696 requests (21.70%)
# Completed 152/696 requests (21.84%)
# Completed 153/696 requests (21.98%)
# Completed 154/696 requests (22.13%)
# Completed 155/696 requests (22.27%)
# Completed 156/696 requests (22.41%)
# Completed 157/696 requests (22.56%)
# Completed 158/696 requests (22.70%)
# Completed 159/696 requests (22.84%)
# Completed 160/696 requests (22.99%)
# Completed 161/696 requests (23.13%)
# Completed 162/696 requests (23.28%)
# Completed 163/696 requests (23.42%)
# Completed 164/696 requests (23.56%)
# Completed 165/696 requests (23.71%)
# Completed 166/696 requests (23.85%)
# Completed 167/696 requests (23.99%)
# Completed 168/696 requests (24.14%)
# Completed 169/696 requests (24.28%)
# Completed 170/696 requests (24.43%)
# Completed 171/696 requests (24.57%)
# Completed 172/696 requests (24.71%)
# Completed 173/696 requests (24.86%)
# Completed 174/696 requests (25.00%)
# Completed 175/696 requests (25.14%)
# Completed 176/696 requests (25.29%)
# Completed 177/696 requests (25.43%)
# Completed 178/696 requests (25.57%)
# Completed 179/696 requests (25.72%)
# Completed 180/696 requests (25.86%)
# Completed 181/696 requests (26.01%)
# Completed 182/696 requests (26.15%)
# Completed 183/696 requests (26.29%)
# Completed 184/696 requests (26.44%)
# Completed 185/696 requests (26.58%)
# Completed 186/696 requests (26.72%)
# Completed 187/696 requests (26.87%)
# Completed 188/696 requests (27.01%)
# Completed 189/696 requests (27.16%)
# Completed 190/696 requests (27.30%)
# Completed 191/696 requests (27.44%)
# Completed 192/696 requests (27.59%)
# Completed 193/696 requests (27.73%)
# Completed 194/696 requests (27.87%)
# Completed 195/696 requests (28.02%)
# Completed 196/696 requests (28.16%)
# Completed 197/696 requests (28.30%)
# Completed 198/696 requests (28.45%)
# Completed 199/696 requests (28.59%)
# Completed 200/696 requests (28.74%)
# Completed 201/696 requests (28.88%)
# Completed 202/696 requests (29.02%)
# Completed 203/696 requests (29.17%)
# Completed 204/696 requests (29.31%)
# Completed 205/696 requests (29.45%)
# Completed 206/696 requests (29.60%)
# Completed 207/696 requests (29.74%)
# Completed 208/696 requests (29.89%)
# Completed 209/696 requests (30.03%)
# Completed 210/696 requests (30.17%)
# Completed 211/696 requests (30.32%)
# Completed 212/696 requests (30.46%)
# Completed 213/696 requests (30.60%)
# Completed 214/696 requests (30.75%)
# Completed 215/696 requests (30.89%)
# Completed 216/696 requests (31.03%)
# Completed 217/696 requests (31.18%)
# Completed 218/696 requests (31.32%)
# Completed 219/696 requests (31.47%)
# Completed 220/696 requests (31.61%)
# Completed 221/696 requests (31.75%)
# Completed 222/696 requests (31.90%)
# Completed 223/696 requests (32.04%)
# Completed 224/696 requests (32.18%)
# Completed 225/696 requests (32.33%)
# Completed 226/696 requests (32.47%)
# Completed 227/696 requests (32.61%)
# Completed 228/696 requests (32.76%)
# Completed 229/696 requests (32.90%)
# Completed 230/696 requests (33.05%)
# Completed 231/696 requests (33.19%)
# Completed 232/696 requests (33.33%)
# Completed 233/696 requests (33.48%)
# Completed 234/696 requests (33.62%)
# Completed 235/696 requests (33.76%)
# Completed 236/696 requests (33.91%)
# Completed 237/696 requests (34.05%)
# Completed 238/696 requests (34.20%)
# Completed 239/696 requests (34.34%)
# Completed 240/696 requests (34.48%)
# Completed 241/696 requests (34.63%)
# Completed 242/696 requests (34.77%)
# Completed 243/696 requests (34.91%)
# Completed 244/696 requests (35.06%)
# Completed 245/696 requests (35.20%)
# Completed 246/696 requests (35.34%)
# Completed 247/696 requests (35.49%)
# Completed 248/696 requests (35.63%)
# Completed 249/696 requests (35.78%)
# Completed 250/696 requests (35.92%)
# Completed 251/696 requests (36.06%)
# Completed 252/696 requests (36.21%)
# Completed 253/696 requests (36.35%)
# Completed 254/696 requests (36.49%)
# Completed 255/696 requests (36.64%)
# Completed 256/696 requests (36.78%)
# Completed 257/696 requests (36.93%)
# Completed 258/696 requests (37.07%)
# Completed 259/696 requests (37.21%)
# Completed 260/696 requests (37.36%)
# Completed 261/696 requests (37.50%)
# Completed 262/696 requests (37.64%)
# Completed 263/696 requests (37.79%)
# Completed 264/696 requests (37.93%)
# Completed 265/696 requests (38.07%)
# Completed 266/696 requests (38.22%)
# Completed 267/696 requests (38.36%)
# Completed 268/696 requests (38.51%)
# Completed 269/696 requests (38.65%)
# Completed 270/696 requests (38.79%)
# Completed 271/696 requests (38.94%)
# Completed 272/696 requests (39.08%)
# Completed 273/696 requests (39.22%)
# Completed 274/696 requests (39.37%)
# Completed 275/696 requests (39.51%)
# Completed 276/696 requests (39.66%)
# Completed 277/696 requests (39.80%)
# Completed 278/696 requests (39.94%)
# Completed 279/696 requests (40.09%)
# Completed 280/696 requests (40.23%)
# Completed 281/696 requests (40.37%)
# Completed 282/696 requests (40.52%)
# Completed 283/696 requests (40.66%)
# Completed 284/696 requests (40.80%)
# Completed 285/696 requests (40.95%)
# Completed 286/696 requests (41.09%)
# Completed 287/696 requests (41.24%)
# Completed 288/696 requests (41.38%)
# Completed 289/696 requests (41.52%)
# Completed 290/696 requests (41.67%)
# Completed 291/696 requests (41.81%)
# Completed 292/696 requests (41.95%)
# Completed 293/696 requests (42.10%)
# Completed 294/696 requests (42.24%)
# Completed 295/696 requests (42.39%)
# Completed 296/696 requests (42.53%)
# Completed 297/696 requests (42.67%)
# Completed 298/696 requests (42.82%)
# Completed 299/696 requests (42.96%)
# Completed 300/696 requests (43.10%)
# Completed 301/696 requests (43.25%)
# Completed 302/696 requests (43.39%)
# Completed 303/696 requests (43.53%)
# Completed 304/696 requests (43.68%)
# Completed 305/696 requests (43.82%)
# Completed 306/696 requests (43.97%)
# Completed 307/696 requests (44.11%)
# Completed 308/696 requests (44.25%)
# Completed 309/696 requests (44.40%)
# Completed 310/696 requests (44.54%)
# Completed 311/696 requests (44.68%)
# Completed 312/696 requests (44.83%)
# Completed 313/696 requests (44.97%)
# Completed 314/696 requests (45.11%)
# Completed 315/696 requests (45.26%)
# Completed 316/696 requests (45.40%)
# Completed 317/696 requests (45.55%)
# Completed 318/696 requests (45.69%)
# Completed 319/696 requests (45.83%)
# Completed 320/696 requests (45.98%)
# Completed 321/696 requests (46.12%)
# Completed 322/696 requests (46.26%)
# Completed 323/696 requests (46.41%)
# Completed 324/696 requests (46.55%)
# Completed 325/696 requests (46.70%)
# Completed 326/696 requests (46.84%)
# Completed 327/696 requests (46.98%)
# Completed 328/696 requests (47.13%)
# Completed 329/696 requests (47.27%)
# Completed 330/696 requests (47.41%)
# Completed 331/696 requests (47.56%)
# Completed 332/696 requests (47.70%)
# Completed 333/696 requests (47.84%)
# Completed 334/696 requests (47.99%)
# Completed 335/696 requests (48.13%)
# Completed 336/696 requests (48.28%)
# Completed 337/696 requests (48.42%)
# Completed 338/696 requests (48.56%)
# Completed 339/696 requests (48.71%)
# Completed 340/696 requests (48.85%)
# Completed 341/696 requests (48.99%)
# Completed 342/696 requests (49.14%)
# Completed 343/696 requests (49.28%)
# Completed 344/696 requests (49.43%)
# Completed 345/696 requests (49.57%)
# Completed 346/696 requests (49.71%)
# Completed 347/696 requests (49.86%)
# Completed 348/696 requests (50.00%)
# Completed 349/696 requests (50.14%)
# Completed 350/696 requests (50.29%)
# Completed 351/696 requests (50.43%)
# Completed 352/696 requests (50.57%)
# Completed 353/696 requests (50.72%)
# Completed 354/696 requests (50.86%)
# Completed 355/696 requests (51.01%)
# Completed 356/696 requests (51.15%)
# Completed 357/696 requests (51.29%)
# Completed 358/696 requests (51.44%)
# Completed 359/696 requests (51.58%)
# Completed 360/696 requests (51.72%)
# Completed 361/696 requests (51.87%)
# Completed 362/696 requests (52.01%)
# Completed 363/696 requests (52.16%)
# Completed 364/696 requests (52.30%)
# Completed 365/696 requests (52.44%)
# Completed 366/696 requests (52.59%)
# Completed 367/696 requests (52.73%)
# Completed 368/696 requests (52.87%)
# Completed 369/696 requests (53.02%)
# Completed 370/696 requests (53.16%)
# Completed 371/696 requests (53.30%)
# Completed 372/696 requests (53.45%)
# Completed 373/696 requests (53.59%)
# Completed 374/696 requests (53.74%)
# Completed 375/696 requests (53.88%)
# Completed 376/696 requests (54.02%)
# Completed 377/696 requests (54.17%)
# Completed 378/696 requests (54.31%)
# Completed 379/696 requests (54.45%)
# Completed 380/696 requests (54.60%)
# Completed 381/696 requests (54.74%)
# Completed 382/696 requests (54.89%)
# Completed 383/696 requests (55.03%)
# Completed 384/696 requests (55.17%)
# Completed 385/696 requests (55.32%)
# Completed 386/696 requests (55.46%)
# Completed 387/696 requests (55.60%)
# Completed 388/696 requests (55.75%)
# Completed 389/696 requests (55.89%)
# Completed 390/696 requests (56.03%)
# Completed 391/696 requests (56.18%)
# Completed 392/696 requests (56.32%)
# Completed 393/696 requests (56.47%)
# Completed 394/696 requests (56.61%)
# Completed 395/696 requests (56.75%)
# Completed 396/696 requests (56.90%)
# Completed 397/696 requests (57.04%)
# Completed 398/696 requests (57.18%)
# Completed 399/696 requests (57.33%)
# Completed 400/696 requests (57.47%)
# Completed 401/696 requests (57.61%)
# Completed 402/696 requests (57.76%)
# Completed 403/696 requests (57.90%)
# Completed 404/696 requests (58.05%)
# Completed 405/696 requests (58.19%)
# Completed 406/696 requests (58.33%)
# Completed 407/696 requests (58.48%)
# Completed 408/696 requests (58.62%)
# Completed 409/696 requests (58.76%)
# Completed 410/696 requests (58.91%)
# Completed 411/696 requests (59.05%)
# Completed 412/696 requests (59.20%)
# Completed 413/696 requests (59.34%)
# Completed 414/696 requests (59.48%)
# Completed 415/696 requests (59.63%)
# Completed 416/696 requests (59.77%)
# Completed 417/696 requests (59.91%)
# Completed 418/696 requests (60.06%)
# Completed 419/696 requests (60.20%)
# Completed 420/696 requests (60.34%)
# Completed 421/696 requests (60.49%)
# Completed 422/696 requests (60.63%)
# Completed 423/696 requests (60.78%)
# Completed 424/696 requests (60.92%)
# Completed 425/696 requests (61.06%)
# Completed 426/696 requests (61.21%)
# Completed 427/696 requests (61.35%)
# Completed 428/696 requests (61.49%)
# Completed 429/696 requests (61.64%)
# Completed 430/696 requests (61.78%)
# Completed 431/696 requests (61.93%)
# Completed 432/696 requests (62.07%)
# Completed 433/696 requests (62.21%)
# Completed 434/696 requests (62.36%)
# Completed 435/696 requests (62.50%)
# Completed 436/696 requests (62.64%)
# Completed 437/696 requests (62.79%)
# Completed 438/696 requests (62.93%)
# Completed 439/696 requests (63.07%)
# Completed 440/696 requests (63.22%)
# Completed 441/696 requests (63.36%)
# Completed 442/696 requests (63.51%)
# Completed 443/696 requests (63.65%)
# Completed 444/696 requests (63.79%)
# Completed 445/696 requests (63.94%)
# Completed 446/696 requests (64.08%)
# Completed 447/696 requests (64.22%)
# Completed 448/696 requests (64.37%)
# Completed 449/696 requests (64.51%)
# Completed 450/696 requests (64.66%)
# Completed 451/696 requests (64.80%)
# Completed 452/696 requests (64.94%)
# Completed 453/696 requests (65.09%)
# Completed 454/696 requests (65.23%)
# Completed 455/696 requests (65.37%)
# Completed 456/696 requests (65.52%)
# Completed 457/696 requests (65.66%)
# Completed 458/696 requests (65.80%)
# Completed 459/696 requests (65.95%)
# Completed 460/696 requests (66.09%)
# Completed 461/696 requests (66.24%)
# Completed 462/696 requests (66.38%)
# Completed 463/696 requests (66.52%)
# Completed 464/696 requests (66.67%)
# Completed 465/696 requests (66.81%)
# Completed 466/696 requests (66.95%)
# Completed 467/696 requests (67.10%)
# Completed 468/696 requests (67.24%)
# Completed 469/696 requests (67.39%)
# Completed 470/696 requests (67.53%)
# Completed 471/696 requests (67.67%)
# Completed 472/696 requests (67.82%)
# Completed 473/696 requests (67.96%)
# Completed 474/696 requests (68.10%)
# Completed 475/696 requests (68.25%)
# Completed 476/696 requests (68.39%)
# Completed 477/696 requests (68.53%)
# Completed 478/696 requests (68.68%)
# Completed 479/696 requests (68.82%)
# Completed 480/696 requests (68.97%)
# Completed 481/696 requests (69.11%)
# Completed 482/696 requests (69.25%)
# Completed 483/696 requests (69.40%)
# Completed 484/696 requests (69.54%)
# Completed 485/696 requests (69.68%)
# Completed 486/696 requests (69.83%)
# Completed 487/696 requests (69.97%)
# Completed 488/696 requests (70.11%)
# Completed 489/696 requests (70.26%)
# Completed 490/696 requests (70.40%)
# Completed 491/696 requests (70.55%)
# Completed 492/696 requests (70.69%)
# Completed 493/696 requests (70.83%)
# Completed 494/696 requests (70.98%)
# Completed 495/696 requests (71.12%)
# Completed 496/696 requests (71.26%)
# Completed 497/696 requests (71.41%)
# Completed 498/696 requests (71.55%)
# Completed 499/696 requests (71.70%)
# Completed 500/696 requests (71.84%)
# Completed 501/696 requests (71.98%)
# Completed 502/696 requests (72.13%)
# Completed 503/696 requests (72.27%)
# Completed 504/696 requests (72.41%)
# Completed 505/696 requests (72.56%)
# Completed 506/696 requests (72.70%)
# Completed 507/696 requests (72.84%)
# Completed 508/696 requests (72.99%)
# Completed 509/696 requests (73.13%)
# Completed 510/696 requests (73.28%)
# Completed 511/696 requests (73.42%)
# Completed 512/696 requests (73.56%)
# Completed 513/696 requests (73.71%)
# Completed 514/696 requests (73.85%)
# Completed 515/696 requests (73.99%)
# Completed 516/696 requests (74.14%)
# Completed 517/696 requests (74.28%)
# Completed 518/696 requests (74.43%)
# Completed 519/696 requests (74.57%)
# Completed 520/696 requests (74.71%)
# Completed 521/696 requests (74.86%)
# Completed 522/696 requests (75.00%)
# Completed 523/696 requests (75.14%)
# Completed 524/696 requests (75.29%)
# Completed 525/696 requests (75.43%)
# Completed 526/696 requests (75.57%)
# Completed 527/696 requests (75.72%)
# Completed 528/696 requests (75.86%)
# Completed 529/696 requests (76.01%)
# Completed 530/696 requests (76.15%)
# Completed 531/696 requests (76.29%)
# Completed 532/696 requests (76.44%)
# Completed 533/696 requests (76.58%)
# Completed 534/696 requests (76.72%)
# Completed 535/696 requests (76.87%)
# Completed 536/696 requests (77.01%)
# Completed 537/696 requests (77.16%)
# Completed 538/696 requests (77.30%)
# Completed 539/696 requests (77.44%)
# Completed 540/696 requests (77.59%)
# Completed 541/696 requests (77.73%)
# Completed 542/696 requests (77.87%)
# Completed 543/696 requests (78.02%)
# Completed 544/696 requests (78.16%)
# Completed 545/696 requests (78.30%)
# Completed 546/696 requests (78.45%)
# Completed 547/696 requests (78.59%)
# Completed 548/696 requests (78.74%)
# Completed 549/696 requests (78.88%)
# Completed 550/696 requests (79.02%)
# Completed 551/696 requests (79.17%)
# Completed 552/696 requests (79.31%)
# Completed 553/696 requests (79.45%)
# Completed 554/696 requests (79.60%)
# Completed 555/696 requests (79.74%)
# Completed 556/696 requests (79.89%)
# Completed 557/696 requests (80.03%)
# Completed 558/696 requests (80.17%)
# Completed 559/696 requests (80.32%)
# Completed 560/696 requests (80.46%)
# Completed 561/696 requests (80.60%)
# Completed 562/696 requests (80.75%)
# Completed 563/696 requests (80.89%)
# Completed 564/696 requests (81.03%)
# Completed 565/696 requests (81.18%)
# Completed 566/696 requests (81.32%)
# Completed 567/696 requests (81.47%)
# Completed 568/696 requests (81.61%)
# Completed 569/696 requests (81.75%)
# Completed 570/696 requests (81.90%)
# Completed 571/696 requests (82.04%)
# Completed 572/696 requests (82.18%)
# Completed 573/696 requests (82.33%)
# Completed 574/696 requests (82.47%)
# Completed 575/696 requests (82.61%)
# Completed 576/696 requests (82.76%)
# Completed 577/696 requests (82.90%)
# Completed 578/696 requests (83.05%)
# Completed 579/696 requests (83.19%)
# Completed 580/696 requests (83.33%)
# Completed 581/696 requests (83.48%)
# Completed 582/696 requests (83.62%)
# Completed 583/696 requests (83.76%)
# Completed 584/696 requests (83.91%)
# Completed 585/696 requests (84.05%)
# Completed 586/696 requests (84.20%)
# Completed 587/696 requests (84.34%)
# Completed 588/696 requests (84.48%)
# Completed 589/696 requests (84.63%)
# Completed 590/696 requests (84.77%)
# Completed 591/696 requests (84.91%)
# Completed 592/696 requests (85.06%)
# Completed 593/696 requests (85.20%)
# Completed 594/696 requests (85.34%)
# Completed 595/696 requests (85.49%)
# Completed 596/696 requests (85.63%)
# Completed 597/696 requests (85.78%)
# Completed 598/696 requests (85.92%)
# Completed 599/696 requests (86.06%)
# Completed 600/696 requests (86.21%)
# Completed 601/696 requests (86.35%)
# Completed 602/696 requests (86.49%)
# Completed 603/696 requests (86.64%)
# Completed 604/696 requests (86.78%)
# Completed 605/696 requests (86.93%)
# Completed 606/696 requests (87.07%)
# Completed 607/696 requests (87.21%)
# Completed 608/696 requests (87.36%)
# Completed 609/696 requests (87.50%)
# Completed 610/696 requests (87.64%)
# Completed 611/696 requests (87.79%)
# Completed 612/696 requests (87.93%)
# Completed 613/696 requests (88.07%)
# Completed 614/696 requests (88.22%)
# Completed 615/696 requests (88.36%)
# Completed 616/696 requests (88.51%)
# Completed 617/696 requests (88.65%)
# Completed 618/696 requests (88.79%)
# Completed 619/696 requests (88.94%)
# Completed 620/696 requests (89.08%)
# Completed 621/696 requests (89.22%)
# Completed 622/696 requests (89.37%)
# Completed 623/696 requests (89.51%)
# Completed 624/696 requests (89.66%)
# Completed 625/696 requests (89.80%)
# Completed 626/696 requests (89.94%)
# Completed 627/696 requests (90.09%)
# Completed 628/696 requests (90.23%)
# Completed 629/696 requests (90.37%)
# Completed 630/696 requests (90.52%)
# Completed 631/696 requests (90.66%)
# Completed 632/696 requests (90.80%)
# Completed 633/696 requests (90.95%)
# Completed 634/696 requests (91.09%)
# Completed 635/696 requests (91.24%)
# Completed 636/696 requests (91.38%)
# Completed 637/696 requests (91.52%)
# Completed 638/696 requests (91.67%)
# Completed 639/696 requests (91.81%)
# Completed 640/696 requests (91.95%)
# Completed 641/696 requests (92.10%)
# Completed 642/696 requests (92.24%)
# Completed 643/696 requests (92.39%)
# Completed 644/696 requests (92.53%)
# Completed 645/696 requests (92.67%)
# Completed 646/696 requests (92.82%)
# Completed 647/696 requests (92.96%)
# Completed 648/696 requests (93.10%)
# Completed 649/696 requests (93.25%)
# Completed 650/696 requests (93.39%)
# Completed 651/696 requests (93.53%)
# Completed 652/696 requests (93.68%)
# Completed 653/696 requests (93.82%)
# Completed 654/696 requests (93.97%)
# Completed 655/696 requests (94.11%)
# Completed 656/696 requests (94.25%)
# Completed 657/696 requests (94.40%)
# Completed 658/696 requests (94.54%)
# Completed 659/696 requests (94.68%)
# Completed 660/696 requests (94.83%)
# Completed 661/696 requests (94.97%)
# Completed 662/696 requests (95.11%)
# Completed 663/696 requests (95.26%)
# Completed 664/696 requests (95.40%)
# Completed 665/696 requests (95.55%)
# Completed 666/696 requests (95.69%)
# Completed 667/696 requests (95.83%)
# Completed 668/696 requests (95.98%)
# Completed 669/696 requests (96.12%)
# Completed 670/696 requests (96.26%)
# Completed 671/696 requests (96.41%)
# Completed 672/696 requests (96.55%)
# Completed 673/696 requests (96.70%)
# Completed 674/696 requests (96.84%)
# Completed 675/696 requests (96.98%)
# Completed 676/696 requests (97.13%)
# Completed 677/696 requests (97.27%)
# Completed 678/696 requests (97.41%)
# Completed 679/696 requests (97.56%)
# Completed 680/696 requests (97.70%)
# Completed 681/696 requests (97.84%)
# Completed 682/696 requests (97.99%)
# Completed 683/696 requests (98.13%)
# Completed 684/696 requests (98.28%)
# Completed 685/696 requests (98.42%)
# Completed 686/696 requests (98.56%)
# Completed 687/696 requests (98.71%)
# Completed 688/696 requests (98.85%)
# Completed 689/696 requests (98.99%)
# Completed 690/696 requests (99.14%)
# Completed 691/696 requests (99.28%)
# Completed 692/696 requests (99.43%)
# Completed 693/696 requests (99.57%)
# Completed 694/696 requests (99.71%)
# Completed 695/696 requests (99.86%)
# Completed 696/696 requests (100.00%)

# %%
df = pd.read_csv('./data-raw/event_data_sherdog.csv')
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df.to_csv('./data-raw/event_data_sherdog.csv', index=False)

# %%
df = pd.read_csv('./data-raw/event_data_sherdog.csv')
print(f"Total number of rows including the header in event_data_sherdog.csv: {len(df)}")
print(f"Column names: {list(df.columns)}")
# Out:
# Total number of rows including the header in event_data_sherdog.csv: 7654
# Column names: ['Event Name', 'Event Location', 'Event Date', 'Fighter 1', 'Fighter 2', 'Fighter 1 ID', 'Fighter 2 ID', 'Weight Class', 'Winning Fighter', 'Winning Method', 'Winning Round', 'Winning Time', 'Referee', 'Fight Type']

# %%
### Append sherdog fighter IDs to fighter_id_sherdog.csv

df = pd.read_csv('./data-raw/event_data_sherdog.csv')
df2 = pd.read_csv('./data-raw/fighter_id_sherdog.csv')

# Iterate over each row in df
for index, row in df.iterrows():
    fighter1 = row['Fighter 1']
    fighter2 = row['Fighter 2']
    fighter1_id = row['Fighter 1 ID']
    fighter2_id = row['Fighter 2 ID']
    for fighter, fighter_id in zip([fighter1, fighter2], [fighter1_id, fighter2_id]):
        if fighter not in df2['Fighter'].values and fighter_id not in df2['Fighter_ID'].values:
            df2 = pd.concat([df2, pd.DataFrame([{'Fighter': fighter, 'Fighter_ID': fighter_id}])])  # adjusted line

# Save the DataFrame
df2.to_csv('./data-raw/fighter_id_sherdog.csv', index=False)


### Function to remove nicknames
def remove_nickname(name):
    return re.sub(r" '.+?'", "", name)

## Remove them
df = pd.read_csv('./data-raw/fighter_id_sherdog.csv')
df['Fighter'] = df['Fighter'].apply(remove_nickname) # Apply the function to the 'Fighter' column
df.to_csv('./data-raw/fighter_id_sherdog.csv', index=False)

df = pd.read_csv('./data-raw/event_data_sherdog.csv')
df['Fighter 1'] = df['Fighter 1'].apply(remove_nickname)
df.to_csv('./data-raw/event_data_sherdog.csv', index=False)

df = pd.read_csv('./data-raw/event_data_sherdog.csv')
df['Fighter 2'] = df['Fighter 2'].apply(remove_nickname)
df.to_csv('./data-raw/event_data_sherdog.csv', index=False)

df = pd.read_csv('./data-raw/event_data_sherdog.csv')
df['Winning Fighter'] = df['Winning Fighter'].apply(remove_nickname)
df.to_csv('./data-raw/event_data_sherdog.csv', index=False)


### Add 'UFC' indicator to current fighters in fighter_id_sherdog.csv.csv
# Read the CSV file into a DataFrame
input_file_path = './data-raw/fighter_id_sherdog.csv'
output_file_path = './data-raw/fighter_id_sherdog.csv'
df = pd.read_csv(input_file_path)

# Add the new column 'UFC' with the value 'y'
df['UFC'] = 'y'

# Write the modified DataFrame back to a CSV file
df.to_csv(output_file_path, index=False)

print("New column 'UFC' added to the CSV file.")
# Out:
# New column 'UFC' added to the CSV file.

# %%
df = pd.read_csv('./data-raw/fighter_id_sherdog.csv')
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df.to_csv('./data-raw/fighter_id_sherdog.csv', index=False)

# %%
df = pd.read_csv('./data-raw/fighter_id_sherdog.csv')
print(f"Total number of rows including the header in fighter_id_sherdog.csv: {len(df)}")
print(f"Column names: {list(df.columns)}")
# Out:
# Total number of rows including the header in fighter_id_sherdog.csv: 2493
# Column names: ['Fighter', 'Fighter_ID', 'UFC']

# %% [markdown]
# # Fighter General Info

# %%
# W/ concurrent.futures ^

import warnings
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
import tqdm

def scrape_fighter_general_info_sherdog(fighter, fighter_id):
    url = f'https://www.sherdog.com/fighter/{fighter_id}'
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return {}
    soup = BeautifulSoup(response.content, 'html.parser')
    fighter_dict = {}
    try:
        fighter_data = soup.find('div', class_='fighter-data')
    except AttributeError:
        fighter_data = None
    try:
        birthdate = soup.find('span', itemprop='birthDate')
        birthdate = (birthdate.text).strip('""')
    except AttributeError:
        birthdate = '-'
    try:
        nationality = soup.find('strong', itemprop='nationality')
        nationality = (nationality.text).strip()
    except AttributeError:
        nationality = '-'
    try:
        hometown = soup.find('span', {'itemprop': 'addressLocality'}).text
        hometown = hometown.strip()
    except AttributeError:
        hometown = '-'
    try:
        association = soup.find('span', {'itemprop': 'name'}).text
        association = association.strip()
    except AttributeError:
        association = '-'
    try:
        weight_class_div = fighter_data.find('div', {'class': 'association-class'})
        links = weight_class_div.find_all('a')
        weight_class = links[-1].text
        weight_class = weight_class.strip()
    except (AttributeError, IndexError):
        weight_class = ''
    try:
        nickname = soup.find('span', class_='nickname')
        nickname = (nickname.text).strip('"')
    except AttributeError:
        nickname = '-'
    try:
        height = soup.find('b', itemprop='height')
        height = (height.text).strip('"')
    except AttributeError:
        height = '-'
    try:
        wins = soup.find('div', class_='winloses win').find_all('span')[1]
        wins = (wins.text).strip()
    except AttributeError:
        wins = '-'
    try:
        losses = soup.find('div', class_='winloses lose').find_all('span')[1]
        losses = (losses.text).strip()
    except AttributeError:
        losses = '-'
    dec_data_list = []
    try:
        win_type = fighter_data.find_all('div', class_='meter-title', string='DECISIONS')
        for method in win_type:
            if method.text.startswith('DECISIONS'):
                dec_data = method.find_next('div', class_='pl').text
                dec_data_list.append(dec_data)
        wins_dec = (dec_data_list[0]).strip()
        losses_dec = (dec_data_list[1]).strip()
    except (AttributeError, IndexError):
        wins_dec = '-'
        losses_dec = '-'
    ko_data_list = []
    try:
        win_type = soup.find_all('div', class_='meter-title')
        for method in win_type:
            if method.text.startswith('KO'):
                ko_data = method.find_next('div', class_='pl').text
                ko_data_list.append(ko_data)
        wins_ko = (ko_data_list[0]).strip()
        losses_ko = (ko_data_list[1]).strip()
    except (AttributeError, IndexError):
        wins_ko = '-'
        losses_ko = '-'
    sub_data_list = []
    try:
        win_type = fighter_data.find_all('div', class_='meter-title', string='SUBMISSIONS')
        for method in win_type:
            if method.text.startswith('SUBMISSIONS'):
                sub_data = method.find_next('div', class_='pl').text
                sub_data_list.append(sub_data)
        wins_sub = (sub_data_list[0]).strip()
        losses_sub = (sub_data_list[1]).strip()
    except (AttributeError, IndexError):
        wins_sub = '-'
        losses_sub = '-'
    fighter_dict = {
        'Fighter': fighter,
        'Nickname': nickname,
        'Birth Date': birthdate,
        'Nationality': nationality,
        'Hometown': hometown,
        'Association': association,
        'Weight Class': weight_class,
        'Height': height,
        'Wins': wins,
        'Losses': losses,
        'Win_Decision': wins_dec,
        'Win_KO': wins_ko,
        'Win_Sub': wins_sub,
        'Loss_Decision': losses_dec,
        'Loss_KO': losses_ko,
        'Loss_Sub': losses_sub,
        'Fighter_ID': fighter_id
    }
    return fighter_dict

def scrape_fighters_concurrently():
    warnings.filterwarnings("ignore", category=FutureWarning)
    df_fighter_id = pd.read_csv('./data-raw/fighter_id_sherdog.csv')
    fighter_data_list = []
    with ThreadPoolExecutor(max_workers=30) as executor:
        future_to_fighter = {executor.submit(scrape_fighter_general_info_sherdog, row['Fighter'], row['Fighter_ID']): row for index, row in df_fighter_id.iterrows()}
        for future in tqdm.tqdm(as_completed(future_to_fighter), total=len(future_to_fighter)):
            fighter_data = future.result()
            if fighter_data:
                fighter_data_list.append(fighter_data)
    new_df = pd.DataFrame(fighter_data_list)
    new_df.to_csv('./data-raw/fighter_info.csv', index=False)

scrape_fighters_concurrently()
# Out:
# 100%|██████████████████████████| 2493/2493 [02:48<00:00, 14.80it/s]

# %%
df = pd.read_csv('./data-raw/fighter_info.csv')
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
df.to_csv('./data-raw/fighter_info.csv', index=False)

# %%
df = pd.read_csv('./data-raw/fighter_info.csv')
print(f"Total number of rows including the header in fighter_info.csv: {len(df)}")
print(f"Column names: {list(df.columns)}")
# Out:
# Total number of rows including the header in fighter_info.csv: 2492
# Column names: ['Fighter', 'Nickname', 'Birth Date', 'Nationality', 'Hometown', 'Association', 'Weight Class', 'Height', 'Wins', 'Losses', 'Win_Decision', 'Win_KO', 'Win_Sub', 'Loss_Decision', 'Loss_KO', 'Loss_Sub', 'Fighter_ID']

# %% [markdown]
# # Fighter Fights

# %%
# !rm -rf ./data-raw/fighters/

directory_path = './data-raw/fighters/'
if not os.path.exists(directory_path):
    os.makedirs(directory_path)

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

def scrape_fighter_fights_sherdog(fighter_name, fighter_id, fighter_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    response = requests.get(fighter_url, headers=headers, timeout=60)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', {'class': 'new_table fighter'})
        rows = table.find_all('tr')[1:]
        fight_data = []
        new_opponents = []

        for row in rows:
            cols = row.find_all('td')
            fight_dict = {
                'Result': cols[0].text.strip(),
                'Opponent': cols[1].find('a').text.strip() if cols[1].find('a') else '-',
                'Event Date': cols[2].find_all('span')[-1].text.strip() if cols[2].find_all('span') else '-',
                'Method/Referee': cols[3].text.strip().split('\n')[0],
                'Rounds': cols[4].text.strip(),
                'Time': cols[5].text.strip()
            }
            fight_data.append(fight_dict)
            opponent_link = cols[1].find('a')['href'] if cols[1].find('a') else None
            if opponent_link:
                opponent_id = opponent_link.split('-')[-1]
                new_opponents.append({'Fighter': fight_dict['Opponent'], 'Fighter_ID': opponent_id})
        return fighter_id, fighter_name, fight_data, new_opponents
    return fighter_id, fighter_name, [], []

df_fighter_id = pd.read_csv('./data-raw/fighter_id_sherdog.csv')
all_new_opponents = []

def process_fighter(row):
    fighter_url = f"https://www.sherdog.com/fighter/{row['Fighter'].replace(' ', '-')}-{row['Fighter_ID']}"
    return scrape_fighter_fights_sherdog(row['Fighter'], row['Fighter_ID'], fighter_url)

total_fighters = len(df_fighter_id)
fighters_processed = 0

with ThreadPoolExecutor(max_workers=20) as executor:
    futures = [executor.submit(process_fighter, row) for _, row in df_fighter_id.iterrows()]
    for future in as_completed(futures):
        fighter_id, fighter_name, fight_data, new_opponents = future.result()
        fighters_processed += 1
        print(f"Processed {fighters_processed}/{total_fighters} fighters.")
        if fight_data:
            pd.DataFrame(fight_data).to_csv(f"./data-raw/fighters/{fighter_name.replace(' ', '_')}_{fighter_id}.csv", index=False)
            all_new_opponents.extend(new_opponents)

if all_new_opponents:
    df_new_opponents = pd.DataFrame(all_new_opponents).drop_duplicates()
    df_fighter_id = pd.concat([df_fighter_id, df_new_opponents], ignore_index=True).drop_duplicates()
    df_fighter_id.to_csv('./data-raw/fighter_id_sherdog.csv', index=False)
# Out:
# Processed 1/2493 fighters.
# Processed 2/2493 fighters.
# Processed 3/2493 fighters.
# Processed 4/2493 fighters.
# Processed 5/2493 fighters.
# Processed 6/2493 fighters.
# Processed 7/2493 fighters.
# Processed 8/2493 fighters.
# Processed 9/2493 fighters.
# Processed 10/2493 fighters.
# Processed 11/2493 fighters.
# Processed 12/2493 fighters.
# Processed 13/2493 fighters.
# Processed 14/2493 fighters.
# Processed 15/2493 fighters.
# Processed 16/2493 fighters.
# Processed 17/2493 fighters.
# Processed 18/2493 fighters.
# Processed 19/2493 fighters.
# Processed 20/2493 fighters.
# Processed 21/2493 fighters.
# Processed 22/2493 fighters.
# Processed 23/2493 fighters.
# Processed 24/2493 fighters.
# Processed 25/2493 fighters.
# Processed 26/2493 fighters.
# Processed 27/2493 fighters.
# Processed 28/2493 fighters.
# Processed 29/2493 fighters.
# Processed 30/2493 fighters.
# Processed 31/2493 fighters.
# Processed 32/2493 fighters.
# Processed 33/2493 fighters.
# Processed 34/2493 fighters.
# Processed 35/2493 fighters.
# Processed 36/2493 fighters.
# Processed 37/2493 fighters.
# Processed 38/2493 fighters.
# Processed 39/2493 fighters.
# Processed 40/2493 fighters.
# Processed 41/2493 fighters.
# Processed 42/2493 fighters.
# Processed 43/2493 fighters.
# Processed 44/2493 fighters.
# Processed 45/2493 fighters.
# Processed 46/2493 fighters.
# Processed 47/2493 fighters.
# Processed 48/2493 fighters.
# Processed 49/2493 fighters.
# Processed 50/2493 fighters.
# Processed 51/2493 fighters.
# Processed 52/2493 fighters.
# Processed 53/2493 fighters.
# Processed 54/2493 fighters.
# Processed 55/2493 fighters.
# Processed 56/2493 fighters.
# Processed 57/2493 fighters.
# Processed 58/2493 fighters.
# Processed 59/2493 fighters.
# Processed 60/2493 fighters.
# Processed 61/2493 fighters.
# Processed 62/2493 fighters.
# Processed 63/2493 fighters.
# Processed 64/2493 fighters.
# Processed 65/2493 fighters.
# Processed 66/2493 fighters.
# Processed 67/2493 fighters.
# Processed 68/2493 fighters.
# Processed 69/2493 fighters.
# Processed 70/2493 fighters.
# Processed 71/2493 fighters.
# Processed 72/2493 fighters.
# Processed 73/2493 fighters.
# Processed 74/2493 fighters.
# Processed 75/2493 fighters.
# Processed 76/2493 fighters.
# Processed 77/2493 fighters.
# Processed 78/2493 fighters.
# Processed 79/2493 fighters.
# Processed 80/2493 fighters.
# Processed 81/2493 fighters.
# Processed 82/2493 fighters.
# Processed 83/2493 fighters.
# Processed 84/2493 fighters.
# Processed 85/2493 fighters.
# Processed 86/2493 fighters.
# Processed 87/2493 fighters.
# Processed 88/2493 fighters.
# Processed 89/2493 fighters.
# Processed 90/2493 fighters.
# Processed 91/2493 fighters.
# Processed 92/2493 fighters.
# Processed 93/2493 fighters.
# Processed 94/2493 fighters.
# Processed 95/2493 fighters.
# Processed 96/2493 fighters.
# Processed 97/2493 fighters.
# Processed 98/2493 fighters.
# Processed 99/2493 fighters.
# Processed 100/2493 fighters.
# Processed 101/2493 fighters.
# Processed 102/2493 fighters.
# Processed 103/2493 fighters.
# Processed 104/2493 fighters.
# Processed 105/2493 fighters.
# Processed 106/2493 fighters.
# Processed 107/2493 fighters.
# Processed 108/2493 fighters.
# Processed 109/2493 fighters.
# Processed 110/2493 fighters.
# Processed 111/2493 fighters.
# Processed 112/2493 fighters.
# Processed 113/2493 fighters.
# Processed 114/2493 fighters.
# Processed 115/2493 fighters.
# Processed 116/2493 fighters.
# Processed 117/2493 fighters.
# Processed 118/2493 fighters.
# Processed 119/2493 fighters.
# Processed 120/2493 fighters.
# Processed 121/2493 fighters.
# Processed 122/2493 fighters.
# Processed 123/2493 fighters.
# Processed 124/2493 fighters.
# Processed 125/2493 fighters.
# Processed 126/2493 fighters.
# Processed 127/2493 fighters.
# Processed 128/2493 fighters.
# Processed 129/2493 fighters.
# Processed 130/2493 fighters.
# Processed 131/2493 fighters.
# Processed 132/2493 fighters.
# Processed 133/2493 fighters.
# Processed 134/2493 fighters.
# Processed 135/2493 fighters.
# Processed 136/2493 fighters.
# Processed 137/2493 fighters.
# Processed 138/2493 fighters.
# Processed 139/2493 fighters.
# Processed 140/2493 fighters.
# Processed 141/2493 fighters.
# Processed 142/2493 fighters.
# Processed 143/2493 fighters.
# Processed 144/2493 fighters.
# Processed 145/2493 fighters.
# Processed 146/2493 fighters.
# Processed 147/2493 fighters.
# Processed 148/2493 fighters.
# Processed 149/2493 fighters.
# Processed 150/2493 fighters.
# Processed 151/2493 fighters.
# Processed 152/2493 fighters.
# Processed 153/2493 fighters.
# Processed 154/2493 fighters.
# Processed 155/2493 fighters.
# Processed 156/2493 fighters.
# Processed 157/2493 fighters.
# Processed 158/2493 fighters.
# Processed 159/2493 fighters.
# Processed 160/2493 fighters.
# Processed 161/2493 fighters.
# Processed 162/2493 fighters.
# Processed 163/2493 fighters.
# Processed 164/2493 fighters.
# Processed 165/2493 fighters.
# Processed 166/2493 fighters.
# Processed 167/2493 fighters.
# Processed 168/2493 fighters.
# Processed 169/2493 fighters.
# Processed 170/2493 fighters.
# Processed 171/2493 fighters.
# Processed 172/2493 fighters.
# Processed 173/2493 fighters.
# Processed 174/2493 fighters.
# Processed 175/2493 fighters.
# Processed 176/2493 fighters.
# Processed 177/2493 fighters.
# Processed 178/2493 fighters.
# Processed 179/2493 fighters.
# Processed 180/2493 fighters.
# Processed 181/2493 fighters.
# Processed 182/2493 fighters.
# Processed 183/2493 fighters.
# Processed 184/2493 fighters.
# Processed 185/2493 fighters.
# Processed 186/2493 fighters.
# Processed 187/2493 fighters.
# Processed 188/2493 fighters.
# Processed 189/2493 fighters.
# Processed 190/2493 fighters.
# Processed 191/2493 fighters.
# Processed 192/2493 fighters.
# Processed 193/2493 fighters.
# Processed 194/2493 fighters.
# Processed 195/2493 fighters.
# Processed 196/2493 fighters.
# Processed 197/2493 fighters.
# Processed 198/2493 fighters.
# Processed 199/2493 fighters.
# Processed 200/2493 fighters.
# Processed 201/2493 fighters.
# Processed 202/2493 fighters.
# Processed 203/2493 fighters.
# Processed 204/2493 fighters.
# Processed 205/2493 fighters.
# Processed 206/2493 fighters.
# Processed 207/2493 fighters.
# Processed 208/2493 fighters.
# Processed 209/2493 fighters.
# Processed 210/2493 fighters.
# Processed 211/2493 fighters.
# Processed 212/2493 fighters.
# Processed 213/2493 fighters.
# Processed 214/2493 fighters.
# Processed 215/2493 fighters.
# Processed 216/2493 fighters.
# Processed 217/2493 fighters.
# Processed 218/2493 fighters.
# Processed 219/2493 fighters.
# Processed 220/2493 fighters.
# Processed 221/2493 fighters.
# Processed 222/2493 fighters.
# Processed 223/2493 fighters.
# Processed 224/2493 fighters.
# Processed 225/2493 fighters.
# Processed 226/2493 fighters.
# Processed 227/2493 fighters.
# Processed 228/2493 fighters.
# Processed 229/2493 fighters.
# Processed 230/2493 fighters.
# Processed 231/2493 fighters.
# Processed 232/2493 fighters.
# Processed 233/2493 fighters.
# Processed 234/2493 fighters.
# Processed 235/2493 fighters.
# Processed 236/2493 fighters.
# Processed 237/2493 fighters.
# Processed 238/2493 fighters.
# Processed 239/2493 fighters.
# Processed 240/2493 fighters.
# Processed 241/2493 fighters.
# Processed 242/2493 fighters.
# Processed 243/2493 fighters.
# Processed 244/2493 fighters.
# Processed 245/2493 fighters.
# Processed 246/2493 fighters.
# Processed 247/2493 fighters.
# Processed 248/2493 fighters.
# Processed 249/2493 fighters.
# Processed 250/2493 fighters.
# Processed 251/2493 fighters.
# Processed 252/2493 fighters.
# Processed 253/2493 fighters.
# Processed 254/2493 fighters.
# Processed 255/2493 fighters.
# Processed 256/2493 fighters.
# Processed 257/2493 fighters.
# Processed 258/2493 fighters.
# Processed 259/2493 fighters.
# Processed 260/2493 fighters.
# Processed 261/2493 fighters.
# Processed 262/2493 fighters.
# Processed 263/2493 fighters.
# Processed 264/2493 fighters.
# Processed 265/2493 fighters.
# Processed 266/2493 fighters.
# Processed 267/2493 fighters.
# Processed 268/2493 fighters.
# Processed 269/2493 fighters.
# Processed 270/2493 fighters.
# Processed 271/2493 fighters.
# Processed 272/2493 fighters.
# Processed 273/2493 fighters.
# Processed 274/2493 fighters.
# Processed 275/2493 fighters.
# Processed 276/2493 fighters.
# Processed 277/2493 fighters.
# Processed 278/2493 fighters.
# Processed 279/2493 fighters.
# Processed 280/2493 fighters.
# Processed 281/2493 fighters.
# Processed 282/2493 fighters.
# Processed 283/2493 fighters.
# Processed 284/2493 fighters.
# Processed 285/2493 fighters.
# Processed 286/2493 fighters.
# Processed 287/2493 fighters.
# Processed 288/2493 fighters.
# Processed 289/2493 fighters.
# Processed 290/2493 fighters.
# Processed 291/2493 fighters.
# Processed 292/2493 fighters.
# Processed 293/2493 fighters.
# Processed 294/2493 fighters.
# Processed 295/2493 fighters.
# Processed 296/2493 fighters.
# Processed 297/2493 fighters.
# Processed 298/2493 fighters.
# Processed 299/2493 fighters.
# Processed 300/2493 fighters.
# Processed 301/2493 fighters.
# Processed 302/2493 fighters.
# Processed 303/2493 fighters.
# Processed 304/2493 fighters.
# Processed 305/2493 fighters.
# Processed 306/2493 fighters.
# Processed 307/2493 fighters.
# Processed 308/2493 fighters.
# Processed 309/2493 fighters.
# Processed 310/2493 fighters.
# Processed 311/2493 fighters.
# Processed 312/2493 fighters.
# Processed 313/2493 fighters.
# Processed 314/2493 fighters.
# Processed 315/2493 fighters.
# Processed 316/2493 fighters.
# Processed 317/2493 fighters.
# Processed 318/2493 fighters.
# Processed 319/2493 fighters.
# Processed 320/2493 fighters.
# Processed 321/2493 fighters.
# Processed 322/2493 fighters.
# Processed 323/2493 fighters.
# Processed 324/2493 fighters.
# Processed 325/2493 fighters.
# Processed 326/2493 fighters.
# Processed 327/2493 fighters.
# Processed 328/2493 fighters.
# Processed 329/2493 fighters.
# Processed 330/2493 fighters.
# Processed 331/2493 fighters.
# Processed 332/2493 fighters.
# Processed 333/2493 fighters.
# Processed 334/2493 fighters.
# Processed 335/2493 fighters.
# Processed 336/2493 fighters.
# Processed 337/2493 fighters.
# Processed 338/2493 fighters.
# Processed 339/2493 fighters.
# Processed 340/2493 fighters.
# Processed 341/2493 fighters.
# Processed 342/2493 fighters.
# Processed 343/2493 fighters.
# Processed 344/2493 fighters.
# Processed 345/2493 fighters.
# Processed 346/2493 fighters.
# Processed 347/2493 fighters.
# Processed 348/2493 fighters.
# Processed 349/2493 fighters.
# Processed 350/2493 fighters.
# Processed 351/2493 fighters.
# Processed 352/2493 fighters.
# Processed 353/2493 fighters.
# Processed 354/2493 fighters.
# Processed 355/2493 fighters.
# Processed 356/2493 fighters.
# Processed 357/2493 fighters.
# Processed 358/2493 fighters.
# Processed 359/2493 fighters.
# Processed 360/2493 fighters.
# Processed 361/2493 fighters.
# Processed 362/2493 fighters.
# Processed 363/2493 fighters.
# Processed 364/2493 fighters.
# Processed 365/2493 fighters.
# Processed 366/2493 fighters.
# Processed 367/2493 fighters.
# Processed 368/2493 fighters.
# Processed 369/2493 fighters.
# Processed 370/2493 fighters.
# Processed 371/2493 fighters.
# Processed 372/2493 fighters.
# Processed 373/2493 fighters.
# Processed 374/2493 fighters.
# Processed 375/2493 fighters.
# Processed 376/2493 fighters.
# Processed 377/2493 fighters.
# Processed 378/2493 fighters.
# Processed 379/2493 fighters.
# Processed 380/2493 fighters.
# Processed 381/2493 fighters.
# Processed 382/2493 fighters.
# Processed 383/2493 fighters.
# Processed 384/2493 fighters.
# Processed 385/2493 fighters.
# Processed 386/2493 fighters.
# Processed 387/2493 fighters.
# Processed 388/2493 fighters.
# Processed 389/2493 fighters.
# Processed 390/2493 fighters.
# Processed 391/2493 fighters.
# Processed 392/2493 fighters.
# Processed 393/2493 fighters.
# Processed 394/2493 fighters.
# Processed 395/2493 fighters.
# Processed 396/2493 fighters.
# Processed 397/2493 fighters.
# Processed 398/2493 fighters.
# Processed 399/2493 fighters.
# Processed 400/2493 fighters.
# Processed 401/2493 fighters.
# Processed 402/2493 fighters.
# Processed 403/2493 fighters.
# Processed 404/2493 fighters.
# Processed 405/2493 fighters.
# Processed 406/2493 fighters.
# Processed 407/2493 fighters.
# Processed 408/2493 fighters.
# Processed 409/2493 fighters.
# Processed 410/2493 fighters.
# Processed 411/2493 fighters.
# Processed 412/2493 fighters.
# Processed 413/2493 fighters.
# Processed 414/2493 fighters.
# Processed 415/2493 fighters.
# Processed 416/2493 fighters.
# Processed 417/2493 fighters.
# Processed 418/2493 fighters.
# Processed 419/2493 fighters.
# Processed 420/2493 fighters.
# Processed 421/2493 fighters.
# Processed 422/2493 fighters.
# Processed 423/2493 fighters.
# Processed 424/2493 fighters.
# Processed 425/2493 fighters.
# Processed 426/2493 fighters.
# Processed 427/2493 fighters.
# Processed 428/2493 fighters.
# Processed 429/2493 fighters.
# Processed 430/2493 fighters.
# Processed 431/2493 fighters.
# Processed 432/2493 fighters.
# Processed 433/2493 fighters.
# Processed 434/2493 fighters.
# Processed 435/2493 fighters.
# Processed 436/2493 fighters.
# Processed 437/2493 fighters.
# Processed 438/2493 fighters.
# Processed 439/2493 fighters.
# Processed 440/2493 fighters.
# Processed 441/2493 fighters.
# Processed 442/2493 fighters.
# Processed 443/2493 fighters.
# Processed 444/2493 fighters.
# Processed 445/2493 fighters.
# Processed 446/2493 fighters.
# Processed 447/2493 fighters.
# Processed 448/2493 fighters.
# Processed 449/2493 fighters.
# Processed 450/2493 fighters.
# Processed 451/2493 fighters.
# Processed 452/2493 fighters.
# Processed 453/2493 fighters.
# Processed 454/2493 fighters.
# Processed 455/2493 fighters.
# Processed 456/2493 fighters.
# Processed 457/2493 fighters.
# Processed 458/2493 fighters.
# Processed 459/2493 fighters.
# Processed 460/2493 fighters.
# Processed 461/2493 fighters.
# Processed 462/2493 fighters.
# Processed 463/2493 fighters.
# Processed 464/2493 fighters.
# Processed 465/2493 fighters.
# Processed 466/2493 fighters.
# Processed 467/2493 fighters.
# Processed 468/2493 fighters.
# Processed 469/2493 fighters.
# Processed 470/2493 fighters.
# Processed 471/2493 fighters.
# Processed 472/2493 fighters.
# Processed 473/2493 fighters.
# Processed 474/2493 fighters.
# Processed 475/2493 fighters.
# Processed 476/2493 fighters.
# Processed 477/2493 fighters.
# Processed 478/2493 fighters.
# Processed 479/2493 fighters.
# Processed 480/2493 fighters.
# Processed 481/2493 fighters.
# Processed 482/2493 fighters.
# Processed 483/2493 fighters.
# Processed 484/2493 fighters.
# Processed 485/2493 fighters.
# Processed 486/2493 fighters.
# Processed 487/2493 fighters.
# Processed 488/2493 fighters.
# Processed 489/2493 fighters.
# Processed 490/2493 fighters.
# Processed 491/2493 fighters.
# Processed 492/2493 fighters.
# Processed 493/2493 fighters.
# Processed 494/2493 fighters.
# Processed 495/2493 fighters.
# Processed 496/2493 fighters.
# Processed 497/2493 fighters.
# Processed 498/2493 fighters.
# Processed 499/2493 fighters.
# Processed 500/2493 fighters.
# Processed 501/2493 fighters.
# Processed 502/2493 fighters.
# Processed 503/2493 fighters.
# Processed 504/2493 fighters.
# Processed 505/2493 fighters.
# Processed 506/2493 fighters.
# Processed 507/2493 fighters.
# Processed 508/2493 fighters.
# Processed 509/2493 fighters.
# Processed 510/2493 fighters.
# Processed 511/2493 fighters.
# Processed 512/2493 fighters.
# Processed 513/2493 fighters.
# Processed 514/2493 fighters.
# Processed 515/2493 fighters.
# Processed 516/2493 fighters.
# Processed 517/2493 fighters.
# Processed 518/2493 fighters.
# Processed 519/2493 fighters.
# Processed 520/2493 fighters.
# Processed 521/2493 fighters.
# Processed 522/2493 fighters.
# Processed 523/2493 fighters.
# Processed 524/2493 fighters.
# Processed 525/2493 fighters.
# Processed 526/2493 fighters.
# Processed 527/2493 fighters.
# Processed 528/2493 fighters.
# Processed 529/2493 fighters.
# Processed 530/2493 fighters.
# Processed 531/2493 fighters.
# Processed 532/2493 fighters.
# Processed 533/2493 fighters.
# Processed 534/2493 fighters.
# Processed 535/2493 fighters.
# Processed 536/2493 fighters.
# Processed 537/2493 fighters.
# Processed 538/2493 fighters.
# Processed 539/2493 fighters.
# Processed 540/2493 fighters.
# Processed 541/2493 fighters.
# Processed 542/2493 fighters.
# Processed 543/2493 fighters.
# Processed 544/2493 fighters.
# Processed 545/2493 fighters.
# Processed 546/2493 fighters.
# Processed 547/2493 fighters.
# Processed 548/2493 fighters.
# Processed 549/2493 fighters.
# Processed 550/2493 fighters.
# Processed 551/2493 fighters.
# Processed 552/2493 fighters.
# Processed 553/2493 fighters.
# Processed 554/2493 fighters.
# Processed 555/2493 fighters.
# Processed 556/2493 fighters.
# Processed 557/2493 fighters.
# Processed 558/2493 fighters.
# Processed 559/2493 fighters.
# Processed 560/2493 fighters.
# Processed 561/2493 fighters.
# Processed 562/2493 fighters.
# Processed 563/2493 fighters.
# Processed 564/2493 fighters.
# Processed 565/2493 fighters.
# Processed 566/2493 fighters.
# Processed 567/2493 fighters.
# Processed 568/2493 fighters.
# Processed 569/2493 fighters.
# Processed 570/2493 fighters.
# Processed 571/2493 fighters.
# Processed 572/2493 fighters.
# Processed 573/2493 fighters.
# Processed 574/2493 fighters.
# Processed 575/2493 fighters.
# Processed 576/2493 fighters.
# Processed 577/2493 fighters.
# Processed 578/2493 fighters.
# Processed 579/2493 fighters.
# Processed 580/2493 fighters.
# Processed 581/2493 fighters.
# Processed 582/2493 fighters.
# Processed 583/2493 fighters.
# Processed 584/2493 fighters.
# Processed 585/2493 fighters.
# Processed 586/2493 fighters.
# Processed 587/2493 fighters.
# Processed 588/2493 fighters.
# Processed 589/2493 fighters.
# Processed 590/2493 fighters.
# Processed 591/2493 fighters.
# Processed 592/2493 fighters.
# Processed 593/2493 fighters.
# Processed 594/2493 fighters.
# Processed 595/2493 fighters.
# Processed 596/2493 fighters.
# Processed 597/2493 fighters.
# Processed 598/2493 fighters.
# Processed 599/2493 fighters.
# Processed 600/2493 fighters.
# Processed 601/2493 fighters.
# Processed 602/2493 fighters.
# Processed 603/2493 fighters.
# Processed 604/2493 fighters.
# Processed 605/2493 fighters.
# Processed 606/2493 fighters.
# Processed 607/2493 fighters.
# Processed 608/2493 fighters.
# Processed 609/2493 fighters.
# Processed 610/2493 fighters.
# Processed 611/2493 fighters.
# Processed 612/2493 fighters.
# Processed 613/2493 fighters.
# Processed 614/2493 fighters.
# Processed 615/2493 fighters.
# Processed 616/2493 fighters.
# Processed 617/2493 fighters.
# Processed 618/2493 fighters.
# Processed 619/2493 fighters.
# Processed 620/2493 fighters.
# Processed 621/2493 fighters.
# Processed 622/2493 fighters.
# Processed 623/2493 fighters.
# Processed 624/2493 fighters.
# Processed 625/2493 fighters.
# Processed 626/2493 fighters.
# Processed 627/2493 fighters.
# Processed 628/2493 fighters.
# Processed 629/2493 fighters.
# Processed 630/2493 fighters.
# Processed 631/2493 fighters.
# Processed 632/2493 fighters.
# Processed 633/2493 fighters.
# Processed 634/2493 fighters.
# Processed 635/2493 fighters.
# Processed 636/2493 fighters.
# Processed 637/2493 fighters.
# Processed 638/2493 fighters.
# Processed 639/2493 fighters.
# Processed 640/2493 fighters.
# Processed 641/2493 fighters.
# Processed 642/2493 fighters.
# Processed 643/2493 fighters.
# Processed 644/2493 fighters.
# Processed 645/2493 fighters.
# Processed 646/2493 fighters.
# Processed 647/2493 fighters.
# Processed 648/2493 fighters.
# Processed 649/2493 fighters.
# Processed 650/2493 fighters.
# Processed 651/2493 fighters.
# Processed 652/2493 fighters.
# Processed 653/2493 fighters.
# Processed 654/2493 fighters.
# Processed 655/2493 fighters.
# Processed 656/2493 fighters.
# Processed 657/2493 fighters.
# Processed 658/2493 fighters.
# Processed 659/2493 fighters.
# Processed 660/2493 fighters.
# Processed 661/2493 fighters.
# Processed 662/2493 fighters.
# Processed 663/2493 fighters.
# Processed 664/2493 fighters.
# Processed 665/2493 fighters.
# Processed 666/2493 fighters.
# Processed 667/2493 fighters.
# Processed 668/2493 fighters.
# Processed 669/2493 fighters.
# Processed 670/2493 fighters.
# Processed 671/2493 fighters.
# Processed 672/2493 fighters.
# Processed 673/2493 fighters.
# Processed 674/2493 fighters.
# Processed 675/2493 fighters.
# Processed 676/2493 fighters.
# Processed 677/2493 fighters.
# Processed 678/2493 fighters.
# Processed 679/2493 fighters.
# Processed 680/2493 fighters.
# Processed 681/2493 fighters.
# Processed 682/2493 fighters.
# Processed 683/2493 fighters.
# Processed 684/2493 fighters.
# Processed 685/2493 fighters.
# Processed 686/2493 fighters.
# Processed 687/2493 fighters.
# Processed 688/2493 fighters.
# Processed 689/2493 fighters.
# Processed 690/2493 fighters.
# Processed 691/2493 fighters.
# Processed 692/2493 fighters.
# Processed 693/2493 fighters.
# Processed 694/2493 fighters.
# Processed 695/2493 fighters.
# Processed 696/2493 fighters.
# Processed 697/2493 fighters.
# Processed 698/2493 fighters.
# Processed 699/2493 fighters.
# Processed 700/2493 fighters.
# Processed 701/2493 fighters.
# Processed 702/2493 fighters.
# Processed 703/2493 fighters.
# Processed 704/2493 fighters.
# Processed 705/2493 fighters.
# Processed 706/2493 fighters.
# Processed 707/2493 fighters.
# Processed 708/2493 fighters.
# Processed 709/2493 fighters.
# Processed 710/2493 fighters.
# Processed 711/2493 fighters.
# Processed 712/2493 fighters.
# Processed 713/2493 fighters.
# Processed 714/2493 fighters.
# Processed 715/2493 fighters.
# Processed 716/2493 fighters.
# Processed 717/2493 fighters.
# Processed 718/2493 fighters.
# Processed 719/2493 fighters.
# Processed 720/2493 fighters.
# Processed 721/2493 fighters.
# Processed 722/2493 fighters.
# Processed 723/2493 fighters.
# Processed 724/2493 fighters.
# Processed 725/2493 fighters.
# Processed 726/2493 fighters.
# Processed 727/2493 fighters.
# Processed 728/2493 fighters.
# Processed 729/2493 fighters.
# Processed 730/2493 fighters.
# Processed 731/2493 fighters.
# Processed 732/2493 fighters.
# Processed 733/2493 fighters.
# Processed 734/2493 fighters.
# Processed 735/2493 fighters.
# Processed 736/2493 fighters.
# Processed 737/2493 fighters.
# Processed 738/2493 fighters.
# Processed 739/2493 fighters.
# Processed 740/2493 fighters.
# Processed 741/2493 fighters.
# Processed 742/2493 fighters.
# Processed 743/2493 fighters.
# Processed 744/2493 fighters.
# Processed 745/2493 fighters.
# Processed 746/2493 fighters.
# Processed 747/2493 fighters.
# Processed 748/2493 fighters.
# Processed 749/2493 fighters.
# Processed 750/2493 fighters.
# Processed 751/2493 fighters.
# Processed 752/2493 fighters.
# Processed 753/2493 fighters.
# Processed 754/2493 fighters.
# Processed 755/2493 fighters.
# Processed 756/2493 fighters.
# Processed 757/2493 fighters.
# Processed 758/2493 fighters.
# Processed 759/2493 fighters.
# Processed 760/2493 fighters.
# Processed 761/2493 fighters.
# Processed 762/2493 fighters.
# Processed 763/2493 fighters.
# Processed 764/2493 fighters.
# Processed 765/2493 fighters.
# Processed 766/2493 fighters.
# Processed 767/2493 fighters.
# Processed 768/2493 fighters.
# Processed 769/2493 fighters.
# Processed 770/2493 fighters.
# Processed 771/2493 fighters.
# Processed 772/2493 fighters.
# Processed 773/2493 fighters.
# Processed 774/2493 fighters.
# Processed 775/2493 fighters.
# Processed 776/2493 fighters.
# Processed 777/2493 fighters.
# Processed 778/2493 fighters.
# Processed 779/2493 fighters.
# Processed 780/2493 fighters.
# Processed 781/2493 fighters.
# Processed 782/2493 fighters.
# Processed 783/2493 fighters.
# Processed 784/2493 fighters.
# Processed 785/2493 fighters.
# Processed 786/2493 fighters.
# Processed 787/2493 fighters.
# Processed 788/2493 fighters.
# Processed 789/2493 fighters.
# Processed 790/2493 fighters.
# Processed 791/2493 fighters.
# Processed 792/2493 fighters.
# Processed 793/2493 fighters.
# Processed 794/2493 fighters.
# Processed 795/2493 fighters.
# Processed 796/2493 fighters.
# Processed 797/2493 fighters.
# Processed 798/2493 fighters.
# Processed 799/2493 fighters.
# Processed 800/2493 fighters.
# Processed 801/2493 fighters.
# Processed 802/2493 fighters.
# Processed 803/2493 fighters.
# Processed 804/2493 fighters.
# Processed 805/2493 fighters.
# Processed 806/2493 fighters.
# Processed 807/2493 fighters.
# Processed 808/2493 fighters.
# Processed 809/2493 fighters.
# Processed 810/2493 fighters.
# Processed 811/2493 fighters.
# Processed 812/2493 fighters.
# Processed 813/2493 fighters.
# Processed 814/2493 fighters.
# Processed 815/2493 fighters.
# Processed 816/2493 fighters.
# Processed 817/2493 fighters.
# Processed 818/2493 fighters.
# Processed 819/2493 fighters.
# Processed 820/2493 fighters.
# Processed 821/2493 fighters.
# Processed 822/2493 fighters.
# Processed 823/2493 fighters.
# Processed 824/2493 fighters.
# Processed 825/2493 fighters.
# Processed 826/2493 fighters.
# Processed 827/2493 fighters.
# Processed 828/2493 fighters.
# Processed 829/2493 fighters.
# Processed 830/2493 fighters.
# Processed 831/2493 fighters.
# Processed 832/2493 fighters.
# Processed 833/2493 fighters.
# Processed 834/2493 fighters.
# Processed 835/2493 fighters.
# Processed 836/2493 fighters.
# Processed 837/2493 fighters.
# Processed 838/2493 fighters.
# Processed 839/2493 fighters.
# Processed 840/2493 fighters.
# Processed 841/2493 fighters.
# Processed 842/2493 fighters.
# Processed 843/2493 fighters.
# Processed 844/2493 fighters.
# Processed 845/2493 fighters.
# Processed 846/2493 fighters.
# Processed 847/2493 fighters.
# Processed 848/2493 fighters.
# Processed 849/2493 fighters.
# Processed 850/2493 fighters.
# Processed 851/2493 fighters.
# Processed 852/2493 fighters.
# Processed 853/2493 fighters.
# Processed 854/2493 fighters.
# Processed 855/2493 fighters.
# Processed 856/2493 fighters.
# Processed 857/2493 fighters.
# Processed 858/2493 fighters.
# Processed 859/2493 fighters.
# Processed 860/2493 fighters.
# Processed 861/2493 fighters.
# Processed 862/2493 fighters.
# Processed 863/2493 fighters.
# Processed 864/2493 fighters.
# Processed 865/2493 fighters.
# Processed 866/2493 fighters.
# Processed 867/2493 fighters.
# Processed 868/2493 fighters.
# Processed 869/2493 fighters.
# Processed 870/2493 fighters.
# Processed 871/2493 fighters.
# Processed 872/2493 fighters.
# Processed 873/2493 fighters.
# Processed 874/2493 fighters.
# Processed 875/2493 fighters.
# Processed 876/2493 fighters.
# Processed 877/2493 fighters.
# Processed 878/2493 fighters.
# Processed 879/2493 fighters.
# Processed 880/2493 fighters.
# Processed 881/2493 fighters.
# Processed 882/2493 fighters.
# Processed 883/2493 fighters.
# Processed 884/2493 fighters.
# Processed 885/2493 fighters.
# Processed 886/2493 fighters.
# Processed 887/2493 fighters.
# Processed 888/2493 fighters.
# Processed 889/2493 fighters.
# Processed 890/2493 fighters.
# Processed 891/2493 fighters.
# Processed 892/2493 fighters.
# Processed 893/2493 fighters.
# Processed 894/2493 fighters.
# Processed 895/2493 fighters.
# Processed 896/2493 fighters.
# Processed 897/2493 fighters.
# Processed 898/2493 fighters.
# Processed 899/2493 fighters.
# Processed 900/2493 fighters.
# Processed 901/2493 fighters.
# Processed 902/2493 fighters.
# Processed 903/2493 fighters.
# Processed 904/2493 fighters.
# Processed 905/2493 fighters.
# Processed 906/2493 fighters.
# Processed 907/2493 fighters.
# Processed 908/2493 fighters.
# Processed 909/2493 fighters.
# Processed 910/2493 fighters.
# Processed 911/2493 fighters.
# Processed 912/2493 fighters.
# Processed 913/2493 fighters.
# Processed 914/2493 fighters.
# Processed 915/2493 fighters.
# Processed 916/2493 fighters.
# Processed 917/2493 fighters.
# Processed 918/2493 fighters.
# Processed 919/2493 fighters.
# Processed 920/2493 fighters.
# Processed 921/2493 fighters.
# Processed 922/2493 fighters.
# Processed 923/2493 fighters.
# Processed 924/2493 fighters.
# Processed 925/2493 fighters.
# Processed 926/2493 fighters.
# Processed 927/2493 fighters.
# Processed 928/2493 fighters.
# Processed 929/2493 fighters.
# Processed 930/2493 fighters.
# Processed 931/2493 fighters.
# Processed 932/2493 fighters.
# Processed 933/2493 fighters.
# Processed 934/2493 fighters.
# Processed 935/2493 fighters.
# Processed 936/2493 fighters.
# Processed 937/2493 fighters.
# Processed 938/2493 fighters.
# Processed 939/2493 fighters.
# Processed 940/2493 fighters.
# Processed 941/2493 fighters.
# Processed 942/2493 fighters.
# Processed 943/2493 fighters.
# Processed 944/2493 fighters.
# Processed 945/2493 fighters.
# Processed 946/2493 fighters.
# Processed 947/2493 fighters.
# Processed 948/2493 fighters.
# Processed 949/2493 fighters.
# Processed 950/2493 fighters.
# Processed 951/2493 fighters.
# Processed 952/2493 fighters.
# Processed 953/2493 fighters.
# Processed 954/2493 fighters.
# Processed 955/2493 fighters.
# Processed 956/2493 fighters.
# Processed 957/2493 fighters.
# Processed 958/2493 fighters.
# Processed 959/2493 fighters.
# Processed 960/2493 fighters.
# Processed 961/2493 fighters.
# Processed 962/2493 fighters.
# Processed 963/2493 fighters.
# Processed 964/2493 fighters.
# Processed 965/2493 fighters.
# Processed 966/2493 fighters.
# Processed 967/2493 fighters.
# Processed 968/2493 fighters.
# Processed 969/2493 fighters.
# Processed 970/2493 fighters.
# Processed 971/2493 fighters.
# Processed 972/2493 fighters.
# Processed 973/2493 fighters.
# Processed 974/2493 fighters.
# Processed 975/2493 fighters.
# Processed 976/2493 fighters.
# Processed 977/2493 fighters.
# Processed 978/2493 fighters.
# Processed 979/2493 fighters.
# Processed 980/2493 fighters.
# Processed 981/2493 fighters.
# Processed 982/2493 fighters.
# Processed 983/2493 fighters.
# Processed 984/2493 fighters.
# Processed 985/2493 fighters.
# Processed 986/2493 fighters.
# Processed 987/2493 fighters.
# Processed 988/2493 fighters.
# Processed 989/2493 fighters.
# Processed 990/2493 fighters.
# Processed 991/2493 fighters.
# Processed 992/2493 fighters.
# Processed 993/2493 fighters.
# Processed 994/2493 fighters.
# Processed 995/2493 fighters.
# Processed 996/2493 fighters.
# Processed 997/2493 fighters.
# Processed 998/2493 fighters.
# Processed 999/2493 fighters.
# Processed 1000/2493 fighters.
# Processed 1001/2493 fighters.
# Processed 1002/2493 fighters.
# Processed 1003/2493 fighters.
# Processed 1004/2493 fighters.
# Processed 1005/2493 fighters.
# Processed 1006/2493 fighters.
# Processed 1007/2493 fighters.
# Processed 1008/2493 fighters.
# Processed 1009/2493 fighters.
# Processed 1010/2493 fighters.
# Processed 1011/2493 fighters.
# Processed 1012/2493 fighters.
# Processed 1013/2493 fighters.
# Processed 1014/2493 fighters.
# Processed 1015/2493 fighters.
# Processed 1016/2493 fighters.
# Processed 1017/2493 fighters.
# Processed 1018/2493 fighters.
# Processed 1019/2493 fighters.
# Processed 1020/2493 fighters.
# Processed 1021/2493 fighters.
# Processed 1022/2493 fighters.
# Processed 1023/2493 fighters.
# Processed 1024/2493 fighters.
# Processed 1025/2493 fighters.
# Processed 1026/2493 fighters.
# Processed 1027/2493 fighters.
# Processed 1028/2493 fighters.
# Processed 1029/2493 fighters.
# Processed 1030/2493 fighters.
# Processed 1031/2493 fighters.
# Processed 1032/2493 fighters.
# Processed 1033/2493 fighters.
# Processed 1034/2493 fighters.
# Processed 1035/2493 fighters.
# Processed 1036/2493 fighters.
# Processed 1037/2493 fighters.
# Processed 1038/2493 fighters.
# Processed 1039/2493 fighters.
# Processed 1040/2493 fighters.
# Processed 1041/2493 fighters.
# Processed 1042/2493 fighters.
# Processed 1043/2493 fighters.
# Processed 1044/2493 fighters.
# Processed 1045/2493 fighters.
# Processed 1046/2493 fighters.
# Processed 1047/2493 fighters.
# Processed 1048/2493 fighters.
# Processed 1049/2493 fighters.
# Processed 1050/2493 fighters.
# Processed 1051/2493 fighters.
# Processed 1052/2493 fighters.
# Processed 1053/2493 fighters.
# Processed 1054/2493 fighters.
# Processed 1055/2493 fighters.
# Processed 1056/2493 fighters.
# Processed 1057/2493 fighters.
# Processed 1058/2493 fighters.
# Processed 1059/2493 fighters.
# Processed 1060/2493 fighters.
# Processed 1061/2493 fighters.
# Processed 1062/2493 fighters.
# Processed 1063/2493 fighters.
# Processed 1064/2493 fighters.
# Processed 1065/2493 fighters.
# Processed 1066/2493 fighters.
# Processed 1067/2493 fighters.
# Processed 1068/2493 fighters.
# Processed 1069/2493 fighters.
# Processed 1070/2493 fighters.
# Processed 1071/2493 fighters.
# Processed 1072/2493 fighters.
# Processed 1073/2493 fighters.
# Processed 1074/2493 fighters.
# Processed 1075/2493 fighters.
# Processed 1076/2493 fighters.
# Processed 1077/2493 fighters.
# Processed 1078/2493 fighters.
# Processed 1079/2493 fighters.
# Processed 1080/2493 fighters.
# Processed 1081/2493 fighters.
# Processed 1082/2493 fighters.
# Processed 1083/2493 fighters.
# Processed 1084/2493 fighters.
# Processed 1085/2493 fighters.
# Processed 1086/2493 fighters.
# Processed 1087/2493 fighters.
# Processed 1088/2493 fighters.
# Processed 1089/2493 fighters.
# Processed 1090/2493 fighters.
# Processed 1091/2493 fighters.
# Processed 1092/2493 fighters.
# Processed 1093/2493 fighters.
# Processed 1094/2493 fighters.
# Processed 1095/2493 fighters.
# Processed 1096/2493 fighters.
# Processed 1097/2493 fighters.
# Processed 1098/2493 fighters.
# Processed 1099/2493 fighters.
# Processed 1100/2493 fighters.
# Processed 1101/2493 fighters.
# Processed 1102/2493 fighters.
# Processed 1103/2493 fighters.
# Processed 1104/2493 fighters.
# Processed 1105/2493 fighters.
# Processed 1106/2493 fighters.
# Processed 1107/2493 fighters.
# Processed 1108/2493 fighters.
# Processed 1109/2493 fighters.
# Processed 1110/2493 fighters.
# Processed 1111/2493 fighters.
# Processed 1112/2493 fighters.
# Processed 1113/2493 fighters.
# Processed 1114/2493 fighters.
# Processed 1115/2493 fighters.
# Processed 1116/2493 fighters.
# Processed 1117/2493 fighters.
# Processed 1118/2493 fighters.
# Processed 1119/2493 fighters.
# Processed 1120/2493 fighters.
# Processed 1121/2493 fighters.
# Processed 1122/2493 fighters.
# Processed 1123/2493 fighters.
# Processed 1124/2493 fighters.
# Processed 1125/2493 fighters.
# Processed 1126/2493 fighters.
# Processed 1127/2493 fighters.
# Processed 1128/2493 fighters.
# Processed 1129/2493 fighters.
# Processed 1130/2493 fighters.
# Processed 1131/2493 fighters.
# Processed 1132/2493 fighters.
# Processed 1133/2493 fighters.
# Processed 1134/2493 fighters.
# Processed 1135/2493 fighters.
# Processed 1136/2493 fighters.
# Processed 1137/2493 fighters.
# Processed 1138/2493 fighters.
# Processed 1139/2493 fighters.
# Processed 1140/2493 fighters.
# Processed 1141/2493 fighters.
# Processed 1142/2493 fighters.
# Processed 1143/2493 fighters.
# Processed 1144/2493 fighters.
# Processed 1145/2493 fighters.
# Processed 1146/2493 fighters.
# Processed 1147/2493 fighters.
# Processed 1148/2493 fighters.
# Processed 1149/2493 fighters.
# Processed 1150/2493 fighters.
# Processed 1151/2493 fighters.
# Processed 1152/2493 fighters.
# Processed 1153/2493 fighters.
# Processed 1154/2493 fighters.
# Processed 1155/2493 fighters.
# Processed 1156/2493 fighters.
# Processed 1157/2493 fighters.
# Processed 1158/2493 fighters.
# Processed 1159/2493 fighters.
# Processed 1160/2493 fighters.
# Processed 1161/2493 fighters.
# Processed 1162/2493 fighters.
# Processed 1163/2493 fighters.
# Processed 1164/2493 fighters.
# Processed 1165/2493 fighters.
# Processed 1166/2493 fighters.
# Processed 1167/2493 fighters.
# Processed 1168/2493 fighters.
# Processed 1169/2493 fighters.
# Processed 1170/2493 fighters.
# Processed 1171/2493 fighters.
# Processed 1172/2493 fighters.
# Processed 1173/2493 fighters.
# Processed 1174/2493 fighters.
# Processed 1175/2493 fighters.
# Processed 1176/2493 fighters.
# Processed 1177/2493 fighters.
# Processed 1178/2493 fighters.
# Processed 1179/2493 fighters.
# Processed 1180/2493 fighters.
# Processed 1181/2493 fighters.
# Processed 1182/2493 fighters.
# Processed 1183/2493 fighters.
# Processed 1184/2493 fighters.
# Processed 1185/2493 fighters.
# Processed 1186/2493 fighters.
# Processed 1187/2493 fighters.
# Processed 1188/2493 fighters.
# Processed 1189/2493 fighters.
# Processed 1190/2493 fighters.
# Processed 1191/2493 fighters.
# Processed 1192/2493 fighters.
# Processed 1193/2493 fighters.
# Processed 1194/2493 fighters.
# Processed 1195/2493 fighters.
# Processed 1196/2493 fighters.
# Processed 1197/2493 fighters.
# Processed 1198/2493 fighters.
# Processed 1199/2493 fighters.
# Processed 1200/2493 fighters.
# Processed 1201/2493 fighters.
# Processed 1202/2493 fighters.
# Processed 1203/2493 fighters.
# Processed 1204/2493 fighters.
# Processed 1205/2493 fighters.
# Processed 1206/2493 fighters.
# Processed 1207/2493 fighters.
# Processed 1208/2493 fighters.
# Processed 1209/2493 fighters.
# Processed 1210/2493 fighters.
# Processed 1211/2493 fighters.
# Processed 1212/2493 fighters.
# Processed 1213/2493 fighters.
# Processed 1214/2493 fighters.
# Processed 1215/2493 fighters.
# Processed 1216/2493 fighters.
# Processed 1217/2493 fighters.
# Processed 1218/2493 fighters.
# Processed 1219/2493 fighters.
# Processed 1220/2493 fighters.
# Processed 1221/2493 fighters.
# Processed 1222/2493 fighters.
# Processed 1223/2493 fighters.
# Processed 1224/2493 fighters.
# Processed 1225/2493 fighters.
# Processed 1226/2493 fighters.
# Processed 1227/2493 fighters.
# Processed 1228/2493 fighters.
# Processed 1229/2493 fighters.
# Processed 1230/2493 fighters.
# Processed 1231/2493 fighters.
# Processed 1232/2493 fighters.
# Processed 1233/2493 fighters.
# Processed 1234/2493 fighters.
# Processed 1235/2493 fighters.
# Processed 1236/2493 fighters.
# Processed 1237/2493 fighters.
# Processed 1238/2493 fighters.
# Processed 1239/2493 fighters.
# Processed 1240/2493 fighters.
# Processed 1241/2493 fighters.
# Processed 1242/2493 fighters.
# Processed 1243/2493 fighters.
# Processed 1244/2493 fighters.
# Processed 1245/2493 fighters.
# Processed 1246/2493 fighters.
# Processed 1247/2493 fighters.
# Processed 1248/2493 fighters.
# Processed 1249/2493 fighters.
# Processed 1250/2493 fighters.
# Processed 1251/2493 fighters.
# Processed 1252/2493 fighters.
# Processed 1253/2493 fighters.
# Processed 1254/2493 fighters.
# Processed 1255/2493 fighters.
# Processed 1256/2493 fighters.
# Processed 1257/2493 fighters.
# Processed 1258/2493 fighters.
# Processed 1259/2493 fighters.
# Processed 1260/2493 fighters.
# Processed 1261/2493 fighters.
# Processed 1262/2493 fighters.
# Processed 1263/2493 fighters.
# Processed 1264/2493 fighters.
# Processed 1265/2493 fighters.
# Processed 1266/2493 fighters.
# Processed 1267/2493 fighters.
# Processed 1268/2493 fighters.
# Processed 1269/2493 fighters.
# Processed 1270/2493 fighters.
# Processed 1271/2493 fighters.
# Processed 1272/2493 fighters.
# Processed 1273/2493 fighters.
# Processed 1274/2493 fighters.
# Processed 1275/2493 fighters.
# Processed 1276/2493 fighters.
# Processed 1277/2493 fighters.
# Processed 1278/2493 fighters.
# Processed 1279/2493 fighters.
# Processed 1280/2493 fighters.
# Processed 1281/2493 fighters.
# Processed 1282/2493 fighters.
# Processed 1283/2493 fighters.
# Processed 1284/2493 fighters.
# Processed 1285/2493 fighters.
# Processed 1286/2493 fighters.
# Processed 1287/2493 fighters.
# Processed 1288/2493 fighters.
# Processed 1289/2493 fighters.
# Processed 1290/2493 fighters.
# Processed 1291/2493 fighters.
# Processed 1292/2493 fighters.
# Processed 1293/2493 fighters.
# Processed 1294/2493 fighters.
# Processed 1295/2493 fighters.
# Processed 1296/2493 fighters.
# Processed 1297/2493 fighters.
# Processed 1298/2493 fighters.
# Processed 1299/2493 fighters.
# Processed 1300/2493 fighters.
# Processed 1301/2493 fighters.
# Processed 1302/2493 fighters.
# Processed 1303/2493 fighters.
# Processed 1304/2493 fighters.
# Processed 1305/2493 fighters.
# Processed 1306/2493 fighters.
# Processed 1307/2493 fighters.
# Processed 1308/2493 fighters.
# Processed 1309/2493 fighters.
# Processed 1310/2493 fighters.
# Processed 1311/2493 fighters.
# Processed 1312/2493 fighters.
# Processed 1313/2493 fighters.
# Processed 1314/2493 fighters.
# Processed 1315/2493 fighters.
# Processed 1316/2493 fighters.
# Processed 1317/2493 fighters.
# Processed 1318/2493 fighters.
# Processed 1319/2493 fighters.
# Processed 1320/2493 fighters.
# Processed 1321/2493 fighters.
# Processed 1322/2493 fighters.
# Processed 1323/2493 fighters.
# Processed 1324/2493 fighters.
# Processed 1325/2493 fighters.
# Processed 1326/2493 fighters.
# Processed 1327/2493 fighters.
# Processed 1328/2493 fighters.
# Processed 1329/2493 fighters.
# Processed 1330/2493 fighters.
# Processed 1331/2493 fighters.
# Processed 1332/2493 fighters.
# Processed 1333/2493 fighters.
# Processed 1334/2493 fighters.
# Processed 1335/2493 fighters.
# Processed 1336/2493 fighters.
# Processed 1337/2493 fighters.
# Processed 1338/2493 fighters.
# Processed 1339/2493 fighters.
# Processed 1340/2493 fighters.
# Processed 1341/2493 fighters.
# Processed 1342/2493 fighters.
# Processed 1343/2493 fighters.
# Processed 1344/2493 fighters.
# Processed 1345/2493 fighters.
# Processed 1346/2493 fighters.
# Processed 1347/2493 fighters.
# Processed 1348/2493 fighters.
# Processed 1349/2493 fighters.
# Processed 1350/2493 fighters.
# Processed 1351/2493 fighters.
# Processed 1352/2493 fighters.
# Processed 1353/2493 fighters.
# Processed 1354/2493 fighters.
# Processed 1355/2493 fighters.
# Processed 1356/2493 fighters.
# Processed 1357/2493 fighters.
# Processed 1358/2493 fighters.
# Processed 1359/2493 fighters.
# Processed 1360/2493 fighters.
# Processed 1361/2493 fighters.
# Processed 1362/2493 fighters.
# Processed 1363/2493 fighters.
# Processed 1364/2493 fighters.
# Processed 1365/2493 fighters.
# Processed 1366/2493 fighters.
# Processed 1367/2493 fighters.
# Processed 1368/2493 fighters.
# Processed 1369/2493 fighters.
# Processed 1370/2493 fighters.
# Processed 1371/2493 fighters.
# Processed 1372/2493 fighters.
# Processed 1373/2493 fighters.
# Processed 1374/2493 fighters.
# Processed 1375/2493 fighters.
# Processed 1376/2493 fighters.
# Processed 1377/2493 fighters.
# Processed 1378/2493 fighters.
# Processed 1379/2493 fighters.
# Processed 1380/2493 fighters.
# Processed 1381/2493 fighters.
# Processed 1382/2493 fighters.
# Processed 1383/2493 fighters.
# Processed 1384/2493 fighters.
# Processed 1385/2493 fighters.
# Processed 1386/2493 fighters.
# Processed 1387/2493 fighters.
# Processed 1388/2493 fighters.
# Processed 1389/2493 fighters.
# Processed 1390/2493 fighters.
# Processed 1391/2493 fighters.
# Processed 1392/2493 fighters.
# Processed 1393/2493 fighters.
# Processed 1394/2493 fighters.
# Processed 1395/2493 fighters.
# Processed 1396/2493 fighters.
# Processed 1397/2493 fighters.
# Processed 1398/2493 fighters.
# Processed 1399/2493 fighters.
# Processed 1400/2493 fighters.
# Processed 1401/2493 fighters.
# Processed 1402/2493 fighters.
# Processed 1403/2493 fighters.
# Processed 1404/2493 fighters.
# Processed 1405/2493 fighters.
# Processed 1406/2493 fighters.
# Processed 1407/2493 fighters.
# Processed 1408/2493 fighters.
# Processed 1409/2493 fighters.
# Processed 1410/2493 fighters.
# Processed 1411/2493 fighters.
# Processed 1412/2493 fighters.
# Processed 1413/2493 fighters.
# Processed 1414/2493 fighters.
# Processed 1415/2493 fighters.
# Processed 1416/2493 fighters.
# Processed 1417/2493 fighters.
# Processed 1418/2493 fighters.
# Processed 1419/2493 fighters.
# Processed 1420/2493 fighters.
# Processed 1421/2493 fighters.
# Processed 1422/2493 fighters.
# Processed 1423/2493 fighters.
# Processed 1424/2493 fighters.
# Processed 1425/2493 fighters.
# Processed 1426/2493 fighters.
# Processed 1427/2493 fighters.
# Processed 1428/2493 fighters.
# Processed 1429/2493 fighters.
# Processed 1430/2493 fighters.
# Processed 1431/2493 fighters.
# Processed 1432/2493 fighters.
# Processed 1433/2493 fighters.
# Processed 1434/2493 fighters.
# Processed 1435/2493 fighters.
# Processed 1436/2493 fighters.
# Processed 1437/2493 fighters.
# Processed 1438/2493 fighters.
# Processed 1439/2493 fighters.
# Processed 1440/2493 fighters.
# Processed 1441/2493 fighters.
# Processed 1442/2493 fighters.
# Processed 1443/2493 fighters.
# Processed 1444/2493 fighters.
# Processed 1445/2493 fighters.
# Processed 1446/2493 fighters.
# Processed 1447/2493 fighters.
# Processed 1448/2493 fighters.
# Processed 1449/2493 fighters.
# Processed 1450/2493 fighters.
# Processed 1451/2493 fighters.
# Processed 1452/2493 fighters.
# Processed 1453/2493 fighters.
# Processed 1454/2493 fighters.
# Processed 1455/2493 fighters.
# Processed 1456/2493 fighters.
# Processed 1457/2493 fighters.
# Processed 1458/2493 fighters.
# Processed 1459/2493 fighters.
# Processed 1460/2493 fighters.
# Processed 1461/2493 fighters.
# Processed 1462/2493 fighters.
# Processed 1463/2493 fighters.
# Processed 1464/2493 fighters.
# Processed 1465/2493 fighters.
# Processed 1466/2493 fighters.
# Processed 1467/2493 fighters.
# Processed 1468/2493 fighters.
# Processed 1469/2493 fighters.
# Processed 1470/2493 fighters.
# Processed 1471/2493 fighters.
# Processed 1472/2493 fighters.
# Processed 1473/2493 fighters.
# Processed 1474/2493 fighters.
# Processed 1475/2493 fighters.
# Processed 1476/2493 fighters.
# Processed 1477/2493 fighters.
# Processed 1478/2493 fighters.
# Processed 1479/2493 fighters.
# Processed 1480/2493 fighters.
# Processed 1481/2493 fighters.
# Processed 1482/2493 fighters.
# Processed 1483/2493 fighters.
# Processed 1484/2493 fighters.
# Processed 1485/2493 fighters.
# Processed 1486/2493 fighters.
# Processed 1487/2493 fighters.
# Processed 1488/2493 fighters.
# Processed 1489/2493 fighters.
# Processed 1490/2493 fighters.
# Processed 1491/2493 fighters.
# Processed 1492/2493 fighters.
# Processed 1493/2493 fighters.
# Processed 1494/2493 fighters.
# Processed 1495/2493 fighters.
# Processed 1496/2493 fighters.
# Processed 1497/2493 fighters.
# Processed 1498/2493 fighters.
# Processed 1499/2493 fighters.
# Processed 1500/2493 fighters.
# Processed 1501/2493 fighters.
# Processed 1502/2493 fighters.
# Processed 1503/2493 fighters.
# Processed 1504/2493 fighters.
# Processed 1505/2493 fighters.
# Processed 1506/2493 fighters.
# Processed 1507/2493 fighters.
# Processed 1508/2493 fighters.
# Processed 1509/2493 fighters.
# Processed 1510/2493 fighters.
# Processed 1511/2493 fighters.
# Processed 1512/2493 fighters.
# Processed 1513/2493 fighters.
# Processed 1514/2493 fighters.
# Processed 1515/2493 fighters.
# Processed 1516/2493 fighters.
# Processed 1517/2493 fighters.
# Processed 1518/2493 fighters.
# Processed 1519/2493 fighters.
# Processed 1520/2493 fighters.
# Processed 1521/2493 fighters.
# Processed 1522/2493 fighters.
# Processed 1523/2493 fighters.
# Processed 1524/2493 fighters.
# Processed 1525/2493 fighters.
# Processed 1526/2493 fighters.
# Processed 1527/2493 fighters.
# Processed 1528/2493 fighters.
# Processed 1529/2493 fighters.
# Processed 1530/2493 fighters.
# Processed 1531/2493 fighters.
# Processed 1532/2493 fighters.
# Processed 1533/2493 fighters.
# Processed 1534/2493 fighters.
# Processed 1535/2493 fighters.
# Processed 1536/2493 fighters.
# Processed 1537/2493 fighters.
# Processed 1538/2493 fighters.
# Processed 1539/2493 fighters.
# Processed 1540/2493 fighters.
# Processed 1541/2493 fighters.
# Processed 1542/2493 fighters.
# Processed 1543/2493 fighters.
# Processed 1544/2493 fighters.
# Processed 1545/2493 fighters.
# Processed 1546/2493 fighters.
# Processed 1547/2493 fighters.
# Processed 1548/2493 fighters.
# Processed 1549/2493 fighters.
# Processed 1550/2493 fighters.
# Processed 1551/2493 fighters.
# Processed 1552/2493 fighters.
# Processed 1553/2493 fighters.
# Processed 1554/2493 fighters.
# Processed 1555/2493 fighters.
# Processed 1556/2493 fighters.
# Processed 1557/2493 fighters.
# Processed 1558/2493 fighters.
# Processed 1559/2493 fighters.
# Processed 1560/2493 fighters.
# Processed 1561/2493 fighters.
# Processed 1562/2493 fighters.
# Processed 1563/2493 fighters.
# Processed 1564/2493 fighters.
# Processed 1565/2493 fighters.
# Processed 1566/2493 fighters.
# Processed 1567/2493 fighters.
# Processed 1568/2493 fighters.
# Processed 1569/2493 fighters.
# Processed 1570/2493 fighters.
# Processed 1571/2493 fighters.
# Processed 1572/2493 fighters.
# Processed 1573/2493 fighters.
# Processed 1574/2493 fighters.
# Processed 1575/2493 fighters.
# Processed 1576/2493 fighters.
# Processed 1577/2493 fighters.
# Processed 1578/2493 fighters.
# Processed 1579/2493 fighters.
# Processed 1580/2493 fighters.
# Processed 1581/2493 fighters.
# Processed 1582/2493 fighters.
# Processed 1583/2493 fighters.
# Processed 1584/2493 fighters.
# Processed 1585/2493 fighters.
# Processed 1586/2493 fighters.
# Processed 1587/2493 fighters.
# Processed 1588/2493 fighters.
# Processed 1589/2493 fighters.
# Processed 1590/2493 fighters.
# Processed 1591/2493 fighters.
# Processed 1592/2493 fighters.
# Processed 1593/2493 fighters.
# Processed 1594/2493 fighters.
# Processed 1595/2493 fighters.
# Processed 1596/2493 fighters.
# Processed 1597/2493 fighters.
# Processed 1598/2493 fighters.
# Processed 1599/2493 fighters.
# Processed 1600/2493 fighters.
# Processed 1601/2493 fighters.
# Processed 1602/2493 fighters.
# Processed 1603/2493 fighters.
# Processed 1604/2493 fighters.
# Processed 1605/2493 fighters.
# Processed 1606/2493 fighters.
# Processed 1607/2493 fighters.
# Processed 1608/2493 fighters.
# Processed 1609/2493 fighters.
# Processed 1610/2493 fighters.
# Processed 1611/2493 fighters.
# Processed 1612/2493 fighters.
# Processed 1613/2493 fighters.
# Processed 1614/2493 fighters.
# Processed 1615/2493 fighters.
# Processed 1616/2493 fighters.
# Processed 1617/2493 fighters.
# Processed 1618/2493 fighters.
# Processed 1619/2493 fighters.
# Processed 1620/2493 fighters.
# Processed 1621/2493 fighters.
# Processed 1622/2493 fighters.
# Processed 1623/2493 fighters.
# Processed 1624/2493 fighters.
# Processed 1625/2493 fighters.
# Processed 1626/2493 fighters.
# Processed 1627/2493 fighters.
# Processed 1628/2493 fighters.
# Processed 1629/2493 fighters.
# Processed 1630/2493 fighters.
# Processed 1631/2493 fighters.
# Processed 1632/2493 fighters.
# Processed 1633/2493 fighters.
# Processed 1634/2493 fighters.
# Processed 1635/2493 fighters.
# Processed 1636/2493 fighters.
# ...
# Processed 1961/2493 fighters.
# Processed 1962/2493 fighters.
# Processed 1963/2493 fighters.
# Processed 1964/2493 fighters.
# Processed 1965/2493 fighters.
# Processed 1966/2493 fighters.
# Processed 1967/2493 fighters.
# Processed 1968/2493 fighters.
# Processed 1969/2493 fighters.
# Processed 1970/2493 fighters.
# Processed 1971/2493 fighters.
# Processed 1972/2493 fighters.
# Processed 1973/2493 fighters.
# Processed 1974/2493 fighters.
# Processed 1975/2493 fighters.
# Processed 1976/2493 fighters.
# Processed 1977/2493 fighters.
# Processed 1978/2493 fighters.
# Processed 1979/2493 fighters.
# Processed 1980/2493 fighters.
# Processed 1981/2493 fighters.
# Processed 1982/2493 fighters.
# Processed 1983/2493 fighters.
# Processed 1984/2493 fighters.
# Processed 1985/2493 fighters.
# Processed 1986/2493 fighters.
# Processed 1987/2493 fighters.
# Processed 1988/2493 fighters.
# Processed 1989/2493 fighters.
# Processed 1990/2493 fighters.
# Processed 1991/2493 fighters.
# Processed 1992/2493 fighters.
# Processed 1993/2493 fighters.
# Processed 1994/2493 fighters.
# Processed 1995/2493 fighters.
# Processed 1996/2493 fighters.
# Processed 1997/2493 fighters.
# Processed 1998/2493 fighters.
# Processed 1999/2493 fighters.
# Processed 2000/2493 fighters.
# Processed 2001/2493 fighters.
# Processed 2002/2493 fighters.
# Processed 2003/2493 fighters.
# Processed 2004/2493 fighters.
# Processed 2005/2493 fighters.
# Processed 2006/2493 fighters.
# Processed 2007/2493 fighters.
# Processed 2008/2493 fighters.
# Processed 2009/2493 fighters.
# Processed 2010/2493 fighters.
# Processed 2011/2493 fighters.
# Processed 2012/2493 fighters.
# Processed 2013/2493 fighters.
# Processed 2014/2493 fighters.
# Processed 2015/2493 fighters.
# Processed 2016/2493 fighters.
# Processed 2017/2493 fighters.
# Processed 2018/2493 fighters.
# Processed 2019/2493 fighters.
# Processed 2020/2493 fighters.
# Processed 2021/2493 fighters.
# Processed 2022/2493 fighters.
# Processed 2023/2493 fighters.
# Processed 2024/2493 fighters.
# Processed 2025/2493 fighters.
# Processed 2026/2493 fighters.
# Processed 2027/2493 fighters.
# Processed 2028/2493 fighters.
# Processed 2029/2493 fighters.
# Processed 2030/2493 fighters.
# Processed 2031/2493 fighters.
# Processed 2032/2493 fighters.
# Processed 2033/2493 fighters.
# Processed 2034/2493 fighters.
# Processed 2035/2493 fighters.
# Processed 2036/2493 fighters.
# Processed 2037/2493 fighters.
# Processed 2038/2493 fighters.
# Processed 2039/2493 fighters.
# Processed 2040/2493 fighters.
# Processed 2041/2493 fighters.
# Processed 2042/2493 fighters.
# Processed 2043/2493 fighters.
# Processed 2044/2493 fighters.
# Processed 2045/2493 fighters.
# Processed 2046/2493 fighters.
# Processed 2047/2493 fighters.
# Processed 2048/2493 fighters.
# Processed 2049/2493 fighters.
# Processed 2050/2493 fighters.
# Processed 2051/2493 fighters.
# Processed 2052/2493 fighters.
# Processed 2053/2493 fighters.
# Processed 2054/2493 fighters.
# Processed 2055/2493 fighters.
# Processed 2056/2493 fighters.
# Processed 2057/2493 fighters.
# Processed 2058/2493 fighters.
# Processed 2059/2493 fighters.
# Processed 2060/2493 fighters.
# Processed 2061/2493 fighters.
# Processed 2062/2493 fighters.
# Processed 2063/2493 fighters.
# Processed 2064/2493 fighters.
# Processed 2065/2493 fighters.
# Processed 2066/2493 fighters.
# Processed 2067/2493 fighters.
# Processed 2068/2493 fighters.
# Processed 2069/2493 fighters.
# Processed 2070/2493 fighters.
# Processed 2071/2493 fighters.
# Processed 2072/2493 fighters.
# Processed 2073/2493 fighters.
# Processed 2074/2493 fighters.
# Processed 2075/2493 fighters.
# Processed 2076/2493 fighters.
# Processed 2077/2493 fighters.
# Processed 2078/2493 fighters.
# Processed 2079/2493 fighters.
# Processed 2080/2493 fighters.
# Processed 2081/2493 fighters.
# Processed 2082/2493 fighters.
# Processed 2083/2493 fighters.
# Processed 2084/2493 fighters.
# Processed 2085/2493 fighters.
# Processed 2086/2493 fighters.
# Processed 2087/2493 fighters.
# Processed 2088/2493 fighters.
# Processed 2089/2493 fighters.
# Processed 2090/2493 fighters.
# Processed 2091/2493 fighters.
# Processed 2092/2493 fighters.
# Processed 2093/2493 fighters.
# Processed 2094/2493 fighters.
# Processed 2095/2493 fighters.
# Processed 2096/2493 fighters.
# Processed 2097/2493 fighters.
# Processed 2098/2493 fighters.
# Processed 2099/2493 fighters.
# Processed 2100/2493 fighters.
# Processed 2101/2493 fighters.
# Processed 2102/2493 fighters.
# Processed 2103/2493 fighters.
# Processed 2104/2493 fighters.
# Processed 2105/2493 fighters.
# Processed 2106/2493 fighters.
# Processed 2107/2493 fighters.
# Processed 2108/2493 fighters.
# Processed 2109/2493 fighters.
# Processed 2110/2493 fighters.
# Processed 2111/2493 fighters.
# Processed 2112/2493 fighters.
# Processed 2113/2493 fighters.
# Processed 2114/2493 fighters.
# Processed 2115/2493 fighters.
# Processed 2116/2493 fighters.
# Processed 2117/2493 fighters.
# Processed 2118/2493 fighters.
# Processed 2119/2493 fighters.
# Processed 2120/2493 fighters.
# Processed 2121/2493 fighters.
# Processed 2122/2493 fighters.
# Processed 2123/2493 fighters.
# Processed 2124/2493 fighters.
# Processed 2125/2493 fighters.
# Processed 2126/2493 fighters.
# Processed 2127/2493 fighters.
# Processed 2128/2493 fighters.
# Processed 2129/2493 fighters.
# Processed 2130/2493 fighters.
# Processed 2131/2493 fighters.
# Processed 2132/2493 fighters.
# Processed 2133/2493 fighters.
# Processed 2134/2493 fighters.
# Processed 2135/2493 fighters.
# Processed 2136/2493 fighters.
# Processed 2137/2493 fighters.
# Processed 2138/2493 fighters.
# Processed 2139/2493 fighters.
# Processed 2140/2493 fighters.
# Processed 2141/2493 fighters.
# Processed 2142/2493 fighters.
# Processed 2143/2493 fighters.
# Processed 2144/2493 fighters.
# Processed 2145/2493 fighters.
# Processed 2146/2493 fighters.
# Processed 2147/2493 fighters.
# Processed 2148/2493 fighters.
# Processed 2149/2493 fighters.
# Processed 2150/2493 fighters.
# Processed 2151/2493 fighters.
# Processed 2152/2493 fighters.
# Processed 2153/2493 fighters.
# Processed 2154/2493 fighters.
# Processed 2155/2493 fighters.
# Processed 2156/2493 fighters.
# Processed 2157/2493 fighters.
# Processed 2158/2493 fighters.
# Processed 2159/2493 fighters.
# Processed 2160/2493 fighters.
# Processed 2161/2493 fighters.
# Processed 2162/2493 fighters.
# Processed 2163/2493 fighters.
# Processed 2164/2493 fighters.
# Processed 2165/2493 fighters.
# Processed 2166/2493 fighters.
# Processed 2167/2493 fighters.
# Processed 2168/2493 fighters.
# Processed 2169/2493 fighters.
# Processed 2170/2493 fighters.
# Processed 2171/2493 fighters.
# Processed 2172/2493 fighters.
# Processed 2173/2493 fighters.
# Processed 2174/2493 fighters.
# Processed 2175/2493 fighters.
# Processed 2176/2493 fighters.
# Processed 2177/2493 fighters.
# Processed 2178/2493 fighters.
# Processed 2179/2493 fighters.
# Processed 2180/2493 fighters.
# Processed 2181/2493 fighters.
# Processed 2182/2493 fighters.
# Processed 2183/2493 fighters.
# Processed 2184/2493 fighters.
# Processed 2185/2493 fighters.
# Processed 2186/2493 fighters.
# Processed 2187/2493 fighters.
# Processed 2188/2493 fighters.
# Processed 2189/2493 fighters.
# Processed 2190/2493 fighters.
# Processed 2191/2493 fighters.
# Processed 2192/2493 fighters.
# Processed 2193/2493 fighters.
# Processed 2194/2493 fighters.
# Processed 2195/2493 fighters.
# Processed 2196/2493 fighters.
# Processed 2197/2493 fighters.
# Processed 2198/2493 fighters.
# Processed 2199/2493 fighters.
# Processed 2200/2493 fighters.
# Processed 2201/2493 fighters.
# Processed 2202/2493 fighters.
# Processed 2203/2493 fighters.
# Processed 2204/2493 fighters.
# Processed 2205/2493 fighters.
# Processed 2206/2493 fighters.
# Processed 2207/2493 fighters.
# Processed 2208/2493 fighters.
# Processed 2209/2493 fighters.
# Processed 2210/2493 fighters.
# Processed 2211/2493 fighters.
# Processed 2212/2493 fighters.
# Processed 2213/2493 fighters.
# Processed 2214/2493 fighters.
# Processed 2215/2493 fighters.
# Processed 2216/2493 fighters.
# Processed 2217/2493 fighters.
# Processed 2218/2493 fighters.
# Processed 2219/2493 fighters.
# Processed 2220/2493 fighters.
# Processed 2221/2493 fighters.
# Processed 2222/2493 fighters.
# Processed 2223/2493 fighters.
# Processed 2224/2493 fighters.
# Processed 2225/2493 fighters.
# Processed 2226/2493 fighters.
# Processed 2227/2493 fighters.
# Processed 2228/2493 fighters.
# Processed 2229/2493 fighters.
# Processed 2230/2493 fighters.
# Processed 2231/2493 fighters.
# Processed 2232/2493 fighters.
# Processed 2233/2493 fighters.
# Processed 2234/2493 fighters.
# Processed 2235/2493 fighters.
# Processed 2236/2493 fighters.
# Processed 2237/2493 fighters.
# Processed 2238/2493 fighters.
# Processed 2239/2493 fighters.
# Processed 2240/2493 fighters.
# Processed 2241/2493 fighters.
# Processed 2242/2493 fighters.
# Processed 2243/2493 fighters.
# Processed 2244/2493 fighters.
# Processed 2245/2493 fighters.
# Processed 2246/2493 fighters.
# Processed 2247/2493 fighters.
# Processed 2248/2493 fighters.
# Processed 2249/2493 fighters.
# Processed 2250/2493 fighters.
# Processed 2251/2493 fighters.
# Processed 2252/2493 fighters.
# Processed 2253/2493 fighters.
# Processed 2254/2493 fighters.
# Processed 2255/2493 fighters.
# Processed 2256/2493 fighters.
# Processed 2257/2493 fighters.
# Processed 2258/2493 fighters.
# Processed 2259/2493 fighters.
# Processed 2260/2493 fighters.
# Processed 2261/2493 fighters.
# Processed 2262/2493 fighters.
# Processed 2263/2493 fighters.
# Processed 2264/2493 fighters.
# Processed 2265/2493 fighters.
# Processed 2266/2493 fighters.
# Processed 2267/2493 fighters.
# Processed 2268/2493 fighters.
# Processed 2269/2493 fighters.
# Processed 2270/2493 fighters.
# Processed 2271/2493 fighters.
# Processed 2272/2493 fighters.
# Processed 2273/2493 fighters.
# Processed 2274/2493 fighters.
# Processed 2275/2493 fighters.
# Processed 2276/2493 fighters.
# Processed 2277/2493 fighters.
# Processed 2278/2493 fighters.
# Processed 2279/2493 fighters.
# Processed 2280/2493 fighters.
# Processed 2281/2493 fighters.
# Processed 2282/2493 fighters.
# Processed 2283/2493 fighters.
# Processed 2284/2493 fighters.
# Processed 2285/2493 fighters.
# Processed 2286/2493 fighters.
# Processed 2287/2493 fighters.
# Processed 2288/2493 fighters.
# Processed 2289/2493 fighters.
# Processed 2290/2493 fighters.
# Processed 2291/2493 fighters.
# Processed 2292/2493 fighters.
# Processed 2293/2493 fighters.
# Processed 2294/2493 fighters.
# Processed 2295/2493 fighters.
# Processed 2296/2493 fighters.
# Processed 2297/2493 fighters.
# Processed 2298/2493 fighters.
# Processed 2299/2493 fighters.
# Processed 2300/2493 fighters.
# Processed 2301/2493 fighters.
# Processed 2302/2493 fighters.
# Processed 2303/2493 fighters.
# Processed 2304/2493 fighters.
# Processed 2305/2493 fighters.
# Processed 2306/2493 fighters.
# Processed 2307/2493 fighters.
# Processed 2308/2493 fighters.
# Processed 2309/2493 fighters.
# Processed 2310/2493 fighters.
# Processed 2311/2493 fighters.
# Processed 2312/2493 fighters.
# Processed 2313/2493 fighters.
# Processed 2314/2493 fighters.
# Processed 2315/2493 fighters.
# Processed 2316/2493 fighters.
# Processed 2317/2493 fighters.
# Processed 2318/2493 fighters.
# Processed 2319/2493 fighters.
# Processed 2320/2493 fighters.
# Processed 2321/2493 fighters.
# Processed 2322/2493 fighters.
# Processed 2323/2493 fighters.
# Processed 2324/2493 fighters.
# Processed 2325/2493 fighters.
# Processed 2326/2493 fighters.
# Processed 2327/2493 fighters.
# Processed 2328/2493 fighters.
# Processed 2329/2493 fighters.
# Processed 2330/2493 fighters.
# Processed 2331/2493 fighters.
# Processed 2332/2493 fighters.
# Processed 2333/2493 fighters.
# Processed 2334/2493 fighters.
# Processed 2335/2493 fighters.
# Processed 2336/2493 fighters.
# Processed 2337/2493 fighters.
# Processed 2338/2493 fighters.
# Processed 2339/2493 fighters.
# Processed 2340/2493 fighters.
# Processed 2341/2493 fighters.
# Processed 2342/2493 fighters.
# Processed 2343/2493 fighters.
# Processed 2344/2493 fighters.
# Processed 2345/2493 fighters.
# Processed 2346/2493 fighters.
# Processed 2347/2493 fighters.
# Processed 2348/2493 fighters.
# Processed 2349/2493 fighters.
# Processed 2350/2493 fighters.
# Processed 2351/2493 fighters.
# Processed 2352/2493 fighters.
# Processed 2353/2493 fighters.
# Processed 2354/2493 fighters.
# Processed 2355/2493 fighters.
# Processed 2356/2493 fighters.
# Processed 2357/2493 fighters.
# Processed 2358/2493 fighters.
# Processed 2359/2493 fighters.
# Processed 2360/2493 fighters.
# Processed 2361/2493 fighters.
# Processed 2362/2493 fighters.
# Processed 2363/2493 fighters.
# Processed 2364/2493 fighters.
# Processed 2365/2493 fighters.
# Processed 2366/2493 fighters.
# Processed 2367/2493 fighters.
# Processed 2368/2493 fighters.
# Processed 2369/2493 fighters.
# Processed 2370/2493 fighters.
# Processed 2371/2493 fighters.
# Processed 2372/2493 fighters.
# Processed 2373/2493 fighters.
# Processed 2374/2493 fighters.
# Processed 2375/2493 fighters.
# Processed 2376/2493 fighters.
# Processed 2377/2493 fighters.
# Processed 2378/2493 fighters.
# Processed 2379/2493 fighters.
# Processed 2380/2493 fighters.
# Processed 2381/2493 fighters.
# Processed 2382/2493 fighters.
# Processed 2383/2493 fighters.
# Processed 2384/2493 fighters.
# Processed 2385/2493 fighters.
# Processed 2386/2493 fighters.
# Processed 2387/2493 fighters.
# Processed 2388/2493 fighters.
# Processed 2389/2493 fighters.
# Processed 2390/2493 fighters.
# Processed 2391/2493 fighters.
# Processed 2392/2493 fighters.
# Processed 2393/2493 fighters.
# Processed 2394/2493 fighters.
# Processed 2395/2493 fighters.
# Processed 2396/2493 fighters.
# Processed 2397/2493 fighters.
# Processed 2398/2493 fighters.
# Processed 2399/2493 fighters.
# Processed 2400/2493 fighters.
# Processed 2401/2493 fighters.
# Processed 2402/2493 fighters.
# Processed 2403/2493 fighters.
# Processed 2404/2493 fighters.
# Processed 2405/2493 fighters.
# Processed 2406/2493 fighters.
# Processed 2407/2493 fighters.
# Processed 2408/2493 fighters.
# Processed 2409/2493 fighters.
# Processed 2410/2493 fighters.
# Processed 2411/2493 fighters.
# Processed 2412/2493 fighters.
# Processed 2413/2493 fighters.
# Processed 2414/2493 fighters.
# Processed 2415/2493 fighters.
# Processed 2416/2493 fighters.
# Processed 2417/2493 fighters.
# Processed 2418/2493 fighters.
# Processed 2419/2493 fighters.
# Processed 2420/2493 fighters.
# Processed 2421/2493 fighters.
# Processed 2422/2493 fighters.
# Processed 2423/2493 fighters.
# Processed 2424/2493 fighters.
# Processed 2425/2493 fighters.
# Processed 2426/2493 fighters.
# Processed 2427/2493 fighters.
# Processed 2428/2493 fighters.
# Processed 2429/2493 fighters.
# Processed 2430/2493 fighters.
# Processed 2431/2493 fighters.
# Processed 2432/2493 fighters.
# Processed 2433/2493 fighters.
# Processed 2434/2493 fighters.
# Processed 2435/2493 fighters.
# Processed 2436/2493 fighters.
# Processed 2437/2493 fighters.
# Processed 2438/2493 fighters.
# Processed 2439/2493 fighters.
# Processed 2440/2493 fighters.
# Processed 2441/2493 fighters.
# Processed 2442/2493 fighters.
# Processed 2443/2493 fighters.
# Processed 2444/2493 fighters.
# Processed 2445/2493 fighters.
# Processed 2446/2493 fighters.
# Processed 2447/2493 fighters.
# Processed 2448/2493 fighters.
# Processed 2449/2493 fighters.
# Processed 2450/2493 fighters.
# Processed 2451/2493 fighters.
# Processed 2452/2493 fighters.
# Processed 2453/2493 fighters.
# Processed 2454/2493 fighters.
# Processed 2455/2493 fighters.
# Processed 2456/2493 fighters.
# Processed 2457/2493 fighters.
# Processed 2458/2493 fighters.
# Processed 2459/2493 fighters.
# Processed 2460/2493 fighters.
# Processed 2461/2493 fighters.
# Processed 2462/2493 fighters.
# Processed 2463/2493 fighters.
# Processed 2464/2493 fighters.
# Processed 2465/2493 fighters.
# Processed 2466/2493 fighters.
# Processed 2467/2493 fighters.
# Processed 2468/2493 fighters.
# Processed 2469/2493 fighters.
# Processed 2470/2493 fighters.
# Processed 2471/2493 fighters.
# Processed 2472/2493 fighters.
# Processed 2473/2493 fighters.
# Processed 2474/2493 fighters.
# Processed 2475/2493 fighters.
# Processed 2476/2493 fighters.
# Processed 2477/2493 fighters.
# Processed 2478/2493 fighters.
# Processed 2479/2493 fighters.
# Processed 2480/2493 fighters.
# Processed 2481/2493 fighters.
# Processed 2482/2493 fighters.
# Processed 2483/2493 fighters.
# Processed 2484/2493 fighters.
# Processed 2485/2493 fighters.
# Processed 2486/2493 fighters.
# Processed 2487/2493 fighters.
# Processed 2488/2493 fighters.
# Processed 2489/2493 fighters.
# Processed 2490/2493 fighters.
# Processed 2491/2493 fighters.
# Processed 2492/2493 fighters.
# Processed 2493/2493 fighters.

# %%
directory_path = './data-raw/fighters/'

for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):  # Check if the file is a CSV
        file_path = os.path.join(directory_path, filename)
        df = pd.read_csv(file_path)
        df = df.map(lambda x: x.strip() if isinstance(x, str) else x)
        df.to_csv(file_path, index=False)

# %%
first_name = "Dustin"
last_name = "Poirier"

# Adjust the pattern to match files containing both the first name and the last name
file_pattern = f'./data-raw/fighters/*{first_name}*{last_name}*.csv'

# Use glob to find files that match the updated pattern
matching_files = glob.glob(file_pattern)

if matching_files:
    first_file = matching_files[0]
    df = pd.read_csv(first_file)
    
    print(f"Total number of rows including the header in {first_file}: {len(df)}")
    print(f"Column names: {list(df.columns)}")
else:
    print("No files found matching the pattern.")
# Out:
# Total number of rows including the header in ./data-raw/fighters/Dustin_Poirier_50529.csv: 40
# Column names: ['Result', 'Opponent', 'Event Date', 'Method/Referee', 'Rounds', 'Time']

# %%
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')
print(f"Number of rows in fighter_info.csv: {len(fighter_info_df)}")
# Out:
# Number of rows in fighter_info.csv: 2492

# %% [markdown]
# # Cleaning

# %%
### START GOOD ###

# %%
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')
print(f"Number of rows in fighter_info.csv: {len(fighter_info_df)}")
# Out:
# Number of rows in fighter_info.csv: 2492

# %%
# Removing women's fights and fighters

womens_weight_classes = ['Strawweight'] # 'Flyweight', 'Bantamweight', 'Featherweight'
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')
cleaned_fighter_info_df = fighter_info_df[~fighter_info_df['Weight Class'].isin(womens_weight_classes)]
cleaned_fighter_info_df.to_csv('./data-raw/fighter_info.csv', index=False)
print(f"Cleaned dataset saved to {'./data-raw/fighter_info.csv'}")
# Out:
# Cleaned dataset saved to ./data-raw/fighter_info.csv

# %%
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')
print(f"Number of rows in fighter_info.csv: {len(fighter_info_df)}")
# Out:
# Number of rows in fighter_info.csv: 2399

# %%
### START GIT ###

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os
import csv
import warnings
import re
import sqlite3

os.makedirs('./data/github/', exist_ok=True)
os.makedirs('./data/github/fighter-details', exist_ok=True)

urls = [
    'https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/ufc_event_details.csv',
    'https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/ufc_fight_details.csv',
    'https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/ufc_fight_results.csv',
    'https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/ufc_fight_stats.csv',
    'https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/ufc_fighter_details.csv',
    'https://raw.githubusercontent.com/Greco1899/scrape_ufc_stats/main/ufc_fighter_tott.csv'
]

for url in urls:
    df = pd.read_csv(url)
    df = df.map(lambda x: x.strip() if isinstance(x, str) else x)
    df.to_csv('./data/github/' + url.split('/')[-1], index=False)
    
# Merge the DATE and LOCATION of every fight

event_details_df = pd.read_csv('./data/github/ufc_event_details.csv')
fight_results_df = pd.read_csv('./data/github/ufc_fight_results.csv')

# Set the 'EVENT' column as index in the event details DataFrame for easier merging
event_details_df_for_merge = event_details_df.set_index('EVENT')

# Merge 'DATE' and 'LOCATION' from event details into fight results DataFrame based on 'EVENT'
merged_df = fight_results_df.join(event_details_df_for_merge[['DATE', 'LOCATION']], on='EVENT')

merged_df.to_csv('./data/github/master.csv', index=False)

# Create FIGHTER1, FIGHTER2, and WINNING_FIGHTER columns

fight_results_df = pd.read_csv('./data/github/master.csv')

# Split the 'BOUT' column into two new columns 'Fighter1' and 'Fighter2'
fight_results_df[['FIGHTER1', 'FIGHTER2']] = fight_results_df['BOUT'].str.split(' vs. ', expand=True)

# Use a multiline lambda within apply for readability without an external function
fight_results_df['WINNING_FIGHTER'] = fight_results_df.apply(
    lambda row: row['FIGHTER1'].strip() if row['OUTCOME'] == 'W/L' else
                (row['FIGHTER2'].strip() if row['OUTCOME'] == 'L/W' else
                 ('No Contest' if row['OUTCOME'] == 'NC/NC' else
                  ('Draw' if row['OUTCOME'] == 'D/D' else 'Unknown Outcome'))),
    axis=1
)

fight_results_df.to_csv('./data/github/master.csv', index=False)

# Load the latest master.csv file into a DataFrame
latest_master_df = pd.read_csv('./data/github/master.csv')

# Clean leading and trailing whitespace in FIGHTER1 and FIGHTER2 columns
latest_master_df['FIGHTER1'] = latest_master_df['FIGHTER1'].str.strip()
latest_master_df['FIGHTER2'] = latest_master_df['FIGHTER2'].str.strip()

# Create an SQLite database connection in a writable location
conn = sqlite3.connect('ufc_database.db')
cursor = conn.cursor()

# Create the fight_results table
create_table_query = """
CREATE TABLE IF NOT EXISTS fight_results (
    EVENT TEXT,
    BOUT TEXT,
    OUTCOME TEXT,
    WEIGHTCLASS TEXT,
    METHOD TEXT,
    ROUND INTEGER,
    TIME TEXT,
    TIME_FORMAT TEXT,
    REFEREE TEXT,
    DETAILS TEXT,
    URL TEXT,
    DATE TEXT,
    LOCATION TEXT,
    FIGHTER1 TEXT,
    FIGHTER2 TEXT,
    WINNING_FIGHTER TEXT
)
"""
cursor.execute(create_table_query)
conn.commit()

# Insert data into the fight_results table
latest_master_df.to_sql('fight_results', conn, if_exists='replace', index=False)

# Verify the data insertion
result = cursor.execute("SELECT COUNT(*) FROM fight_results").fetchone()[0]

# Close the connection
conn.close()

result
# Out:
# 7692

# %%
### END GIT ###

# %%
# Remove white spaces and special characters

import re
import pandas as pd

# Load the datasets
master_df = pd.read_csv('./data/github/master.csv')
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')

# Remove leading/trailing whitespace, special characters, and normalize to lowercase
fighter_info_df['Fighter'] = fighter_info_df['Fighter'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)
master_df['FIGHTER1'] = master_df['FIGHTER1'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)
master_df['FIGHTER2'] = master_df['FIGHTER2'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)

# Save the cleaned datasets back to their original files
master_df.to_csv('./data/github/master.csv', index=False)
fighter_info_df.to_csv('./data-raw/fighter_info.csv', index=False)

print("Whitespace and special characters removed, and cleaned datasets saved.")
# Out:
# Whitespace and special characters removed, and cleaned datasets saved.

# %%
# Cleaning more women's names from git data

master_df = pd.read_csv('./data/github/master.csv')
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')

womens_fights_master = master_df[master_df['WEIGHTCLASS'].str.contains('Women', case=False, na=False)]
female_fighters = set(womens_fights_master['FIGHTER1']).union(set(womens_fights_master['FIGHTER2']))
cleaned_fighter_info_df = fighter_info_df[~fighter_info_df['Fighter'].isin(female_fighters)]
cleaned_fighter_info_df.to_csv('./data-raw/fighter_info.csv', index=False)

print(f"Cleaned dataset saved to ./data-raw/fighter_info.csv")
# Out:
# Cleaned dataset saved to ./data-raw/fighter_info.csv

# %%
fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')
print(f"Number of rows in fighter_info.csv: {len(fighter_info_df)}")
# Out:
# Number of rows in fighter_info.csv: 2249

# %%
# Remove womens fight rows from master.csv (CANT DO BEFORE USING THEM FOR FIGHTER_INFO.CSV)

import pandas as pd

# Load the master dataset
master_df = pd.read_csv('./data/github/master.csv')

# Print the number of rows before removing women's fights
print(f"Number of rows before: {len(master_df)}")

# Filter out rows corresponding to women's fights
cleaned_master_df = master_df[~master_df['WEIGHTCLASS'].str.contains('Women', case=False, na=False)]

# Print the number of rows before removing women's fights
print(f"Number of rows before: {len(cleaned_master_df)}")

# Save the cleaned dataset back to the original file
cleaned_master_df.to_csv('./data/github/master.csv', index=False)

print("Women's fights removed, and cleaned master.csv saved.")
# Out:
# Number of rows before: 7692
# Number of rows before: 6930
# Women's fights removed, and cleaned master.csv saved.

# %%
# Remove fights from before 2015 in master.csv

import pandas as pd

# Load the master dataset
master_df = pd.read_csv('./data/github/master.csv')

# Convert the DATE column to datetime
master_df['DATE'] = pd.to_datetime(master_df['DATE'], errors='coerce')

# Filter out rows with events before 2010
cleaned_master_df = master_df[master_df['DATE'] >= '2005-01-01']

# Save the cleaned dataset back to the original file
cleaned_master_df.to_csv('./data/github/master.csv', index=False)

print("Rows with events before 2010 removed, and cleaned master.csv saved.")
# Out:
# Rows with events before 2010 removed, and cleaned master.csv saved.

# %%
# Remove all TUF rows from master.csv

import pandas as pd

# Load the dataset
master_df = pd.read_csv('./data/github/master.csv')

# Print the number of rows before removing women's fights
print(f"Number of rows before: {len(master_df)}")

# Remove rows where the EVENT column contains 'Ultimate Fighter' or 'TUF'
filtered_df = master_df[~master_df['WEIGHTCLASS'].str.contains('Ultimate Fighter|TUF', case=False, na=False)]

# Print the number of rows before removing women's fights
print(f"Number of rows before: {len(filtered_df)}")

# Save the filtered DataFrame to a new CSV file
filtered_df.to_csv('./data/github/master.csv', index=False)
# Out:
# Number of rows before: 6490
# Number of rows before: 6438

# %%
# # RESEARCH MANUALLY IF ANY TUF SEASONS WERE WOMENS #

# Ultimate Fighter 28 Heavyweight Tournament Title Bout
# Ultimate Fighter 27 Lightweight Tournament Title Bout
# Ultimate Fighter 27 Featherweight Tournament Title Bout
# UFC Interim Welterweight Title Bout
# Ultimate Fighter 25 Welterweight Tournament Title Bout
# Ultimate Fighter Latin America 3 Lightweight Tournament Title Bout
# Ultimate Fighter 23 Light Heavyweight Tournament Title Bout
# UFC Interim Light Heavyweight Title Bout
# Ultimate Fighter 22 Lightweight Tournament Title Bout
# Ultimate Fighter Latin America 2 Welterweight Tournament Title Bout
# Ultimate Fighter Latin America 2 Lightweight Tournament Title Bout
# Ultimate Fighter Brazil 4 Lightweight Tournament Title Bout
# Ultimate Fighter Brazil 4 Bantamweight Tournament Title Bout
# Ultimate Fighter 21 Welterweight Tournament Title Bout
# Ultimate Fighter Latin America Featherweight Tournament Title Bout
# Ultimate Fighter Latin America Bantamweight Tournament Title Bout
# Ultimate Fighter China Featherweight Tournament Title Bout
# Ultimate Fighter 19 Light Heavyweight Tournament Title Bout
# Ultimate Fighter 19 Middleweight Tournament Title Bout
# Ultimate Fighter 18 Bantamweight Tournament Title Bout
# Ultimate Fighter Brazil 2 Welterweight Tournament Title Bout
# Ultimate Fighter 17 Middleweight Tournament Title Bout
# Ultimate Fighter 16 Welterweight Tournament Title Bout
# Ultimate Fighter Australia vs. UK Welterweight Tournament Title Bout
# Ultimate Fighter Australia vs. UK Lightweight Tournament Title Bout
# Ultimate Fighter Brazil 1 Middleweight Tournament Title Bout
# Ultimate Fighter Brazil 1 Featherweight Tournament Title Bout
# Ultimate Fighter 15 Lightweight Tournament Title Bout
# Ultimate Fighter 14 Featherweight Tournament Title Bout
# Ultimate Fighter 14 Bantamweight Tournament Title Bout
# Ultimate Fighter 13 Welterweight Tournament Title Bout
# Ultimate Fighter 12 Lightweight Tournament Title Bout
# Ultimate Fighter 11 Middleweight Tournament Title Bout
# Ultimate Fighter 10 Heavyweight Tournament Title Bout
# Ultimate Fighter 9 Welterweight Tournament Title Bout
# Ultimate Fighter 9 Lightweight Tournament Title Bout
# Ultimate Fighter 8 Lightweight Tournament Title Bout
# Ultimate Fighter 8 Light Heavyweight Tournament Title Bout
# Ultimate Fighter 7 Middleweight Tournament Title Bout
# Ultimate Fighter 6 Welterweight Tournament Title Bout
# Ultimate Fighter 5 Lightweight Tournament Title Bout
# Ultimate Fighter 4 Welterweight Tournament Title Bout
# Ultimate Fighter 4 Middleweight Tournament Title Bout
# Ultimate Fighter 3 Light Heavyweight Tournament Title Bout
# Ultimate Fighter 3 Middleweight Tournament Title Bout
# Ultimate Fighter 2 Heavyweight Tournament Title Bout
# Ultimate Fighter 2 Welterweight Tournament Title Bout
# Ultimate Fighter 1 Light Heavyweight Tournament Title Bout
# Ultimate Fighter 1 Middleweight Tournament Title Bout ​​

# %%
# # Combine the 'FIGHTER1' and 'FIGHTER2' columns from the entire file to find unique fighters
# unique_fighters_all = pd.concat([data['FIGHTER1'], data['FIGHTER2']]).unique()

# # Count the number of unique fighters in the entire file
# unique_fighter_count_all = len(unique_fighters_all)
# unique_fighter_count_all

# %%
### END GOOD ###

# %%
# # Remove white spaces

# import re
# import pandas as pd

# # Load the data
# df = pd.read_csv('./data-raw/fighter_info.csv')

# # Count changes
# original = df['Fighter'].copy()

# # Remove special characters and strip leading/trailing whitespace
# df['Fighter'] = df['Fighter'].apply(lambda x: re.sub(r'[^\w\s]', '', x).strip().lower())

# # Calculate and print the number of changes
# changes = (original != df['Fighter']).sum()
# print(f'Number of rows changed: {changes}')

# # Save the cleaned data back to CSV
# df.to_csv('./data-raw/fighter_info.csv', index=False)

# %%
# # Remove white spaces and make lowercase for all data

# # Load the data
# df = pd.read_csv('./data-raw/fighter_info.csv')

# # Normalize column names: convert to lowercase
# df.columns = [col.lower() for col in df.columns]

# # Apply transformations to each column and count changes
# for col in df.columns:
#     original = df[col].copy()  # Copy original data for change comparison
#     df[col] = df[col].astype(str).apply(lambda x: x.strip().lower())  # Trim and lowercase data
#     changes = (original != df[col]).sum()  # Calculate changes
#     print(f'Number of rows changed in {col}: {changes}')

# # Save the cleaned data back to CSV
# df.to_csv('./data-raw/fighter_info.csv', index=False)

# %%
# All together (womens and cleaning shit)

# import re
# import pandas as pd

# # Load the datasets
# master_df = pd.read_csv('./data/github/master.csv')
# fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')

# # Remove leading/trailing whitespace, special characters, and normalize to lowercase
# master_df['FIGHTER1'] = master_df['FIGHTER1'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)
# master_df['FIGHTER2'] = master_df['FIGHTER2'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)
# fighter_info_df['Fighter'] = fighter_info_df['Fighter'].str.strip().str.lower().str.replace(r'[^\w\s]', '', regex=True)

# # Save the cleaned datasets back to their original files
# master_df.to_csv('./data/github/master.csv', index=False)
# fighter_info_df.to_csv('./data-raw/fighter_info.csv', index=False)

# # Reload the cleaned datasets
# master_df = pd.read_csv('./data/github/master.csv')
# fighter_info_df = pd.read_csv('./data-raw/fighter_info.csv')

# # Filter for women's fights
# womens_fights_master = master_df[master_df['WEIGHTCLASS'].str.contains('Women', case=False, na=False)]

# # Extract Fighter Names
# female_fighters = set(womens_fights_master['FIGHTER1']).union(set(womens_fights_master['FIGHTER2']))

# # Clean `fighter_info.csv`
# cleaned_fighter_info_df = fighter_info_df[~fighter_info_df['Fighter'].isin(female_fighters)]

# # Save the cleaned dataset, overwriting the original file
# cleaned_fighter_info_df.to_csv('./data-raw/fighter_info.csv', index=False)

# print("Cleaned dataset saved to ./data-raw/fighter_info.csv")

# %%
# # Standardize birth date

# # Load the dataset
# fighter_info = pd.read_csv('./data-raw/fighter_info.csv')

# # Convert 'birth date' to datetime
# fighter_info['birth date'] = pd.to_datetime(fighter_info['birth date'], errors='coerce', format='%b %d, %Y')

# # Optional: Check for null values which indicate parsing errors
# print(fighter_info['birth date'].isnull().sum(), "parsing errors in birth dates")

# # Save the standardized dataset
# fighter_info.to_csv('./data-raw/fighter_info.csv', index=False)

# %%
# Delete fights 

# # Load the dataset
# data = pd.read_csv('./data-raw/event_data_sherdog.csv')

# # Convert 'Event Date' to datetime with timezone awareness
# data['Event Date'] = pd.to_datetime(data['Event Date'], errors='coerce', utc=True)

# # Filter the dataset to include only events from 2015 onwards
# data = data[data['Event Date'].dt.year >= 2015]

# # Now 'data' contains only the rows for fights from 2015 onwards
# print(data.head())

# %% [markdown]
# # Convert to Text Files

# %%
# !rm -rf ./data-txt
# !mkdir -p ./data-txt/fighters

# %%
# for filename in os.listdir('./data-raw/'):
#     if filename.endswith('.csv'):
#         file_path = os.path.join('./data-raw/', filename)
#         output_file_path = os.path.join('./data-txt/', filename.replace('.csv', '.txt'))
#         df = pd.read_csv(file_path)
#         df.to_csv(output_file_path, index=False, sep='\t')

# for filename in os.listdir('./data-raw/fighters'):
#     if filename.endswith('.csv'):
#         file_path = os.path.join('./data-raw/fighters', filename)
#         output_file_path = os.path.join('./data-txt/fighters', filename.replace('.csv', '.txt'))
#         df = pd.read_csv(file_path)
#         df.to_csv(output_file_path, index=False, sep='\t')
