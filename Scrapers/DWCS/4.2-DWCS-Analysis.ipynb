# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Perform exploratory data analysis

# %% [markdown]
# # Returning Fighters Analysis

# %%
df = pd.read_csv('./data-dwcs/DWCS_Event_Data_Sherdog.csv')

# Combine the 'Fighter 1' and 'Fighter 2' columns into a single list
all_fighters = df['Fighter 1'].tolist() + df['Fighter 2'].tolist()

# Convert the list into a pandas Series and count the occurrences of each fighter
all_fighters_series = pd.Series(all_fighters)
fighter_counts = all_fighters_series.value_counts()

# Filter out fighters who have fought more than once
repeat_fighters = fighter_counts[fighter_counts > 1]

# %% [markdown]
# ### GPT Analysis 1
#
# Great, let's dig deeper into the win percentages for fighters who have fought exactly twice on the show. Here's a summary:
#
# Summary of Win Status for Fighters with Exactly 2 Bouts
# 11 fighters lost both their first and second bouts.
# 8 fighters lost their first bout but won their second bout.
# 5 fighters won their first bout but lost their second bout.
# 11 fighters won both their first and second bouts.
# Win Percentage Analysis
# Among fighters who won their first bout, approximately 68.75% also won their second bout.
# Among fighters who lost their first bout, approximately 42.11% won their second bout.
# From this analysis, it appears that fighters who win their first bout are more likely to win their second bout as well (68.75% win rate for the second bout). Conversely, for those who lose their first bout, the chance of winning the second bout is lower, at around 42.11%.
#
# Here's the code I used to conduct this deeper analysis:

# %%
df = pd.read_csv('./data-dwcs/DWCS_Event_Data_Sherdog.csv')

# Create a summary DataFrame from the extracted fighter statistics
summary_df = pd.DataFrame(summary_rows)

# Group by 'Won First Bout' and 'Won Second Bout' to get counts
summary_counts = summary_df.groupby(['Won First Bout', 'Won Second Bout']).size().reset_index(name='Count')

# Calculate percentages for specific scenarios
won_first_won_second = summary_df[(summary_df['Won First Bout'] == True) & (summary_df['Won Second Bout'] == True)].shape[0]
won_first_total = summary_df[summary_df['Won First Bout'] == True].shape[0]
percentage_won_first_won_second = (won_first_won_second / won_first_total) * 100

lost_first_won_second = summary_df[(summary_df['Won First Bout'] == False) & (summary_df['Won Second Bout'] == True)].shape[0]
lost_first_total = summary_df[summary_df['Won First Bout'] == False].shape[0]
percentage_lost_first_won_second = (lost_first_won_second / lost_first_total) * 100

# %% [markdown]
# ### GPT Analysis 2
#
# After closely examining the data for returning fighters who have had exactly two bouts, I found an interesting trend related to whether fights go the distance:
#
# Fights Going the Distance (Ending in Round 3)
# In the first bouts, 21 fights went the distance, which is approximately 60% of the total fights.
# In the second bouts, 24 fights went the distance, which is approximately 68.57% of the total fights.
# Fights Not Going the Distance (Ending Before Round 3)
# In the first bouts, approximately 40% of the fights did not go the distance.
# In the second bouts, approximately 31.43% of the fights did not go the distance.
# From this, we can observe that fights are slightly more likely to go the distance in the second bout compared to the first bout for returning fighters.
#
# Here's the code I used for this analysis:

# %%
df = pd.read_csv('./data-dwcs/DWCS_Event_Data_Sherdog.csv')

# Create a round summary DataFrame from extracted 'Winning Round' data
round_summary_df = pd.DataFrame(round_summary_rows)

# Count the number of fights that went the distance (i.e., ended in round 3) in the first and second bouts
went_distance_first = round_summary_df[round_summary_df['First Bout Round'] == 3].shape[0]
went_distance_second = round_summary_df[round_summary_df['Second Bout Round'] == 3].shape[0]

# Calculate the percentages of fights that went the distance in the first and second bouts
total_fights = len(round_summary_rows)
percentage_went_distance_first = (went_distance_first / total_fights) * 100
percentage_went_distance_second = (went_distance_second / total_fights) * 100

# %% [markdown]
# ### GPT Analysis 3
#
# After digging deeper into the original dataset, here are five more insightful and interesting trends:
#
# 1. Distribution by Weight Class
# The most common weight class for fights is Middleweight with 88 bouts, followed by Light Heavyweight with 67 bouts and Lightweight with 50 bouts. The least represented weight classes are Strawweight and 188lb Catchweight, each with just 5 bouts.
# 2. Trends in Winning Methods over Time
# The winning method "Decision (Unanimous)" has been consistently popular across years, dominating the count each year.
# 3. Event Locations
# A significant majority of the events took place at the UFC Training Center in Las Vegas, Nevada, United States (262 bouts). The UFC Apex in Las Vegas hosted 43 bouts, making it the second most common venue.
# 4. Average Fight Duration by Weight Class
# Bantamweight fights tend to last the longest, with an average duration of approximately 4.06 minutes. Strawweight fights are the shortest on average, lasting around 2.90 minutes.
# 5. Winning Fighters by Weight Class
# There doesn't seem to be a dominant fighter in any particular weight class based on the available data. The wins are fairly distributed among various fighters.

# %% [markdown]
# # Previous Fight Leagues Results (Cage Warriors)

# %%
import pandas as pd
import os

fighters_folder_path = 'data-dwcs/fighters/'

# Function to process each fighter's file and retain DWCS fight, plus the fight after
def filter_fighter_fights_extended(df):
    # Identify rows where the 'Event Name' contains "DWCS" or "Contender Series"
    dwcs_mask = df['Event Name'].str.contains('DWCS|Contender Series', case=False, na=False)

    # Find indices of the DWCS fights
    dwcs_indices = df[dwcs_mask].index
    
    # Create an empty list to hold rows to keep
    rows_to_keep = []

    # Loop through each index where a DWCS fight is found
    for idx in dwcs_indices:
        # Add the current DWCS fight row (idx) and the next row (idx + 1), if exists
        rows_to_keep.append(idx)
        if idx + 1 < len(df):
            rows_to_keep.append(idx + 1)

    # Filter the DataFrame to keep only the selected rows
    filtered_df = df.loc[rows_to_keep]

    return filtered_df

# Iterate through each file in the directory
for filename in os.listdir(fighters_folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(fighters_folder_path, filename)

        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Process the DataFrame to keep only DWCS fight and the fight after
        filtered_df = filter_fighter_fights_extended(df)

        # Save the filtered DataFrame back to the file (or to a new file if preferred)
        filtered_df.to_csv(file_path, index=False)

        print(f"Processed and saved: {filename}")
# Out:
# Processed and saved: Kyler_Matrix_Phillips_190919.csv
# Processed and saved: Ernesta_Heavy-Handed_Kareckaite_319093.csv
# Processed and saved: Vanderson_de_Camp_285789.csv
# Processed and saved: Brunno_Ferreira_322603.csv
# Processed and saved: Armen_Superman_Petrosyan_302783.csv
# Processed and saved: Janaina_Jana_Popozinha_Silva_284089.csv
# Processed and saved: Geoff_Handz_of_Steel_Neal_72107.csv
# Processed and saved: Jasmine_Jasudavicius_311001.csv
# Processed and saved: Alex_Perez_12443.csv
# Processed and saved: Sean_The_Sniper_Woodson_235563.csv
# Processed and saved: Ginseng_Poit_DuJour_172427.csv
# Processed and saved: Adam_Samurai_Bramhald_159939.csv
# Processed and saved: Weldon_Silva_de_Oliveira_158505.csv
# Processed and saved: Bevon_The_Extraordinary_Gentleman_Lewis_211153.csv
# Processed and saved: Ikram_Aliskerov_202763.csv
# Processed and saved: Dwight_Joseph_106151.csv
# Processed and saved: Taylor_Tombstone_Johnson_232443.csv
# Processed and saved: Ronnie_The_Heat_Lawrence_102885.csv
# Processed and saved: Eli_Aronov_295271.csv
# Processed and saved: Kaik_Brito_204891.csv
# Processed and saved: Collin_Huck_Wild_Huckbody_140211.csv
# Processed and saved: Hunter_Azure_251727.csv
# Processed and saved: Taylor_Moore_207161.csv
# Processed and saved: Marcio_Breno_Rodrigues_Braga_80762.csv
# Processed and saved: Terry_Welch_294689.csv
# Processed and saved: Lucas_Fenomeno_Rocha_255729.csv
# Processed and saved: Victoria_Dudakova_333829.csv
# Processed and saved: Chad_Superman_Hanekom_215519.csv
# Processed and saved: Joanderson_Tubarao_Brito_181115.csv
# Processed and saved: Daniel_The_Werewolf_of_Texas_Jolly_83243.csv
# Processed and saved: Lucas_Rosa_58906.csv
# Processed and saved: Loneer_Kavanagh_213249.csv
# Processed and saved: Victor_Kelevra_Reyna_72745.csv
# Processed and saved: Brexton_Everett_210159.csv
# Processed and saved: Jesse_Hollywood_Murray_149445.csv
# Processed and saved: Mateus_Silva_132953.csv
# Processed and saved: Jaimelene_Nievera_88009.csv
# Processed and saved: Tyler_The_Zombie_Hill_55299.csv
# Processed and saved: Jailton_Almeida_114657.csv
# Processed and saved: Lukasz_Kopera_86924.csv
# Processed and saved: Tuluosibake_Kuerbanjiang_184347.csv
# Processed and saved: Zevan_Hunt_306081.csv
# Processed and saved: Justin_The_Fort_Sumter_98983.csv
# Processed and saved: Thanh_Le_108007.csv
# Processed and saved: Rodrigo_Yogi_Bear_Ze_Colmeia_Nascimento_97975.csv
# Processed and saved: Jakub_Dohnal_244637.csv
# Processed and saved: Julia_Polastri_266047.csv
# Processed and saved: Kelly_Killer_McGill-Velasco_170067.csv
# Processed and saved: Anthony_The_Genius_Romero_221129.csv
# Processed and saved: Jarious_Gill_384128.csv
# Processed and saved: Yann_Liasse_227899.csv
# Processed and saved: Kaleio_K.O._Romero_226585.csv
# Processed and saved: Johnny_Walker_170203.csv
# Processed and saved: Teddy_Ash_101379.csv
# Processed and saved: Gian_Franco_Cortez_291425.csv
# Processed and saved: Emrah_The_Anatolian_Wolf_Sonmez_147863.csv
# Processed and saved: Rafael_Calcidoni_234485.csv
# Processed and saved: Billy_Quarantillo_68076.csv
# Processed and saved: Pavel_Dailidko_314061.csv
# Processed and saved: Shelton_The_Gravedigger_Graves_89415.csv
# Processed and saved: Miguel_Caramel_Thunder_Baeza_231403.csv
# Processed and saved: Will_Currie_249519.csv
# Processed and saved: Loik_Radzhabov_154357.csv
# Processed and saved: Pauline_Pita_Macias_225033.csv
# Processed and saved: Taiga_Iwasaki_375260.csv
# Processed and saved: Edwin_Smart_174989.csv
# Processed and saved: Nicolo_Solli_239497.csv
# Processed and saved: Karl_Williams_333575.csv
# Processed and saved: Dashawn_Boatwright_241897.csv
# Processed and saved: Madars_Bertholds-Fleminas_224999.csv
# Processed and saved: Ewerton_Polaquini_288809.csv
# Processed and saved: Ronaldo_Pac-Man_Candido_de_Oliveira_128351.csv
# Processed and saved: Danilo_de_Souza_Silva_143839.csv
# Processed and saved: Eduarda_Ronda_Moura_395040.csv
# Processed and saved: Jonny_Parsons_65875.csv
# Processed and saved: Rami_The_Russian_Hamed_187079.csv
# Processed and saved: Aaron_Jeffery_127631.csv
# Processed and saved: Cameron_The_Baby-Faced_Killer_Smotherman_339497.csv
# Processed and saved: Ray_The_Judge_Rodriguez_78078.csv
# Processed and saved: Yuri_Fraga_21928.csv
# Processed and saved: Chris_The_Action_Man_Curtis_48039.csv
# Processed and saved: Kleydson_K.R._Rodrigues_229541.csv
# Processed and saved: Anvar_The_Uzbek_Boynazarov_382280.csv
# Processed and saved: Jay_The_Joker_Perrin_99689.csv
# Processed and saved: Gilmar_Dutra_Lima_14613.csv
# Processed and saved: Nurullo_Tajik_Eagle_Aliev_274869.csv
# Processed and saved: Julio_Arce_71299.csv
# Processed and saved: Allan_da_Silva_Pena_203527.csv
# Processed and saved: Marcos_Vinicius_dos_Santos_da_Silva_198931.csv
# Processed and saved: Thomas_Paull_159169.csv
# Processed and saved: Leonardo_Silva_149277.csv
# Processed and saved: Cody_Haddon_286511.csv
# Processed and saved: Philip_Rowe_121067.csv
# Processed and saved: Bo_Nickal_392031.csv
# Processed and saved: Issa_Isakov_181953.csv
# Processed and saved: Greg_Ribz_Rebello_12293.csv
# Processed and saved: Jonathan_Knutson_44209.csv
# Processed and saved: Ben_Combat_Wombat_Sosoli_125617.csv
# Processed and saved: Rainn_Drop_Guerrero_292231.csv
# Processed and saved: Jose_Delgado_307733.csv
# Processed and saved: Jack_Cartwright_162593.csv
# Processed and saved: Mick_Parkin_224411.csv
# Processed and saved: Hailey_All_Hail_Cowan_271495.csv
# Processed and saved: Tyler_Smith_59101.csv
# Processed and saved: Dustin_Stoltzfus_113779.csv
# Processed and saved: James_Mooka_Barnes_164811.csv
# Processed and saved: Malik_Lewis_183193.csv
# Processed and saved: Alex_The_Chess_Master_Morgan_134879.csv
# Processed and saved: James_Llontop_191443.csv
# Processed and saved: Seok_Hyun_Ko_275977.csv
# Processed and saved: Fernie_Garcia_112047.csv
# Processed and saved: Josefine_Little_Thunder_Lindgren_Knutsson_378677.csv
# Processed and saved: Mansur_Abdul-Malik_393926.csv
# Processed and saved: Halston_Williams_290919.csv
# Processed and saved: Ian_The_Hurricane_Heinisch_187341.csv
# Processed and saved: Joe_Pyfer_239253.csv
# Processed and saved: Jose_No_Way_Johnson_238733.csv
# Processed and saved: Jacob_Heavlin_277409.csv
# Processed and saved: Edivan_Pe_de_Sapo_Santos_244213.csv
# Processed and saved: Aalon_Cruz_103485.csv
# Processed and saved: Cody_Brundage_281913.csv
# Processed and saved: Daniel_Agent_Orange_Swain_73000.csv
# Processed and saved: Steve_Mean_Machine_Garcia_50916.csv
# Processed and saved: Raimond_Magomedaliev_191869.csv
# Processed and saved: Kathryn_Paprocki_281761.csv
# Processed and saved: Dumar_Roa_172649.csv
# Processed and saved: Ary_Santos_52029.csv
# Processed and saved: Brandon_Superman_Lewis_230745.csv
# Processed and saved: Daniel_Golden_Boy_Zellhuber_238903.csv
# Processed and saved: A.J._The_Savage_Cunningham_228033.csv
# Processed and saved: Dan_50K_Ige_136499.csv
# Processed and saved: Alex_Gilpin_137961.csv
# Processed and saved: Eiycaireon_Tavarres_263325.csv
# Processed and saved: Donelei_Benedetto_78258.csv
# Processed and saved: Jonathan_JSP_Pearce_183541.csv
# Processed and saved: Chris_Pecero_66878.csv
# Processed and saved: Viacheslav_Borshchev_337895.csv
# Processed and saved: Riley_The_Perfect_Storm_Dutro_42022.csv
# Processed and saved: Adrian_Yanez_86354.csv
# Processed and saved: Martin_The_Spartan_Day_155883.csv
# Processed and saved: Devin_The_Prodigy_Smyth_224885.csv
# Processed and saved: Shannon_The_Turkish_Delight_Ross_65792.csv
# Processed and saved: Jiang__Tao_222535.csv
# Processed and saved: Abdul-Kareem_Al-Selwady_115453.csv
# Processed and saved: Joao_Vitor_Ramos_Dantas_198829.csv
# Processed and saved: Jafel_Pastor_Filho_131375.csv
# Processed and saved: Wesley_Ledford_329227.csv
# Processed and saved: Mallory_Martin_200771.csv
# Processed and saved: Dylan_Salvador_322181.csv
# Processed and saved: Alonzo_Atomic_Menifield_210501.csv
# Processed and saved: Donovan_Beard_310501.csv
# Processed and saved: Chase_Waldon_68408.csv
# Processed and saved: Jamahal_Sweet_Dreams_Hill_280417.csv
# Processed and saved: Oron_Kahlon_92631.csv
# Processed and saved: Boston_Boom_Boom_Salmon_131463.csv
# Processed and saved: Shadoe_Himle_259627.csv
# Processed and saved: Pedro_Oliveira_378164.csv
# Processed and saved: Matheus_Scheffel_108913.csv
# Processed and saved: Matt_Frevola_100247.csv
# Processed and saved: Farid_Basharat_222641.csv
# Processed and saved: Roman_Kopylov_232601.csv
# Processed and saved: Ryan_Mondala_154673.csv
# Processed and saved: Brendan_Loughnane_44417.csv
# Processed and saved: Chandler_The_Hammer_Cole_201389.csv
# Processed and saved: Mike_Beast_Boy_Davis_202169.csv
# Processed and saved: Elias_Urbina_167417.csv
# Processed and saved: An_Tuan_The_Highlight_Ho_307731.csv
# Processed and saved: A.J._The_Ghost_Fletcher_284309.csv
# Processed and saved: Chris_Bungard_73304.csv
# Processed and saved: Khadzhimurat_Bestaev_164821.csv
# Processed and saved: Dylan_Lockard_168855.csv
# Processed and saved: Marquel_Mederos_302655.csv
# Processed and saved: Serhiy_Sidey_220713.csv
# Processed and saved: Alonzo_Menifield_210501.csv
# Processed and saved: Hamza_Salim_58713.csv
# Processed and saved: Rickson_Thai_The_King_Zenidim_Bueno_134695.csv
# Processed and saved: Edgar_Puro_Chicali_Chairez_244721.csv
# Processed and saved: J.P._Young_Savage_Buys_197069.csv
# Processed and saved: Jose_Flores_60457.csv
# Processed and saved: Victoria_Fury_Leonardo_212725.csv
# Processed and saved: Maurice_The_AK_Kid_Mitchell_37818.csv
# Processed and saved: Cory_Poppins_McKenna_178347.csv
# Processed and saved: Claudia_Leite_283949.csv
# Processed and saved: Diego_Lopes_112531.csv
# Processed and saved: Cameron_Saaiman_317055.csv
# Processed and saved: Jack_Phar_Jenkins_228039.csv
# Processed and saved: Charles_Kid_Dynamite_Byrd_51234.csv
# Processed and saved: Kirill_Kornilov_338905.csv
# Processed and saved: Chelsea_Hammer_Hackett_319473.csv
# Processed and saved: Kevin_Ray_Sears_87251.csv
# Processed and saved: Liam_Anderson_299651.csv
# Processed and saved: Valesca_Tina_Black_Machado_215597.csv
# Processed and saved: Jamie_The_Nightwolf_Pickett_72595.csv
# Processed and saved: Taneisha_Triple_Threat_Tennant_241537.csv
# Processed and saved: Alton_Cunningham_166015.csv
# Processed and saved: Matt_Magic_Dixon_156097.csv
# Processed and saved: Yousef_Wehbe_181199.csv
# Processed and saved: Shawn_The_Norwegian_Nightmare_Teed_175575.csv
# Processed and saved: Mateusz_Chinczyk_Rebecki_146417.csv
# Processed and saved: Jordan_Espinosa_64942.csv
# Processed and saved: Torrez_The_Punisher_Finney_379262.csv
# Processed and saved: Kevin_El_Chino_Vallejos_391233.csv
# Processed and saved: Ismael_Marreta_Bonfim_84528.csv
# Processed and saved: Dailon_Farias_218917.csv
# Processed and saved: Luke_Dixon_64318.csv
# Processed and saved: Sarah_Frota_222541.csv
# Processed and saved: Jerome_The_Renegade_Rivera_139017.csv
# Processed and saved: Edward_Massey_226105.csv
# Processed and saved: Vince_Vandetta_Morales_177019.csv
# Processed and saved: Phillip_Latu_392424.csv
# Processed and saved: Alexander_Barahona_175771.csv
# Processed and saved: Mikey_Rolls_Gonzalez_205501.csv
# Processed and saved: Valentine_Woodburn_315963.csv
# Processed and saved: Mario_Filipe_de_Sousa_213265.csv
# Processed and saved: Alfred_The_Fearless_Khashakyan_133919.csv
# Processed and saved: Shamil_Gaziev_313721.csv
# Processed and saved: Dylan_The_Mindless_Hulk_Budka_377018.csv
# Processed and saved: Rafael_Macapa_Estevam_200851.csv
# Processed and saved: Osman_Diaz_156965.csv
# Processed and saved: Christian_Hollywood_Lohsen_234019.csv
# Processed and saved: Murtaza_Talha_Ali_269171.csv
# Processed and saved: Ranieri_Yuri_Zenidim_Bueno_80739.csv
# Processed and saved: Dustin_Jacoby_73825.csv
# Processed and saved: Rafael_The_Turn_Alves_96651.csv
# Processed and saved: Austen_Lane_249439.csv
# Processed and saved: Tereza_Bleda_280807.csv
# Processed and saved: Bruno_Brunao_Assis_185297.csv
# Processed and saved: Brandon_Shavers_190277.csv
# Processed and saved: Isis_Fight_Queen_Verbeek_307003.csv
# Processed and saved: Danyelle_Wolf_297121.csv
# Processed and saved: Fausto_de_Souza_164213.csv
# Processed and saved: Bobby_The_Wolfman_Moffett_159019.csv
# Processed and saved: Nayara_Arnault_Maia_Correia_248475.csv
# Processed and saved: Maria_Spider-Girl_Oliveira_207835.csv
# Processed and saved: Maria_Viuva_Negra_Silva_257311.csv
# Processed and saved: Josh_Wang_Kim_188773.csv
# Processed and saved: Henrique_Frankenstein_da_Silva_175493.csv
# Processed and saved: Marcos_Brigagao_258879.csv
# Processed and saved: Jairzinho_Rozenstruik_102803.csv
# Processed and saved: Lazaro_Perez_332087.csv
# Processed and saved: Robin_Roos_242399.csv
# Processed and saved: Kleber_Ferreira_Braz_21862.csv
# Processed and saved: Bruno_Brunao_Lopes_144007.csv
# Processed and saved: Robbie_Razor_Ring_303011.csv
# Processed and saved: Cameron_Captain_Crunch_Olson_171259.csv
# Processed and saved: James_Wallace_55291.csv
# Processed and saved: Mauricio_Ruffy_192545.csv
# Processed and saved: Diego_Maia_216967.csv
# Processed and saved: Natan_Lethal_Levy_227411.csv
# Processed and saved: Quemuel_Ottoni_174569.csv
# Processed and saved: Nikolas_Iron_Motta_103887.csv
# Processed and saved: Matt_Sayles_93675.csv
# Processed and saved: Denis_Vygovsky_193799.csv
# Processed and saved: Ibo_The_Last_Ottoman_Aslan_247071.csv
# Processed and saved: Orlanison_Neris_de_Oliveira_198107.csv
# Processed and saved: Lun_Tibetan_Knight_Qiu_257571.csv
# Processed and saved: Allan_Begosso_196853.csv
# Processed and saved: Pat_Pytlik_167251.csv
# Processed and saved: Trey_The_Truth_Waters_319103.csv
# Processed and saved: Te_T_Edwards_156303.csv
# Processed and saved: Juan_Andres_Luna_Martinetti_247345.csv
# Processed and saved: Igor_Cavalcanti_387931.csv
# Processed and saved: Carlos_Ulberg_84291.csv
# Processed and saved: John_Noland_245673.csv
# Processed and saved: Yuneisy_Duben_278389.csv
# Processed and saved: Vanessa_Lil_Monster_Demopoulos_118775.csv
# Processed and saved: Martin_Buday_164475.csv
# Processed and saved: Marcos_Matos_194593.csv
# Processed and saved: Eduardo_Bbzao_Neves_363709.csv
# Processed and saved: T.J._The_Truth_Laramie_188479.csv
# Processed and saved: Jordan_Williams_70941.csv
# Processed and saved: Melsik_Baghdasaryan_164681.csv
# Processed and saved: Stephanie_Macaquinha_Frausto_61109.csv
# Processed and saved: Luis_Corazon_de_Leon_Pajuelo_287861.csv
# Processed and saved: A.J._Dobson_119943.csv
# Processed and saved: Hyder_The_Hurricane_Amil_269917.csv
# Processed and saved: Clayton_Carpenter_208467.csv
# Processed and saved: Jordan_The_Native_Psycho_Griffin_56524.csv
# Processed and saved: Trever_Bradshaw_128517.csv
# Processed and saved: Josh_Quinlan_290925.csv
# Processed and saved: Jake_White_Kong_Hadley_200597.csv
# Processed and saved: Yazan_Hajeh_83135.csv
# Processed and saved: Grigoriy_Ponomarev_292517.csv
# Processed and saved: Martin_Badys_Buday_164475.csv
# Processed and saved: Everett_Wolverine_Sims_95469.csv
# Processed and saved: Charlie_Radtke_175669.csv
# Processed and saved: Navajo_Sterling_413272.csv
# Processed and saved: Acacio_Pequeno_dos_Santos_127365.csv
# Processed and saved: Orion_Galaxy_Cosce_156917.csv
# Processed and saved: Diego_Dias_145419.csv
# Processed and saved: Fred_Zamora_209223.csv
# Processed and saved: Michael_Morales_268041.csv
# Processed and saved: Treston_Vines_209133.csv
# Processed and saved: Lucrezia_Ria_153417.csv
# Processed and saved: Cameron_Church_296559.csv
# Processed and saved: Joe_Solecki_227993.csv
# Processed and saved: Jack_Della_Maddalena_208155.csv
# Processed and saved: Impa_Tshilobo_Kasanganay_310489.csv
# Processed and saved: Victor_Hugo_Striker_Silva_123631.csv
# Processed and saved: Jeff_Jepsen_191487.csv
# Processed and saved: Guido_Guido_266641.csv
# Processed and saved: DonTale_Mayes_237177.csv
# Processed and saved: Eduardo_Neves_363709.csv
# Processed and saved: Tebaris_Gordon_260891.csv
# Processed and saved: Piera_La_Fiera_Rodriguez_247469.csv
# Processed and saved: Edson_Gomez_158229.csv
# Processed and saved: Garrett_Gross_84704.csv
# Processed and saved: Alexander_Ironside_Poppeck_99051.csv
# Processed and saved: Toby_2_Quick_Misech_48318.csv
# Processed and saved: Kevin_El_Gallo_Negro_Borjas_245493.csv
# Processed and saved: Bruno_Oliveira_87843.csv
# Processed and saved: Luis_Saldana_77414.csv
# Processed and saved: Chris_Padilla_124527.csv
# Processed and saved: Jhonata_Diniz_389887.csv
# Processed and saved: Amilcar_Alves_23841.csv
# Processed and saved: Mike_Malott_79377.csv
# Processed and saved: Diego_Gaucho_Henrique_da_Silva_76846.csv
# Processed and saved: Trevor_Anderson_281091.csv
# Processed and saved: Jacob_Lil_Animal_Silva_80677.csv
# Processed and saved: Moacir_Rocha_240319.csv
# Processed and saved: Nariman_Abbasov_141581.csv
# Processed and saved: Will_The_Brown_Bomber_Santiago_Jr._65536.csv
# Processed and saved: Kenneth_Bergh_189821.csv
# Processed and saved: Mayana_Kellen_Souza_dos_Santos_173013.csv
# Processed and saved: Crob_Pugliesi_272217.csv
# Processed and saved: Erik_Vo_31141.csv
# Processed and saved: Zion_Tomlinson_277685.csv
# Processed and saved: Meng_Ruthless_Assassin_Ding_241311.csv
# Processed and saved: Angelo_Baby_Monsta_Trevino_201359.csv
# Processed and saved: Achilles_Estremadura_68610.csv
# Processed and saved: Mabelly_Lima_187177.csv
# Processed and saved: Leon_Shahbazyan_158231.csv
# Processed and saved: Jhonoven_Pati_124585.csv
# Processed and saved: Kyle_Gunz_Up_Stewart_102333.csv
# Processed and saved: Fabio_Aguiar_132429.csv
# Processed and saved: Cris_Mims_384345.csv
# Processed and saved: Josias_The_K.O._Wizard_Musasa_416801.csv
# Processed and saved: Sodiq_Super_Yusuff_152359.csv
# Processed and saved: Olivier_Warrior_of_God_Murad_281291.csv
# Processed and saved: Thiago_Moises_130351.csv
# Processed and saved: Harvey_Park_72673.csv
# Processed and saved: Kevin_Pocket_Herc_Gray_120689.csv
# Processed and saved: Jamall_Prettyboy_Emmers_84139.csv
# Processed and saved: Taila_Santos_143185.csv
# Processed and saved: Maycee_Barber_253613.csv
# Processed and saved: Vadim_Litvin_309361.csv
# Processed and saved: Kani_Correa_99807.csv
# Processed and saved: Cheyden_Steadfast_Leialoha_173905.csv
# Processed and saved: Maki_Coconut_Bombz_Pitolo_51049.csv
# Processed and saved: Ricky_Simon_111209.csv
# Processed and saved: Michael_The_Texas_Kid_Aswell_286497.csv
# Processed and saved: Eduardo_Cyborg_Torres_Cant_190429.csv
# Processed and saved: Joseph_Lowry_76336.csv
# Processed and saved: Vitor_Ferreira_Costa_355863.csv
# Processed and saved: Eduardo_Ramon_131261.csv
# Processed and saved: Jimmy_Greedy_Lawson_322177.csv
# Processed and saved: Sidney_Da_Gun_Outlaw_64243.csv
# Processed and saved: Gloria_Glorinha_de_Paula_230933.csv
# Processed and saved: Patrik_Primetime_White_221861.csv
# Processed and saved: Chase_El_Guero_Gibson_180669.csv
# Processed and saved: Qihui_Queen_Kong_Yan_242711.csv
# Processed and saved: Erisson_Gato_Ferreira_226431.csv
# Processed and saved: Magomed_Gadzhiyasulov_272659.csv
# Processed and saved: Nazim_Black_Wolf_Sadykhov_264031.csv
# Processed and saved: Steven_Ocho_Peterson_60433.csv
# Processed and saved: Tracy_Cortez_160955.csv
# Processed and saved: Javier_Ames_267999.csv
# Processed and saved: Stephen_Regman_66763.csv
# Processed and saved: Mario_Piazzon_395038.csv
# Processed and saved: Ledson_Heider_Batista_252775.csv
# Processed and saved: Donavon_Frelow_79087.csv
# Processed and saved: Sari_Hleihil_247905.csv
# Processed and saved: Thiago_Araujo_217985.csv
# Processed and saved: Aziz_Julaidan_121373.csv
# Processed and saved: Lukasz_Brzeski_132249.csv
# Processed and saved: Dinis_Sweetbread_Paiva_69442.csv
# Processed and saved: Thomas_The_Train_Petersen_287525.csv
# Processed and saved: Acacio_dos_Santos_127365.csv
# Processed and saved: Long_Xiao_233007.csv
# Processed and saved: Marilia_Chocolate_Santos_136623.csv
# Processed and saved: Vince_Murdock_119961.csv
# Processed and saved: Edmen_The_Golden_Boy_Shahbazyan_247691.csv
# Processed and saved: Jose_Medina_251871.csv
# Processed and saved: Ode_The_Jamaican_Sensation_Osbourne_137969.csv
# Processed and saved: Rodrigo_Lima_Novais_148265.csv
# Processed and saved: Vinicius_Mamute_Moreira_207291.csv
# Processed and saved: Raul_El_Nino_Problema_Rosas_Jr._339419.csv
# Processed and saved: Michael_Imperato_72325.csv
# Processed and saved: Solomon_Renfro_225631.csv
# Processed and saved: Charalampos_Pampos_Grigoriou_236255.csv
# Processed and saved: Dustin_Dipuma_371129.csv
# Processed and saved: Shimon_Assassin_Smotritsky_254075.csv
# Processed and saved: Miles_Lee_275443.csv
# Processed and saved: Matej_Money_Penaz_370929.csv
# Processed and saved: Ramazan_Kuramagomedov_241397.csv
# Processed and saved: Lucas_Martins_100031.csv
# Processed and saved: Caio_Leao_Bitencourt_78480.csv
# Processed and saved: Ramon_Taveras_332055.csv
# Processed and saved: Mike_Rodriguez_107891.csv
# Processed and saved: Antonina_Shevchenko_45389.csv
# Processed and saved: Ameer_Basheer_338085.csv
# Processed and saved: Collin_Anglin_280415.csv
# Processed and saved: Rogerio_Bontorin_132211.csv
# Processed and saved: Tracy_Hardy_175691.csv
# Processed and saved: Billy_Goff_282365.csv
# Processed and saved: Joby_Sanchez_50239.csv
# Processed and saved: Michael_Garcia_186903.csv
# Processed and saved: Victor_Periquito_Madrigal_40341.csv
# Processed and saved: Kamuela_The_Jawaiian_Kirk_162187.csv
# Processed and saved: Jake_Sebastian_249295.csv
# Processed and saved: Terrance_T.Wrecks_McKinney_232591.csv
# Processed and saved: Yohan_White_Lion_Lainesse_295377.csv
# Processed and saved: Micol_DiSegni_171627.csv
# Processed and saved: Jacob_The_Killer_Kilburn_238233.csv
# Processed and saved: Ihor_Potieria_188721.csv
# Processed and saved: Jordan_The_Monkey_King_Leavitt_259871.csv
# Processed and saved: Dmitriy_Krivulets_289729.csv
# Processed and saved: Justin_Burlinson_160189.csv
# Processed and saved: Zachary_Reese_100903.csv
# Processed and saved: Greg_Prince_of_War_Hardy_271461.csv
# Processed and saved: Austin_The_Gentleman_Vanderford_206919.csv
# Processed and saved: Magomed_Mohammed_Haji_Gadzhiyasulov_272659.csv
# Processed and saved: Hashem_Arkhagha_74722.csv
# Processed and saved: Luis_El_Tigre_Gomez_207041.csv
# Processed and saved: Waldo_Salsa_Boy_Cortes-Acosta_190909.csv
# Processed and saved: Jared_The_Mountain_Vanderaa_152987.csv
# Processed and saved: Rafael_Nunes_32823.csv
# Processed and saved: Jessie_Henry_312223.csv
# Processed and saved: Zach_Edington_109233.csv
# Processed and saved: Dennis_Hernandez_300657.csv
# Processed and saved: Angel_DeAnda_40669.csv
# Processed and saved: Timothy_Twilight_Timmy_Cuamba_316223.csv
# Processed and saved: Matheus_Correa_252765.csv
# Processed and saved: Danny_The_Italian_Gangster_Sabatello_293067.csv
# Processed and saved: Dan_Spohn_39485.csv
# Processed and saved: Cristian_El_Nino_Problema_Quinonez_164995.csv
# Processed and saved: Kevin_Trailblazer_Holland_108999.csv
# Processed and saved: Ange_The_Last_Ninja_Loosa_95799.csv
# Processed and saved: Benito_Golden_Boy_Lopez_122711.csv
# Processed and saved: Cosme_Santos_150637.csv
# Processed and saved: Jeremie_Holloway_175675.csv
# Processed and saved: Rico_The_Triggerman_Farrington_135825.csv
# Processed and saved: Jose_Chicho_Medina_251871.csv
# Processed and saved: Alex_Munoz_207057.csv
# Processed and saved: Paulo_Renato_Jr._155523.csv
# Processed and saved: Marcio_Alexandre_Jr._95457.csv
# Processed and saved: Joseph_Ugly_Man_Holmes_285543.csv
# Processed and saved: Kolton_The_White_Assassin_Englund_80680.csv
# Processed and saved: Jhonata_Silva_179007.csv
# Processed and saved: Quillan_Salkilld_300317.csv
# Processed and saved: Chidi_Chidi_Bang_Bang_Njokuani_25761.csv
# Processed and saved: Karine_Killer_Silva_153807.csv
# Processed and saved: Aliaskhab_Khizriev_209647.csv
# Processed and saved: Rodrigo_Tadeu_de_Souza_129785.csv
# Processed and saved: Mayra_Sheetara_Bueno_Silva_223917.csv
# Processed and saved: Gadzhi_Omargadzhiev_145315.csv
# Processed and saved: Karolina_Polish_Assassin_Wojcik_224757.csv
# Processed and saved: Chris_The_Problem_Duncan_74346.csv
# Processed and saved: Jimmy_The_Brute_Crute_218959.csv
# Processed and saved: Chibwikem_Onyenegecha_142563.csv
# Processed and saved: Wesley_Schultz_338469.csv
# Processed and saved: Kenneth_The_Boss_Cross_232029.csv
# Processed and saved: Zachary_Borrego_383740.csv
# Processed and saved: Tom_Big_Train_Nolan_244655.csv
# Processed and saved: Darrius_Beast_Mode_Flowers_191363.csv
# Processed and saved: Max_Mustaki_79656.csv
# Processed and saved: Luana_Pinheiro_237525.csv
# Processed and saved: Dylan_Budka_377018.csv
# Processed and saved: Denise_Gomes_382138.csv
# Processed and saved: Harry_The_Hurricane_Hunsucker_239513.csv
# Processed and saved: Cole_Jordan_285705.csv
# Processed and saved: Sandra_Peruvian_Zombie_Lavado_241221.csv
# Processed and saved: Rodolfo_Bellato_266457.csv
# Processed and saved: Victor_Reyna_72745.csv
# Processed and saved: Trevor_Ollison_246273.csv
# Processed and saved: Natanael_Aldo_Espindola_233969.csv
# Processed and saved: Charles_de_Oliveira_Santos_159485.csv
# Processed and saved: Micheal_Murphy_226819.csv
# Processed and saved: Leomana_Manaboi_Martinez_130553.csv
# Processed and saved: Sebastian_Ferreira_45501.csv
# Processed and saved: Sam_The_Future_Patterson_141735.csv
# Processed and saved: Richard_Jacobi_391204.csv
# Processed and saved: Jesus_Santos_Aguilar_203965.csv
# Processed and saved: Gabriel_Marretinha_Bonfim_185083.csv
# Processed and saved: Stephanie_Rondinha_Luciano_265743.csv
# Processed and saved: Kevin_Henry_175859.csv
# Processed and saved: Emiliano_Golden_Bull_Linares_298713.csv
# Processed and saved: Carlos_Prates_95593.csv
# Processed and saved: Shahriar_Zolfaghari_334479.csv
# Processed and saved: Viacheslav_Slava_Borshchev_337895.csv
# Processed and saved: Ryan_Spann_68057.csv
# Processed and saved: William_Walker_159323.csv
# Processed and saved: Carlos_Hernandez_171603.csv
# Processed and saved: Allan_St-Gelais_363749.csv
# Processed and saved: Andres_Pedro_390069.csv
# Processed and saved: Tucker_Top_Gun_Lutz_122559.csv
# Processed and saved: Andrey_Pulyaev_398399.csv
# Processed and saved: Justin_J-Train_Gonzales_111883.csv
# Processed and saved: Brandon_Killer_B_Davis_67782.csv
# Processed and saved: Jordan_The_Beverly_Hills_Ninja_Wright_79138.csv
# Processed and saved: Manny_Vazquez_160015.csv
# Processed and saved: C.J._The_Autobot_Hamilton_71119.csv
# Processed and saved: John_Sexi_Mexi_Castaneda_86536.csv
# Processed and saved: Michal_Blackbeard_Martinek_242333.csv
# Processed and saved: Korey_Kuppe_78331.csv
# Processed and saved: Danny_Puma_Silva_310429.csv
# Processed and saved: Devonte_King_Kage_Smith_89163.csv
# Processed and saved: Oscar_Elevation_Cota_105241.csv
# Processed and saved: Saimon_Oliveira_156991.csv
# Processed and saved: Azamat_Bekoev_231875.csv
# Processed and saved: Juan_Leadfeather_Puerta_54931.csv
# Processed and saved: Mario_Filipe_Coracao_Valente_de_Sousa_213265.csv
# Processed and saved: Mikheil_Sazhiniani_315835.csv
# Processed and saved: Danilo_Dan_Suzart_264117.csv
# Processed and saved: Jeff_Lights_Out_Hughes_23793.csv
# Processed and saved: Ivan_Bam_Bam_Valenzuela_303315.csv
# Processed and saved: Richie_The_Milford_Mauler_Santiago_126329.csv
# Processed and saved: Kevin_Pastran_316833.csv
# Processed and saved: Chad_The_Monster_Anheliger_63370.csv
# Processed and saved: Phil_Hawes_130935.csv
# Processed and saved: Lazar_Stojadinovic_25149.csv
# Processed and saved: Aleksa_Camur_228789.csv
# Processed and saved: Junior_Furtoso_220467.csv
# Processed and saved: Charles_Byrd_51234.csv
# Processed and saved: Azunna_Zu_the_8th_Wonder_Anyanwu_68352.csv
# Processed and saved: J.R._Coughran_165367.csv
# Processed and saved: Amiran_The_Sniper_Gogoladze_250897.csv
# Processed and saved: Maiara_Amanajas_dos_Santos_77091.csv
# Processed and saved: Darko_Stosic_107757.csv
# Processed and saved: DonTale_Lord_Kong_Mayes_237177.csv
# Processed and saved: Jacob_Silva_80677.csv
# Processed and saved: Alton_The_Bo-Man_Cunningham_166015.csv
# Processed and saved: Mariusz_Ksiazkiewicz_66522.csv
# Processed and saved: Kendon_Smallwood_250395.csv
# Processed and saved: Punahele_Soriano_230239.csv
# Processed and saved: Vinicius_Chambinho_Sacchelli_Cenci_249659.csv
# Processed and saved: Austin_Bashi_362871.csv
# Processed and saved: Trevor_Peek_280187.csv
# Processed and saved: Emiliano_He-Man_Sordi_79071.csv
# Processed and saved: Esteban_Ribovics_214867.csv
# Processed and saved: Rayanne_dos_Santos_230789.csv
# Processed and saved: Albert_Machete_Duraev_86841.csv
# Processed and saved: Raulian_Paiva_167575.csv
# Processed and saved: Dylan_The_Quiet_Man_Mantello_286197.csv
# Processed and saved: Matt_Bessette_34374.csv
# Processed and saved: Nicolle_Caliari_202195.csv
# Processed and saved: Ricky_The_Karate_Kid_Steele_84460.csv
# Processed and saved: Dimitry_Zebroski_82055.csv
# Processed and saved: Roosevelt_Roberts_191653.csv
# Processed and saved: Maurice_Morris_397906.csv
# Processed and saved: Richard_Kiely_220567.csv
# Processed and saved: Colin_Parr_259579.csv
# Processed and saved: Ben_Bennett_194319.csv
# Processed and saved: Nick_Maximov_302823.csv
# Processed and saved: Tony_Gravely_210575.csv
# Processed and saved: Victor_Jones_175367.csv
# Processed and saved: Nasrudin_Nasrudinov_156463.csv
# Processed and saved: Ernie_Young_Titan_Juarez_269253.csv
# Processed and saved: Claudio_Ribeiro_249103.csv
# Processed and saved: Peter_The_Joker_Petties_183991.csv
# Processed and saved: Jamie_Pickett_72595.csv
# Processed and saved: Antonio_Arroyo_173979.csv
# Processed and saved: Dennis_The_Beard_Bryant_85516.csv
# Processed and saved: Cameron_Meintjes_177243.csv
# Processed and saved: Sedriques_The_Reaper_Dumas_288537.csv
# Processed and saved: Craig_Edwards_77583.csv
# Processed and saved: Marnic_The_Sawed-Off_Savage_Mann_268753.csv
# Processed and saved: Ricardo_Alemao_Prasel_157509.csv
# Processed and saved: Brok_Chata_Tuska_Weaver_53819.csv
# Processed and saved: Chris_The_Big_Buck_Birchler_75224.csv
# Processed and saved: Maheshate_Hayisaer_336819.csv
# Processed and saved: Jean_Matsumoto_263061.csv
# Processed and saved: David_Luna_366685.csv
# Processed and saved: Anton_Berzin_69707.csv
# Processed and saved: Jaime_Alvarez_139887.csv
# Processed and saved: Ahmad_Sohail_Lion_of_the_Ring_Hassanzada_279733.csv
# Processed and saved: Tafon_Nchukwi_282049.csv
# Processed and saved: Marcelo_Tenorio_90635.csv
# Processed and saved: Tony_Johnson_22377.csv
# Processed and saved: Kevin_El_Nino_Bala_Syler_164061.csv
# Processed and saved: Ricky_El_Gallero_Palacios_73600.csv
# Processed and saved: Bailey_Schoenfelder_385797.csv
# Processed and saved: Kali_Pop_Tart_Robbins_178681.csv
# Processed and saved: Carlos_Eduardo_Souza_Custodio_259985.csv
# Processed and saved: Caio_Bigfoot_Machado_247161.csv
# Processed and saved: Theo_Rlayang_256035.csv
# Processed and saved: Andre_Mascote_Lima_201199.csv
# Processed and saved: Casey_Kenney_211031.csv
# Processed and saved: Anthony_Tisdale_172425.csv
# Processed and saved: Vinicius_LokDog_Oliveira_139517.csv
# Processed and saved: Alan_Silva_267611.csv
# Processed and saved: Peter_Slippery_Pete_Barrett_79095.csv
# Processed and saved: Elias_Mendez_378962.csv
# Processed and saved: Nate_The_Savage_Smith_164585.csv
# Processed and saved: Charles_Bennett_1575.csv
# Processed and saved: Phil_No_Hype_Hawes_130935.csv
# Processed and saved: J.P._Buys_197069.csv
# Processed and saved: J.J._The_Bosnian_Bomber_Okanovich_93099.csv
# Processed and saved: Dustin_Joynson_98405.csv
# Processed and saved: Bolaji_The_Zulu_Warrior_Oki_276669.csv
# Processed and saved: Yusaku_Kinoshita_382723.csv
# Processed and saved: Carlos_The_Cannon_Candelario_97453.csv
# Processed and saved: Lukasz_Sudolski_124729.csv
# Processed and saved: Sean_Suga_OMalley_135099.csv
# Processed and saved: Muhammadjon_Hillman_Naimov_228381.csv
# Processed and saved: Anton_The_Pleasure_Man_Turkalj_234667.csv
# Processed and saved: Brady_The_Kung_Fu_Warrior_Huang_140911.csv
# Processed and saved: Jamal_The_Stormtrooper_Pogues_152993.csv
# Processed and saved: Karl_Reed_243879.csv
# Processed and saved: Anthony_Fluffy_Hernandez_86783.csv
# Processed and saved: Chris_Ocon_194123.csv
# Processed and saved: Murad_Adyrbaev_369490.csv
# Processed and saved: Kailan_Hill_232313.csv
# Processed and saved: Victor_The_Brick_Martinez_86938.csv
# Processed and saved: Joey____Gomez_124327.csv
# Processed and saved: Andre_Sergipano_Muniz_81800.csv
# Processed and saved: Miles_Chapo_Johns_172691.csv
# Processed and saved: Sergio_Vieira_12534.csv
# Processed and saved: Gleidson_Poney_Moraes_Cutis_81602.csv
# Processed and saved: Gustavo_Gabriel_Silva_127725.csv
# Processed and saved: Adam_Captain_Chaos_Antolin_28758.csv
# Processed and saved: Genaro_Rayadito_Valdez_227047.csv
# Processed and saved: Roybert_The_Unbroken_Echeverria_317187.csv
# Processed and saved: Carlos_Guerra_114019.csv
# Processed and saved: Gunther_Kalunda_222945.csv
# Processed and saved: Kevin_Aguilar_57838.csv
# Processed and saved: Marina_Rodriguez_193977.csv
# Processed and saved: Al_Matavao_210483.csv
# Processed and saved: Marco_Matuto_Tulio_263543.csv
# Processed and saved: Tiffany_Rainbow_Renegade_Masters_193979.csv
# Processed and saved: Leonardo_Damiani_239897.csv
# Processed and saved: Greg_Hardy_271461.csv
# Processed and saved: Kyle_The_DArce_Knight_Daukaus_83350.csv
# Processed and saved: Tim_The_Bear_Caron_128669.csv
# Processed and saved: Will_Drago_Currie_249519.csv
# Processed and saved: Bruna_The_Special_One_Brasil_182855.csv
# Processed and saved: Jamie_Bad_Mama_Colleen_Miller_115211.csv
# Processed and saved: Hilarie_Rose_205129.csv
# Processed and saved: Jamelle_Jones_137613.csv
# Processed and saved: Bruno_Pereira_123311.csv
# Processed and saved: Estefani_Almeida_205515.csv
# Processed and saved: Adercino_de_Jesus_121403.csv
# Processed and saved: Davi_O_Black_Bittencourt_263121.csv
# Processed and saved: Julian_Juicy_J_Erosa_71442.csv
# Processed and saved: Ahmed_Ansari_123167.csv
# Processed and saved: Dione_The_Witch_Barbosa_266915.csv
# Processed and saved: Jiming_Sun_239389.csv
# Processed and saved: Cameron_Cam_Van_Damme_Rowston_239381.csv
# Processed and saved: Geovani_Cruz_Cordeiro_117915.csv
# Processed and saved: Adonis_Saucedo_176715.csv
# Processed and saved: Chase_The_Dream_Hooper_249301.csv
# Processed and saved: Trevin_Giles_111237.csv
# Processed and saved: Lorenzo_The_Dream_Killer_Hood_51117.csv
# Processed and saved: Henrique_Shiguemoto_74268.csv
# Processed and saved: Santo_Curatolo_266023.csv
# Processed and saved: Jose_El_Pochito_Alday_146733.csv
# Processed and saved: Nick_Piccininni_388414.csv
# Processed and saved: John_The_Hunter_Allan_114875.csv
# Processed and saved: Nursulton_Ruziboev_175547.csv
# Processed and saved: Jordan_Fowler_208173.csv
# Processed and saved: Jason_The_Ass-Kicking_Machine_Jackson_48171.csv
# Processed and saved: Leonardo_Ram_Damiani_239897.csv
# Processed and saved: Cheyanne_The_Warrior_Princess_Vlismas_152049.csv
# Processed and saved: Augusto_Sakai_87303.csv
# Processed and saved: Malik_Jahmaze_309535.csv
# Processed and saved: Josh_The_White_Mamba_Wick_121219.csv
# Processed and saved: Jornel_Lugo_296625.csv
# Processed and saved: Kody_Steele_392962.csv
# Processed and saved: Desmond_The_Tyrant_Torres_251669.csv
# Processed and saved: Alexander_Soldatkin_203601.csv
# Processed and saved: William_Medeiros_128925.csv
# Processed and saved: William_Knightmare_Knight_282383.csv
# Processed and saved: Mateo_Alejandro_Vogel_273397.csv
# Processed and saved: Drako_The_Great_Drakolini_Rodriguez_203421.csv
# Processed and saved: Mitch_Raposo_278793.csv
# Processed and saved: Canaan_Kawaihae_230231.csv
# Processed and saved: William_Knight_282383.csv
# Processed and saved: Jack_The_Fury_Duffy_237621.csv
# Processed and saved: George_Hardwick_155397.csv
# Processed and saved: Daniel_Barez_133743.csv
# Processed and saved: Francis_Fire_Marshall_282887.csv
# Processed and saved: Mingyang_Zhang_243033.csv
# Processed and saved: Armando_La_Lumbre_Villarreal_141205.csv
# Processed and saved: Jeff_El_Jefe_Molina_218069.csv
# Processed and saved: Kurt_Holobaugh_68751.csv
# Processed and saved: Greg_Velasco_289117.csv
# Processed and saved: Juan_The_Kraken_Adams_239097.csv
# Processed and saved: Jacob_Thrall_190941.csv
# Processed and saved: Mike_Santiago_66110.csv
# Processed and saved: Kaloyan_Kolev_230917.csv
# Processed and saved: David_Barkhudaryan_229249.csv
# Processed and saved: Cortavious_Romious_206845.csv
# Processed and saved: Jair_Chosen_Farias_184971.csv
# Processed and saved: Jean_Lord_Silva_239947.csv
# Processed and saved: Sherrard_The_Savage_Blackledge_198563.csv
# Processed and saved: Gregoris_Cisneros_357669.csv
# Processed and saved: Jose_Luke_Flores_60457.csv
# Processed and saved: Gisele_Moreira_146455.csv
# Processed and saved: Danny_Barlow_336147.csv
# Processed and saved: Wallace_Lopes_93937.csv
# Processed and saved: Mateus_Bocao_Mendonca_336923.csv
# Processed and saved: Herdem_Alacabek_180227.csv
# Processed and saved: Alan_Carlos_31494.csv
# Processed and saved: Aleksandr_Kolomytsev_404957.csv
# Processed and saved: Rodrigo_Haro_85479.csv
# Processed and saved: Kelvin_Silva_216513.csv
# Processed and saved: Alton_Murda_Meeks_292547.csv
# Processed and saved: Joao_Paulo_Fagundes_215343.csv
# Processed and saved: Mateus_Messaros_Inacio_117225.csv
# Processed and saved: Yuri_The_Russian_Polar_Bear_Panferov_289931.csv
# Processed and saved: Jacobi_Big_Toe_Jones_326955.csv
# Processed and saved: Payton_Talbott_296553.csv
# Processed and saved: Jalin_The_Tarantula_Turner_158269.csv
# Processed and saved: Thiago_Vieira_129509.csv
# Processed and saved: Connor_Bad_News_Matthews_84660.csv
# Processed and saved: Taffarel_Brasil_227397.csv
# Processed and saved: Rizvan_Kuniev_86319.csv
# Processed and saved: Matthieu_Letho_Duclos_350789.csv
# Processed and saved: Manuel_El_Loco_Torres_297203.csv
# Processed and saved: Kasey_Tanner_160671.csv
# Processed and saved: Kevin_Szaflarski_202089.csv
# Processed and saved: Nikolay_Veretennikov_186789.csv
# Processed and saved: Angel_Pacheco_90675.csv
# Processed and saved: Kirill_Khomitsky_242517.csv
# Processed and saved: Dean_Trueman_61583.csv
# Processed and saved: Mike_Money_Breeden_243687.csv
# Processed and saved: Adrian_Diaz_54296.csv
# Processed and saved: T.J._Downtown_Brown_172347.csv
# Processed and saved: Raheam_Forest_250387.csv
# Processed and saved: Otari_Tanzilov_333455.csv
# Processed and saved: Jingliang_Li_26381.csv
# Processed and saved: Majdeddine_Ayadi_138965.csv
# Processed and saved: Talita_The_Problem_Child_Alencar_386905.csv
# Processed and saved: Herbert_The_Blaze_Burns_152211.csv
# Processed and saved: C.J._Vergara_72117.csv
# Processed and saved: Lucas_Almeida_191243.csv
# Processed and saved: Jonas_Jake_Bilharinho_70752.csv
# Processed and saved: Uros_The_Doctor_Medic_272505.csv
# Processed and saved: Joao_Alicate_Elias_133165.csv
# Processed and saved: Joao_Paulo_Silva_Santos_398940.csv
# Processed and saved: Steven_The_Ninja_Nguyen_121057.csv
# Processed and saved: Oscar_Bruno_Araujo_Alves_51572.csv
# Processed and saved: Mark_The_Pride_of_Bloomfield_Cherico_56202.csv
# Processed and saved: Erik_The_King_Silva_220027.csv
# Processed and saved: Nick_Compton_54059.csv
# Processed and saved: Pedro_Henrique_Queiroz_214039.csv
# Processed and saved: Caio_The_Natural_Borralho_188043.csv
# Processed and saved: Shonte_Shyne_Barnes_261479.csv
# Processed and saved: Daniel_D-Rod_Rodriguez_145945.csv
# Processed and saved: Mariya_Money_Mashka_Agapova_206861.csv
# Processed and saved: Antonio_Malvado_Trocoli_123109.csv
# Processed and saved: Erick_da_Silva_50122.csv
# Processed and saved: Muin_Tajik_Gafurov_182325.csv
# Processed and saved: Ofir_Zigdon_277443.csv
# Processed and saved: Cain_Lugar_151361.csv
# Processed and saved: Austin_Springer_41861.csv
# Processed and saved: Robson_Eufrasio_Lima_322605.csv
# Processed and saved: Jimmy_The_Brick_Flick_60460.csv
# Processed and saved: Gregory_Rodrigues_176275.csv
# Processed and saved: Ty_Flores_86350.csv
# Processed and saved: Fabio_Cherant_230293.csv
# Processed and saved: Nathan_Williams_187961.csv
# Processed and saved: Jordan_Bomaye_Williams_70941.csv
# Processed and saved: Dwight_The_Body_Snatcher_Grant_68983.csv
# Processed and saved: Leon_Soares_de_Deus_306901.csv
# Processed and saved: Carlos_Barbieri_234075.csv
# Processed and saved: Shaheen_Shazam_Santana_227431.csv
# Processed and saved: Shannon_MMA_Barbie_Clark_345497.csv
# Processed and saved: Dusko_Todorovic_207339.csv
# Processed and saved: Kaynan_Bahia_Kruschewsky_152747.csv
# Processed and saved: Renato_da_Silva_Jr._114609.csv
# Processed and saved: Alejandro_El_Gallito_Flores_155325.csv
# Processed and saved: Phil_The_Hitman_Caracappa_179073.csv
# Processed and saved: Gregg_Ellis_261065.csv
# Processed and saved: Sang_Hoon_The_Korean_Assassin_Yoo_246531.csv
# Processed and saved: Cesar_Almeida_217983.csv
# Processed and saved: Billy_Songthak_Brand_128455.csv
# Processed and saved: Collin_Lubberts_157381.csv
# Processed and saved: Trey_Manley_171581.csv
# Processed and saved: Ricky_Pretty_Turcios_80671.csv
# Processed and saved: Nick_Newell_59502.csv
# Processed and saved: Lucas_Fernando_227719.csv
# Processed and saved: Marcos_Conrado_Jr._234165.csv
# Processed and saved: Danilo_Maikuara_272683.csv
# Processed and saved: Darrick_Minner_92115.csv
# Processed and saved: Denis_Gvozdev_273249.csv
# Processed and saved: Omar_Morales_120645.csv
# Processed and saved: Dayana_Silva_38831.csv
# Processed and saved: Jose_Diaz_135209.csv
# Processed and saved: Andreas_Gustafsson_280041.csv
# Processed and saved: Adland_Benson_229465.csv
# Processed and saved: Ryder_Newman_280627.csv
# Processed and saved: Bill_Senor_Perfecto_Algeo_77441.csv
# Processed and saved: Leon_Aliu_224849.csv
# Processed and saved: Brendan_All_In_Allen_201703.csv
# Processed and saved: Mitchell_No_Dice_Sipe_208607.csv
# Processed and saved: Milko_Tucto_263669.csv
# Processed and saved: Ronald_Coleman_378849.csv
# Processed and saved: Javid_The_Snow_Leopard_Basharat_222651.csv
# Processed and saved: Dennis_Buzukja_286225.csv
# Processed and saved: Dorian_Ramos_203579.csv
# Processed and saved: Karl_Roberson_132605.csv
# Processed and saved: Christopher_Wingate_168025.csv
# Processed and saved: Montel_Quik_Jackson_206717.csv
# Processed and saved: Rico_DiSciullo_72881.csv
# Processed and saved: Hugo_Silverback_Cunha_227763.csv
# Processed and saved: Yousri_Baby_Face_Assassin_Belgaroui_380449.csv
# Processed and saved: Shanna_The_Shanimal_Young_126277.csv
# Processed and saved: Kennedy_American_Savage_Nzechukwu_212289.csv
# Processed and saved: Giga_Ninja_Chikadze_213745.csv
# Processed and saved: Chris_Sherley_Rios_97445.csv
# Processed and saved: Mitch_Ramirez_244107.csv
# Processed and saved: Erison_Fernandez_112481.csv
# Processed and saved: Sean_The_Unpredictable_One_Lally_44100.csv
# Processed and saved: Matias_Genes_169911.csv
# Processed and saved: Dylan_Big_Poppa_Potter_209025.csv
# Processed and saved: Michael_The_Don_Lombardo_217745.csv
# Processed and saved: Maycon_Silva_266459.csv
# Processed and saved: Malcolm_Walla_Wellmaker_277031.csv
# Processed and saved: Mo_Mo_Show_Miller_269847.csv
# Processed and saved: Hannah_24K_Goldy_204879.csv
# Processed and saved: Willyanedson_Paiva_177403.csv
# Processed and saved: Marcos_Ironside_Brigagao_258879.csv
# Processed and saved: Yorgan_The_Mad_Titan_De_Castro_176091.csv
# Processed and saved: Daniel_Nikbaht_315507.csv
# Processed and saved: Victor_Pacoca_Dias_232371.csv
# Processed and saved: Dennis_The_Great_Buzukja_286225.csv
# Processed and saved: Randall_Wallace_93103.csv
# Processed and saved: Nour__el_Din_Essam_113549.csv
# Processed and saved: Vinicius_Fenomeno_Salvador_179169.csv
# Processed and saved: Lois_Cadet_164601.csv
# Processed and saved: Reyes_Cortez_Jr._120303.csv
# Processed and saved: Igor_da_Silva_321087.csv
# Processed and saved: Claudiere_Freitas_23161.csv
# Processed and saved: Kyron_Mamba_Bowen_166817.csv
# Processed and saved: Chris_Duncan_74346.csv
# Processed and saved: Nick_Urso_52504.csv
# Processed and saved: Patricia_El_Angel_Alujas_218163.csv
# Processed and saved: Lauren_Princess_Tiger_Mueller_202159.csv
# Processed and saved: Willian_Kuraca_154765.csv
# Processed and saved: Bayan_Zheenbekov_394765.csv
# Processed and saved: Josh_Parisian_181225.csv
# Processed and saved: Blake_El_Animal_Bilder_179949.csv
# Processed and saved: Ronaldo_Lazy_Boy_Rodriguez_266121.csv
# Processed and saved: Willie_Tarpley_16466.csv
# Processed and saved: Shimon_Smotritsky_254075.csv
# Processed and saved: Joshua_Wide_Open_Weems_259641.csv
# Processed and saved: James_Dunn_205699.csv
# Processed and saved: Azamat_Murzakanov_60203.csv
# Processed and saved: Victor_Pereira_Neves_Nunes_352789.csv
# Processed and saved: Vladislav_Kozlovski_159043.csv
# Processed and saved: Julius_Anglickas_217105.csv
# Processed and saved: Chad_Hanekom_215519.csv
# Processed and saved: Bruno_Lopes_144007.csv
# Processed and saved: Christian_Rodriguez_303043.csv
# Processed and saved: Bin_The_Stalker_Xie_231979.csv
# Processed and saved: Austin_The_Flash_Tweedy_91337.csv
# Processed and saved: Chad_Big_Rig_Johnson_213687.csv
# Processed and saved: Oban_The_Welsh_Gangster_Elliott_247601.csv
# Processed and saved: Bruno_Korea_Mesquita_57480.csv
# Processed and saved: Lance_Lawrence_163663.csv
# Processed and saved: Charlie_Campbell_286213.csv
# Processed and saved: Alessandro_Nono_Costa_214613.csv
# Processed and saved: Victor_El_Magnifico_Altamirano_212269.csv
# Processed and saved: Rafael_Silva_de_Souza_204607.csv
# Processed and saved: Mikhail_Romanchuk_318017.csv
# Processed and saved: Flavio_Rodrigo_Magon_113267.csv
# Processed and saved: Alexey_Druzhinin_385341.csv
# Processed and saved: Luana_Dread_Carolina_189719.csv
# Processed and saved: Zach_Gods_Warrior_Zane_180829.csv
# Processed and saved: Anthony_Sugafoot_Adams_144983.csv
# Processed and saved: Mando_El_Toro_Gutierrez_280393.csv
# Processed and saved: Pedro_Pedrinho_Falcao_150185.csv
# Processed and saved: Paulo_Henrique_Laia_275067.csv
# Processed and saved: Rami_Aziz_55264.csv
# Processed and saved: Hussein_Salem_163541.csv
# Processed and saved: Gadzhimurad_Abdullaev_255775.csv
# Processed and saved: Daniel_James_Allen_339119.csv
# Processed and saved: Aaron_Phillips_280195.csv
# Processed and saved: Tommie_Britton_102311.csv
# Processed and saved: Jansey_Silva_145207.csv
# Processed and saved: Rodrigo_The_Dynamis_Lidio_182013.csv
# Processed and saved: Diogo_Cavalcanti_72804.csv
# Processed and saved: Antonio_Doomsday_Jones_127091.csv
# Processed and saved: Luan_Santiago_142651.csv
# Processed and saved: Reyes_Junior_Cortez_Jr._120303.csv
# Processed and saved: Grant_KGD_Dawson_103525.csv
# Processed and saved: Daniel_Soncora_Marcos_205313.csv
# Processed and saved: Kennedy_Nzechukwu_212289.csv
# Processed and saved: Vitor_Petrino_255313.csv
# Processed and saved: Carli_Crispy_Judice_381889.csv
# Processed and saved: Mailton_Azevedo_170423.csv
# Processed and saved: James_The_Phenom_Gray_Jr._139851.csv
# Processed and saved: Allan_Puro_Osso_Nascimento_87857.csv
# Processed and saved: Jose_Henrique_Souza_362437.csv
# Processed and saved: Brendson_Ribeiro_210539.csv
# Processed and saved: Ignacio_La_Jaula_Bahamondes_221417.csv
# Processed and saved: Charlie_Leary_58464.csv
# Processed and saved: Gauge_Gee_Money_Young_325407.csv
# Processed and saved: Ramon_The_Savage_Taveras_332055.csv
# Processed and saved: Bubba_Cruz_209483.csv
# Processed and saved: Josh_The_Juggernaut_Appelt_47983.csv
# Processed and saved: Ryan_Superman_Spann_68057.csv
# Processed and saved: Louis_Cosce_282403.csv
# Processed and saved: Michael_Cora_206353.csv
# Processed and saved: Paulo_Silva_89925.csv
# Processed and saved: Julian_Marquez_77743.csv
# Processed and saved: Domingo_Son_of_Fire_Pilarte_48495.csv
# Processed and saved: Kyle_Driscoll_115585.csv
# Processed and saved: Ashiek_Ajim_286217.csv
# Processed and saved: Jacob_Lil_Badger_Rosales_154819.csv
# Processed and saved: Martin_Day_155883.csv
# Processed and saved: Sarah_Too_Sweet_Alpar_82261.csv
# Processed and saved: Austin_The_Golden_Boy_Arnett_57016.csv
# Processed and saved: Arthur_Bunkov_381853.csv
# Processed and saved: Erick_Macias_280327.csv
# Processed and saved: Corinne_Laframboise_244989.csv
# Processed and saved: Michael_Deiga_Scheck_140117.csv
# Processed and saved: Allen_Pretty_Boy_Crowder_157353.csv
# Processed and saved: Logan_Urban_174025.csv
# Processed and saved: Jamie_Colleen_Miller_115211.csv
# Processed and saved: Malik_Hard_Knock_Lewis_183193.csv
# Processed and saved: Djorden_Shakur_Ribeiro_dos_Santos_164321.csv
# Processed and saved: Joseph_Luciano_228349.csv
# Processed and saved: Yousef_Al-Hamad_74731.csv
# Processed and saved: Zhifa_Dongbei_Flying_Tiger_Shang_103809.csv
# Processed and saved: Bogdan_The_Unleashed_Grad_156707.csv

# %%
import pandas as pd
import os

fighters_folder_path = 'data-dwcs/fighters/'

# Function to check if fighter has Cage Warriors or CW fights
def has_cage_warriors_fight(df):
    # Identify Cage Warriors fights by looking for "Cage Warriors" or "CW" in 'Event Name'
    cage_warriors_mask = df['Event Name'].str.contains('Cage Warriors|CW', case=False, na=False)
    return cage_warriors_mask.any()

# Initialize an empty DataFrame to collect all fighters' data
all_fighters_data = pd.DataFrame()

# Iterate through each file in the directory
for filename in os.listdir(fighters_folder_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(fighters_folder_path, filename)

        # Extract the fighter's name from the file name (assuming format: "First_Last_ID.csv")
        fighter_name = filename.rsplit('_', 1)[0].replace('_', ' ')

        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)

        # Check if the fighter has participated in a Cage Warriors or CW event
        if has_cage_warriors_fight(df):
            df = df.copy()  # Make an explicit copy to avoid warning
            df.loc[:, 'Fighter Name'] = fighter_name  # Add the fighter's name to the DataFrame
            # Append all of the fighter's data (not just filtered rows)
            all_fighters_data = pd.concat([all_fighters_data, df])

# Save the result to a CSV file if there are any valid fighters
if not all_fighters_data.empty:
    all_fighters_data.to_csv("Cage_Warriors_Results.csv", index=False)
    print("Data saved to Cage_Warriors_Results.csv.")
else:
    print("No fighters with Cage Warriors or CW fights found.")
# Out:
# Data saved to Cage_Warriors_Results.csv.

# %%
# !open Cage_Warriors_Results.csv

# %%
import pandas as pd
import plotly.express as px

# Load the results data
df = pd.read_csv('Cage_Warriors_Results.csv')

# Filter for DWCS fights only
dwcs_fights = df[df['Event Name'].str.contains('Dana White\'s Contender Series', case=False)]

# 1. Bar chart for Win vs. Loss using Plotly
win_loss_fig = px.bar(dwcs_fights, x='Result', color='Result',
                      title='Win vs. Loss Distribution in DWCS Fights for CW Fighters',
                      labels={'Result': 'Fight Result', 'count': 'Count'},
                      color_discrete_sequence=px.colors.diverging.Tealrose)

# Remove gridlines and ensure only whole numbers on y-axis
win_loss_fig.update_layout(
    xaxis=dict(tickmode='linear', tick0=0, dtick=1),  # Ensure whole numbers on x-axis
    yaxis=dict(showgrid=False),  # Remove y-axis gridlines
    xaxis_title='Fight Result',
    yaxis_title='Count',
    template='simple_white'  # Removes background gridlines
)

# Save the Win vs. Loss chart
win_loss_fig.write_image("win_loss_distribution.png")  # Save as PNG

# 2. Bar chart for Win Methods using Plotly

# Filter for wins only and make a copy to avoid SettingWithCopyWarning
dwcs_wins = dwcs_fights[dwcs_fights['Result'] == 'win'].copy()

# Extract the method by splitting at the first occurrence of '('
dwcs_wins['Win Method'] = dwcs_wins['Method/Referee'].apply(lambda x: x.split('(')[0].strip())

win_method_fig = px.bar(dwcs_wins, y='Win Method', orientation='h', 
                        title='Distribution of Win Methods in DWCS Fights',
                        labels={'Win Method': 'Win Method', 'count': 'Count'},
                        color='Win Method',
                        color_discrete_sequence=px.colors.sequential.Viridis)

# Remove gridlines and ensure only whole numbers on x-axis
win_method_fig.update_layout(
    yaxis=dict(showgrid=False),  # Remove y-axis gridlines
    xaxis=dict(tickmode='linear', tick0=0, dtick=1),  # Ensure whole numbers on x-axis
    xaxis_title='Count',
    yaxis_title='Win Method',
    template='simple_white'  # Removes background gridlines
)

# Save the Win Methods chart
win_method_fig.write_image("win_method_distribution.png")  # Save as PNG

# 3. Bar chart for Loss Methods using Plotly

# Filter for losses only and make a copy to avoid SettingWithCopyWarning
dwcs_losses = dwcs_fights[dwcs_fights['Result'] == 'loss'].copy()

# Extract the method by splitting at the first occurrence of '('
dwcs_losses['Loss Method'] = dwcs_losses['Method/Referee'].apply(lambda x: x.split('(')[0].strip())

loss_method_fig = px.bar(dwcs_losses, y='Loss Method', orientation='h', 
                         title='Distribution of Loss Methods in DWCS Fights',
                         labels={'Loss Method': 'Loss Method', 'count': 'Count'},
                         color='Loss Method',
                         color_discrete_sequence=px.colors.sequential.Magma)

# Remove gridlines and ensure only whole numbers on x-axis
loss_method_fig.update_layout(
    yaxis=dict(showgrid=False),  # Remove y-axis gridlines
    xaxis=dict(tickmode='linear', tick0=0, dtick=1),  # Ensure whole numbers on x-axis
    xaxis_title='Count',
    yaxis_title='Loss Method',
    template='simple_white'  # Removes background gridlines
)

# Save the Loss Methods chart
loss_method_fig.write_image("loss_method_distribution.png")  # Save as PNG
