# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from tqdm.notebook import tqdm
import warnings
import os
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, as_completed
import numpy as np
import re
import csv
from datetime import datetime
import glob
from xml.etree.ElementTree import fromstring 
import shutil

# %% [markdown]
# # Scrape DWCS Event URLs

# %%
import os, shutil
if os.path.exists('data-dwcs'):
    shutil.rmtree('data-dwcs')
os.makedirs('data-dwcs')

# %%
### Scrape DWCS Event URL's

# Initialize an empty list to store event URLs
event_urls = []

# The URL of the webpage containing DWCS events
url = "https://www.sherdog.com/organizations/Dana-Whites-Contender-Series-12411"

# Set User-Agent in headers
headers = {'User-Agent': 'Mozilla/5.0'}

# Fetch the webpage content
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the section containing the events
event_section = soup.find('div', {'id': 'events_list'})

if event_section:
    # Loop through each event and extract the URL
    for event in event_section.find_all('a', {'itemprop': 'url'}):
        event_url = event.get('href')
        full_url = f"https://www.sherdog.com{event_url}"
        event_urls.append(full_url)
    
    # Save the event URLs to a CSV file
    df = pd.DataFrame({'Event_URLs': event_urls})
    df.to_csv('./data-dwcs/DWCS_Event_URLs.csv', index=False)
    print("Scraped event URLs have been saved to 'DWCS_Event_URLs.csv'")
else:
    print("Could not find the event section. The webpage structure might have changed.")
# Out:
# Scraped event URLs have been saved to 'DWCS_Event_URLs.csv'

# %%
### Move Upcoming Bouts to a Different CSV file

# Read the CSV file
df = pd.read_csv('./data-dwcs/DWCS_Event_URLs.csv')

# List of URLs to delete
upcoming_event_urls = [
    # "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-2-102756",
    # "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-3-102757",
    # "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-4-102758",
    "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-5-102759",
    "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-6-102760",
    "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-7-102761",
    "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-8-102762",
    "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-9-102763",
    "https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-10-102764"
]

# Create a dataframe for the rows to delete
rows_to_delete = df[df['Event_URLs'].isin(upcoming_event_urls)]

# Create a dataframe for the remaining rows
remaining_rows = df[~df['Event_URLs'].isin(upcoming_event_urls)]

# Save the deleted rows to a new CSV
rows_to_delete.to_csv('./data-dwcs/DWCS_Upcoming_Event_URLs.csv', index=False)

# Save the remaining rows back to the original CSV
remaining_rows.to_csv('./data-dwcs/DWCS_Event_URLs.csv', index=False)

print("Deleted rows saved and modified CSV with remaining rows saved.")
# Out:
# Deleted rows saved and modified CSV with remaining rows saved.

# %% [markdown]
# # Scrape Past Event Data

# %%
### Main Event Data Loop

csv_path_fighter_ids = './data-dwcs/DWCS_Fighter_ID_Sherdog.csv'

# Set up headers to use in the request to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Read URLs from the CSV file
url_df = pd.read_csv('./data-dwcs/DWCS_Event_URLs.csv')
url_list = url_df['Event_URLs']

# Initialize tqdm with the total number of URLs
pbar = tqdm(total=len(url_list), desc="Scraping Progress")

# Iterate through the URLs and scrape data
for url_to_scrape in url_list:
    # Make the request
    response = requests.get(url_to_scrape, headers=headers)

    if response.status_code != 200:
        print(f"Failed to get the webpage. Status code: {response.status_code}")
        continue

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Your existing scraping code...
    event_name = soup.find('span', itemprop='name').text.strip()
    event_location = soup.find('span', itemprop='location').text.strip()
    event_date = soup.find('meta', itemprop='startDate').next_sibling.strip()

    fighter1_class = soup.find('div', class_='fighter left_side')
    fighter2_class = soup.find('div', class_='fighter right_side')
    fighter1 = fighter1_class.find('span', itemprop='name').text.strip()
    fighter2 = fighter2_class.find('span', itemprop='name').text.strip()

    weight_class = soup.find('span', class_='weight_class').text.strip()
    winning_fighter = fighter1

    winning_method_em = soup.find('em', string='Method').parent
    winning_method = winning_method_em.contents[2].strip()

    winning_round_em = soup.find('em', string='Round').parent
    winning_round = winning_round_em.contents[2].strip()

    winning_time_em = soup.find('em', string='Time').parent
    winning_time = winning_time_em.contents[2].strip()

    referee_em = soup.find('em', string='Referee').parent
    referee = referee_em.find('a').text.strip()
    # End of your existing scraping code
    
    ### Fighter IDs ###
    fighters = soup.find_all('div', class_='fighter')
    fighter1_url = fighters[0].find('a', itemprop='url')['href']
    fighter2_url = fighters[1].find('a', itemprop='url')['href']
    fighter1_id = (str(fighter1_url)).split('-')[-1]
    fighter2_id = (str(fighter2_url)).split('-')[-1]

    # Append Fighter IDs to existing CSV
    new_row_for_df2 = pd.DataFrame([
        {'Fighter': fighter1, 'Fighter_ID': fighter1_id},
        {'Fighter': fighter2, 'Fighter_ID': fighter2_id}
    ])
    
    if not os.path.exists(csv_path_fighter_ids):
        new_row_for_df2.to_csv(csv_path_fighter_ids, mode='w', index=False, header=True)
    else:
        new_row_for_df2.to_csv(csv_path_fighter_ids, mode='a', index=False, header=False)
#    new_row_for_df2.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', mode='a', header=False, index=False)
    ### End Fighter IDs

    # Store the data
    data_to_append = {
        'Event Name': event_name,
        'Event Location': event_location,
        'Event Date': event_date,
        'Fighter 1': fighter1,
        'Fighter 2': fighter2,
        'Weight Class': weight_class,
        'Winning Fighter': winning_fighter,
        'Winning Method': winning_method,
        'Winning Round': winning_round,
        'Winning Time': winning_time,
        'Referee': referee
    }

    # Save Data
    try:
        df = pd.read_csv('./data-dwcs/DWCS_Event_Data_Sherdog.csv')
    except FileNotFoundError:
        df = pd.DataFrame()

    df = pd.concat([df, pd.DataFrame([data_to_append])])
    df.to_csv('./data-dwcs/DWCS_Event_Data_Sherdog.csv', index=False)
    
    # Update the progress bar
    pbar.update(1)

# Close the progress bar
pbar.close()

print("Scraping completed and data saved.")
# Out:
# Scraping Progress:   0%|          | 0/73 [00:00<?, ?it/s]
# Scraping completed and data saved.

# %%
### Other Bout Data Loop

# Read URLs from the CSV file
url_df = pd.read_csv('./data-dwcs/DWCS_Event_URLs.csv')
url_list = url_df['Event_URLs']

# Initialize tqdm with the total number of URLs
pbar = tqdm(total=len(url_list), desc="Scraping Progress")

# Iterate through the URLs and scrape data
for url_to_scrape in url_list:
    # Make the request
    response = requests.get(url_to_scrape, headers=headers)

    if response.status_code != 200:
        print(f"Failed to get the webpage. Status code: {response.status_code}")
        continue

    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Scrape the Other Bout Data
    rows = soup.find_all('tr', itemprop='subEvent')
    for row in rows:
        fighters = row.find_all('div', class_='fighter_list')
        fighter1 = fighters[0].find('img')['title']
        fighter2 = fighters[1].find('img')['title']

        weight_class = soup.find('span', class_='weight_class').text.strip()

        winning_method = row.find('td', class_='winby').find('b').get_text(strip=True)

        winning_round = row.find_all('td')[-2].get_text(strip=True)
        winning_time = row.find_all('td')[-1].get_text(strip=True)

        referee = row.find('td', class_='winby').find('a').get_text(strip=True)

        ### Fighter IDs ###
        fighter1_url = fighters[0].find('a', itemprop='url')['href']
        fighter2_url = fighters[1].find('a', itemprop='url')['href']
        fighter1_id = (str(fighter1_url)).split('-')[-1]
        fighter2_id = (str(fighter2_url)).split('-')[-1]

        # Append Fighter IDs to existing CSV
        new_row_for_df2 = pd.DataFrame([
            {'Fighter': fighter1, 'Fighter_ID': fighter1_id},
            {'Fighter': fighter2, 'Fighter_ID': fighter2_id}
        ])
        new_row_for_df2.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', mode='a', header=False, index=False)
        ### End Fighter IDs

        # Store the Data for Other Bouts
        data_to_append = {
            'Event Name': event_name,  # Replace with actual data
            'Event Location': event_location,  # Replace with actual data
            'Event Date': event_date,  # Replace with actual data
            'Fighter 1': fighter1,
            'Fighter 2': fighter2,
            'Weight Class': weight_class,
            'Winning Fighter': fighter1,  # You might need to adjust this based on the winning fighter
            'Winning Method': winning_method,
            'Winning Round': winning_round,
            'Winning Time': winning_time,
            'Referee': referee
        }
        
        # Append the new row directly to the existing CSV
        new_row = pd.DataFrame([data_to_append])
        new_row.to_csv('./data-dwcs/DWCS_Event_Data_Sherdog.csv', mode='a', header=False, index=False)
        
    print("Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv")
    
    # Update the progress bar
    pbar.update(1)

# Close the progress bar
pbar.close()

print("Scraping completed and data saved.")
# Out:
# Scraping Progress:   0%|          | 0/73 [00:00<?, ?it/s]
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Other Bout Data Saved to DWCS_Event_Data_Sherdog.csv
# Scraping completed and data saved.

# %% [markdown]
# # Scrape Upcoming Event Data

# %%
### Upcoming Main Event Data

# Set up headers to use in the request to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Read the CSV file with Event URLs, skipping the header row
url_df = pd.read_csv('./data-dwcs/DWCS_Upcoming_Event_URLs.csv')  # Replace with the actual path
event_url = url_df.iloc[0, 0]
print(f"Processing URL: {event_url}")  # Print the URL you're processing

if not url_df.empty:
    # Get the URL from the first row
    event_url = url_df.iloc[0, 0]

    # Make the request
    response = requests.get(event_url, headers=headers)

    # Check the status code of the response
    if response.status_code != 200:
        print(f"Failed to get the webpage. Status code: {response.status_code}")
    else:
        # Parse the HTML using BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        event_name = soup.find('span', itemprop='name').text.strip()
        event_location = soup.find('span', itemprop='location').text.strip()
        event_date = soup.find('meta', itemprop='startDate').next_sibling.strip()

        fighter1_class = soup.find('div', class_='fighter left_side')
        fighter2_class = soup.find('div', class_='fighter right_side')
        fighter1 = fighter1_class.find('span', itemprop='name').text.strip()
        fighter2 = fighter2_class.find('span', itemprop='name').text.strip()

        weight_class = soup.find('span', class_='weight_class').text.strip()
        
#         winning_fighter = fighter1
#         winning_method_em = soup.find('em', string='Method').parent
#         winning_method = winning_method_em.contents[2].strip()
#         winning_round_em = soup.find('em', string='Round').parent
#         winning_round = winning_round_em.contents[2].strip()
#         winning_time_em = soup.find('em', string='Time').parent
#         winning_time = winning_time_em.contents[2].strip()

#         referee_em = soup.find('em', string='Referee').parent
#         referee = referee_em.find('a').text.strip()
        
        ### Fighter IDs ###
        fighters = soup.find_all('div', class_='fighter')
        fighter1_url = fighters[0].find('a', itemprop='url')['href']
        fighter2_url = fighters[1].find('a', itemprop='url')['href']
        fighter1_id = (str(fighter1_url)).split('-')[-1]
        fighter2_id = (str(fighter2_url)).split('-')[-1]

        # Append Fighter IDs to existing CSV
        new_row_for_df2 = pd.DataFrame([
            {'Fighter': fighter1, 'Fighter_ID': fighter1_id},
            {'Fighter': fighter2, 'Fighter_ID': fighter2_id}
        ])
        new_row_for_df2.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', mode='a', header=False, index=False)
        ### End Fighter IDs

        # Store the data
        data_to_append = {
            'Event Name': event_name,
            'Event Location': event_location,
            'Event Date': event_date,
            'Fighter 1': fighter1,
            'Fighter 2': fighter2,
            'Weight Class': weight_class,
#             'Winning Fighter': winning_fighter,
#             'Winning Method': winning_method,
#             'Winning Round': winning_round,
#             'Winning Time': winning_time,
#             'Referee': referee
        }

        # Save Data
        try:
            df = pd.read_csv('./data-dwcs/DWCS_Upcoming_Event_Data_Sherdog.csv')
        except FileNotFoundError:
            df = pd.DataFrame()

        df = pd.concat([df, pd.DataFrame([data_to_append])])
        df.to_csv('./data-dwcs/DWCS_Upcoming_Event_Data_Sherdog.csv', index=False)
        print("Main Event Data Saved to DWCS_Upcoming_Event_Data_Sherdog.csv")
else:
    print("CSV file is empty.")
# Out:
# Processing URL: https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-5-102759
# Main Event Data Saved to DWCS_Upcoming_Event_Data_Sherdog.csv

# %%
### Upcoming Other Bout Data

# Set up headers to use in the request to mimic a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Read the CSV file with Event URLs, skipping the header row
url_df = pd.read_csv('./data-dwcs/DWCS_Upcoming_Event_URLs.csv')  # Replace with the actual path
event_url = url_df.iloc[0, 0]
print(f"Processing URL: {event_url}")  # Print the URL you're processing

# Make the request
response = requests.get(event_url, headers=headers)

# Check the status code of the response
if response.status_code != 200:
    print(f"Failed to get the webpage. Status code: {response.status_code}")
else:
    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Scrape the Other Bout Data
    rows = soup.find_all('tr', itemprop='subEvent')
    for row in rows:
        fighters = row.find_all('div', class_='fighter_list')
        fighter1 = fighters[0].find('img')['title']
        fighter2 = fighters[1].find('img')['title']

        weight_class = soup.find('span', class_='weight_class').text.strip()

#         winning_method = row.find('td', class_='winby').find('b').get_text(strip=True)
#         winning_round = row.find_all('td')[-2].get_text(strip=True)
#         winning_time = row.find_all('td')[-1].get_text(strip=True)
#         referee = row.find('td', class_='winby').find('a').get_text(strip=True)

        ### Fighter IDs ###
        fighter1_url = fighters[0].find('a', itemprop='url')['href']
        fighter2_url = fighters[1].find('a', itemprop='url')['href']
        fighter1_id = (str(fighter1_url)).split('-')[-1]
        fighter2_id = (str(fighter2_url)).split('-')[-1]

        # Append Fighter IDs to existing CSV
        new_row_for_df2 = pd.DataFrame([
            {'Fighter': fighter1, 'Fighter_ID': fighter1_id},
            {'Fighter': fighter2, 'Fighter_ID': fighter2_id}
        ])
        new_row_for_df2.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', mode='a', header=False, index=False)
        ### End Fighter IDs

        # Store the Data for Other Bouts
        data_to_append = {
            'Event Name': event_name,  # Replace with actual data
            'Event Location': event_location,  # Replace with actual data
            'Event Date': event_date,  # Replace with actual data
            'Fighter 1': fighter1,
            'Fighter 2': fighter2,
            'Weight Class': weight_class,
#             'Winning Fighter': fighter1,  # You might need to adjust this based on the winning fighter
#             'Winning Method': winning_method,
#             'Winning Round': winning_round,
#             'Winning Time': winning_time,
#             'Referee': referee
        }
        
        # Append the new row directly to the existing CSV
        new_row = pd.DataFrame([data_to_append])
        new_row.to_csv('./data-dwcs/DWCS_Upcoming_Event_Data_Sherdog.csv', mode='a', header=False, index=False)
        
    print("Other Bout Data Saved to DWCS_Upcoming_Event_Data_Sherdog.csv")
# Out:
# Processing URL: https://www.sherdog.com/events/Dana-Whites-Contender-Series-Contender-Series-2024-Week-5-102759
# Other Bout Data Saved to DWCS_Upcoming_Event_Data_Sherdog.csv

# %% [markdown]
# # Scrape General Fighter Data

# %%
### Create DWCS_Fighter_Info.csv

# Define the column names
column_names = ['Fighter', 'Nickname', 'Height', 'Weight', 'Reach', 'Stance', 'Win_KO', 'Win_Sub', 'Win_Dec', 'Loss_KO', 'Loss_Sub', 'Loss_Dec', 'Sherdog URL']

# Create an empty DataFrame with the specified column names
df_empty = pd.DataFrame(columns=column_names)

# Define the file path
file_path = './data-dwcs/DWCS_Fighter_Info.csv'

# Write the empty DataFrame to the CSV file
df_empty.to_csv(file_path, index=False)

# %%
## Scrape data from fighter page

def scrape_fighter_general_info_sherdog(fighter, soup):
    
    fighter_dict = {}

    ## Fighter Data
    try:
        fighter_data = soup.find('div', class_='fighter-data')
    except AttributeError:
        fighter_data = None
        
    ## Birth Date
    try:
        birthdate = soup.find('span', itemprop='birthDate')
        birthdate = (birthdate.text).strip('""')
    except AttributeError:
        birthdate = '-'
    
    ## Nationality
    try:
        nationality = soup.find('strong', itemprop='nationality')
        nationality = (nationality.text).strip()
    except AttributeError:
        nationality = '-'
        
    ## Hometown
    try:
        hometown = soup.find('span', {'itemprop': 'addressLocality'}).text
        hometown = hometown.strip()
    except AttributeError:
        hometown = '-'
        
    ## Association
    try:
        association = soup.find('span', {'itemprop': 'name'}).text
        association = association.strip()
    except AttributeError:
        association = '-'
        
    ## Weight Class
    try:
        weight_class_div = fighter_data.find('div', {'class': 'association-class'})
        links = weight_class_div.find_all('a')
        weight_class = links[-1].text
        weight_class = weight_class.strip()
    except AttributeError:
        weight_class = ''
    except IndexError:
        weight_class = ''
        
    ## Nickname
    try:
        nickname = soup.find('span', class_='nickname')
        nickname = (nickname.text).strip('"')
    except AttributeError:
        nickname = '-'

    ## Height
    try:
        height = soup.find('b', itemprop='height')
        height = (height.text).strip('"')
    except AttributeError:
        height = '-'

    ## Wins
    try:
        wins = soup.find('div', class_='winloses win').find_all('span')[1]
        wins = (wins.text).strip()
    except AttributeError:
        wins = '-'

    ## Losses
    try:
        losses = soup.find('div', class_='winloses lose').find_all('span')[1]
        losses = (losses.text).strip()
    except AttributeError:
        losses = '-'

    ## Decisions
    dec_data_list = []
    try:
        win_type = fighter_data.find_all('div', class_='meter-title', string='DECISIONS')
        for method in win_type:
            if method.text.startswith('DECISIONS'):
                dec_data = method.find_next('div', class_='pl').text
                dec_data_list.append(dec_data)
        wins_dec = (dec_data_list[0]).strip()
        losses_dec = (dec_data_list[1]).strip()
    except (AttributeError, IndexError):
        wins_dec = '-'
        losses_dec = '-'

    ## Knockouts
    ko_data_list = []
    try:
        win_type = soup.find_all('div', class_='meter-title')
        for method in win_type:
            if method.text.startswith('KO'):
                ko_data = method.find_next('div', class_='pl').text
                ko_data_list.append(ko_data)
        wins_ko = (ko_data_list[0]).strip()
        losses_ko = (ko_data_list[1]).strip()
    except (AttributeError, IndexError):
        wins_ko = '-'
        losses_ko = '-'

    ## Submissions
    sub_data_list = []
    try:
        win_type = fighter_data.find_all('div', class_='meter-title', string='SUBMISSIONS')
        for method in win_type:
            if method.text.startswith('SUBMISSIONS'):
                sub_data = method.find_next('div', class_='pl').text
                sub_data_list.append(sub_data)
        wins_sub = (sub_data_list[0]).strip()
        losses_sub = (sub_data_list[1]).strip()
    except (AttributeError, IndexError):
        wins_sub = '-'
        losses_sub = '-'

    ## Store the Data
    fighter_dict = {
        'Fighter': fighter,
        'Nickname': nickname,
        'Birth Date': birthdate,
        'Nationality': nationality,
        'Hometown': hometown,
        'Association': association,
        'Weight Class': weight_class,
        'Height': height,
        'Wins': wins,
        'Losses': losses,
        'Win_Decision': wins_dec,
        'Win_KO': wins_ko,
        'Win_Sub': wins_sub,
        'Loss_Decision': losses_dec,
        'Loss_KO': losses_ko,
        'Loss_Sub': losses_sub
    }
    
    df = pd.read_csv('./data-dwcs/DWCS_Fighter_Info.csv')
    new_data = pd.DataFrame([fighter_dict]) # Convert fighter_dict to a DataFrame before using pd.concat
    df = pd.concat([df, new_data], ignore_index=True) 
    df.to_csv('./data-dwcs/DWCS_Fighter_Info.csv', index=False)

# %%
## Loop through fighter pages

def scrape_fighter_general_info_sherdog_loop():
    # Ignore warnings
    warnings.filterwarnings("ignore", category=FutureWarning)

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    df_fighter_id = pd.read_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv')

    urls = []  # List to store the generated URLs

    for index, row in tqdm(df_fighter_id.iterrows(), total=df_fighter_id.shape[0],
                           bar_format="{desc}: {percentage:3.0f}%|{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}, {postfix}]"):

        fighter = row['Fighter']
        print(fighter)
        # Split fighter name
        fighter_split = row['Fighter'].split()
        # Assign the first and second words to first_name and last_name
        first_name = fighter_split[0]
        last_name = fighter_split[1] if len(fighter_split) > 1 else ''
        # Get fighter ID for sherdog
        fighter_id = row['Fighter_ID']
        # Form URL
        url = f'https://www.sherdog.com/fighter/{first_name}-{last_name}-{fighter_id}'
        urls.append(url)  # Store the generated URL in the list
        # Get response from URL
        response = requests.get(url, headers=headers)
        # Check if the URL is valid
        if response.status_code != 200:
            print("URL is not valid or the request was unsuccessful.")
            print(row)
            continue  # skip to the next iteration

        soup = BeautifulSoup(response.content, 'html.parser')
        scrape_fighter_general_info_sherdog(fighter, soup)

    # Create a new DataFrame to store the URLs
    df_urls = pd.DataFrame({'Sherdog URL': urls})

    # Read the existing DWCS_Fighter_Info.csv file (if it exists)
    try:
        df_existing = pd.read_csv('./data-dwcs/DWCS_Fighter_Info.csv')
        # Merge the existing DataFrame with the new URLs DataFrame based on the index
        df_combined = pd.concat([df_existing, df_urls], axis=1)
    except FileNotFoundError:
        df_combined = df_urls  # Use only the new URLs DataFrame if the file doesn't exist

    # Write the combined DataFrame to the DWCS_Fighter_Info.csv file
    df_combined.to_csv('./data-dwcs/DWCS_Fighter_Info.csv', index=False)
    

    
## Call the Function
## BUGS
## Making new column Sherdog URL even if it exists
scrape_fighter_general_info_sherdog_loop()
# Out:
#   0%|          | 0/730 [00:00<?, ]
# Seok Hyun Ko
# Igor Cavalcanti
# Andrey Pulyaev
# Liam Anderson
# Andreas Gustafsson
# Pat Pytlik
# Mansur Abdul-Malik
# Wesley Schultz
# Ramon Taveras
# Cortavious Romious
# Rodolfo Bellato
# Murtaza Talha Ali
# Danny Barlow
# Raheam Forest
# Shamil Gaziev
# Greg Velasco
# James Llontop
# Malik Lewis
# Brendson Ribeiro
# Bruno Lopes
# Carlos Prates
# Mitch Ramirez
# Zachary Reese
# Eli Aronov
# Abdul-Kareem Al-Selwady
# George Hardwick
# Cesar Almeida
# Lucas Fernando
# Bo Nickal
# Donovan Beard
# Brunno Ferreira
# Leon Aliu
# Farid Basharat
# Allan Begosso
# Vitor Petrino
# Rodolfo Bellato
# Yusaku Kinoshita
# Jose Henrique Souza
# Mick Parkin
# Eduardo Neves
# Esteban Ribovics
# Thomas Paull
# Bo Nickal
# Zachary Borrego
# Chris Duncan
# Charlie Campbell
# Joe Pyfer
# Osman Diaz
# Maheshate Hayisaer
# Achilles Estremadura
# Gadzhi Omargadzhiev
# Jansey Silva
# Jonny Parsons
# Solomon Renfro
# Christian Rodriguez
# Reyes Cortez Jr.
# Mike Malott
# Shimon Smotritsky
# Ihor Potieria
# Lukasz Sudolski
# A.J. Dobson
# Hashem Arkhagha
# Jailton Almeida
# Nasrudin Nasrudinov
# Josh Quinlan
# Logan Urban
# Azamat Murzakanov
# Matheus Scheffel
# J.P. Buys
# Jacob Silva
# Mario Filipe de Sousa
# Mariusz Ksiazkiewicz
# Carlos Ulberg
# Bruno Oliveira
# Jordan Williams
# Gregory Rodrigues
# Tafon Nchukwi
# Al Matavao
# Melsik Baghdasaryan
# Dennis Buzukja
# Jamie Pickett
# Jhonoven Pati
# Louis Cosce
# Victor Reyna
# Dustin Stoltzfus
# Joe Pyfer
# Dustin Jacoby
# Ty Flores
# Dusko Todorovic
# Teddy Ash
# Philip Rowe
# Leon Shahbazyan
# William Knight
# Herdem Alacabek
# Omar Morales
# Harvey Park
# Aleksa Camur
# Fabio Cherant
# Ramazan Kuramagomedov
# Jordan Williams
# Antonio Arroyo
# Stephen Regman
# Joe Solecki
# James Wallace
# Tony Johnson
# Alton Cunningham
# Punahele Soriano
# Jamie Pickett
# Gisele Moreira
# Dayana Silva
# Marcio Alexandre Jr.
# Leonardo Silva
# Sarah Frota
# Maiara Amanajas dos Santos
# Greg Hardy
# Tebaris Gordon
# Roosevelt Roberts
# Garrett Gross
# Alex Munoz
# Nick Newell
# Maycee Barber
# Jamie Colleen Miller
# Kevin Aguilar
# Joey    Gomez
# Antonina Shevchenko
# Jaimelene Nievera
# Matt Sayles
# Yazan Hajeh
# Alonzo Menifield
# Dashawn Boatwright
# Matt Frevola
# Jose Flores
# Kennedy Nzechukwu
# Anton Berzin
# Charles Byrd
# Randall Wallace
# Mike Rodriguez
# Jamelle Jones
# Julian Marquez
# Phil Hawes
# Karl Roberson
# Ryan Spann
# Dan Spohn
# Angel DeAnda
# Kurt Holobaugh
# Matt Bessette
# Djorden 'Shakur' Ribeiro dos Santos
# Will 'Drago' Currie
# Austin Bashi
# Dorian Ramos
# Yuneisy Duben
# Shannon 'MMA Barbie' Clark
# Quillan Salkilld
# Gauge 'Gee Money' Young
# Bogdan 'The Unleashed' Grad
# Michael 'The Texas Kid' Aswell
# Marco 'Matuto' Tulio
# Matthieu Letho Duclos
# Malcolm 'Walla' Wellmaker
# Adam 'Samurai' Bramhald
# Nick Piccininni
# Jack 'The Fury' Duffy
# Rizvan Kuniev
# Hugo 'Silverback' Cunha
# Cortavious 'Are You Not Entertained?' Romious
# Michael Imperato
# Torrez 'The Punisher' Finney
# Cameron 'Cam Van Damme' Rowston
# Cody Haddon
# Billy 'Songthak' Brand
# Rami 'The Russian' Hamed
# Meng 'Ruthless Assassin' Ding
# Bruno 'Brunao' Lopes
# Mikheil Sazhiniani
# Jose Delgado
# Ernie 'Young Titan' Juarez
# Lone'er Kavanagh
# An Tuan 'The Highlight' Ho
# Andre 'Mascote' Lima
# Rickson Thai 'The King' Zenidim Bueno
# Connor 'Bad News' Matthews
# Jair 'Chosen' Farias
# Torrez 'The Punisher' Finney
# Yuri 'The Russian Polar Bear' Panferov
# Marquel Mederos
# Issa Isakov
# Lucas 'Fenomeno' Rocha
# Davi 'O Black' Bittencourt
# Victor Hugo 'Striker' Silva
# Eduardo 'Cyborg' Torres Cant
# Magomed 'Mohammed Haji' Gadzhiyasulov
# Jose 'Chicho' Medina
# Mauricio Ruffy
# Raimond Magomedaliev
# Mario Piazzon
# Alexander Soldatkin
# Danny 'Puma' Silva
# Angel Pacheco
# Ernesta 'Heavy-Handed' Kareckaite
# Carli 'Crispy' Judice
# Vinicius 'LokDog' Oliveira
# Victor 'Periquito' Madrigal
# Daniel James Allen
# Jacobi 'Big Toe' Jones
# Stephanie 'Rondinha' Luciano
# Talita 'The Problem Child' Alencar
# Kaynan 'Bahia' Kruschewsky
# Dylan 'The Quiet Man' Mantello
# Igor da Silva
# Jhonata Silva
# Jhonata Diniz
# Eduardo 'Bbzao' Neves
# Steven 'The Ninja' Nguyen
# A.J. 'The Savage' Cunningham
# Julia Polastri
# Patricia 'El Angel' Alujas
# Jean Matsumoto
# Kasey Tanner
# Serhiy Sidey
# Ramon 'The Savage' Taveras
# Dylan 'The Mindless Hulk' Budka
# Chad 'Superman' Hanekom
# Jean 'Lord' Silva
# Kevin 'El Chino' Vallejos
# Dione 'The Witch' Barbosa
# Rainn 'Drop' Guerrero
# Marco 'Matuto' Tulio
# Yousri 'Baby Face Assassin' Belgaroui
# Timothy 'Twilight Timmy' Cuamba
# Mateo Alejandro Vogel
# Thomas 'The Train' Petersen
# Chandler 'The Hammer' Cole
# Bolaji 'The Zulu Warrior' Oki
# Dylan Salvador
# Oban 'The Welsh Gangster' Elliott
# Kaik Brito
# Josefine 'Little Thunder' Lindgren Knutsson
# Isis 'Fight Queen' Verbeek
# Luis 'Corazon de Leon' Pajuelo
# Robbie 'Razor' Ring
# Ibo 'The Last Ottoman' Aslan
# Paulo Renato Jr.
# Hyder 'The Hurricane' Amil
# Emrah 'The Anatolian Wolf' Sonmez
# Eduarda 'Ronda' Moura
# Janaina 'Jana Popozinha' Silva
# Charalampos 'Pampos' Grigoriou
# Cameron 'The Baby-Faced Killer' Smotherman
# Tom 'Big Train' Nolan
# Bogdan 'The Unleashed' Grad
# Caio 'Bigfoot' Machado
# Kevin Szaflarski
# Payton Talbott
# Reyes 'Junior' Cortez Jr.
# Kevin 'El Gallo Negro' Borjas
# Victor 'Pacoca' Dias
# Sam 'The Future' Patterson
# Vinicius 'Chambinho' Sacchelli Cenci
# Jack 'Phar' Jenkins
# Emiliano 'Golden Bull' Linares
# Rafael 'Macapa' Estevam
# Joao 'Alicate' Elias
# Mateus 'Bocao' Mendonca
# Ashiek Ajim
# Raul 'El Nino Problema' Rosas Jr.
# Mando 'El Toro' Gutierrez
# Austen Lane
# Richard Jacobi
# Nurullo 'Tajik Eagle' Aliev
# Josh 'The White Mamba' Wick
# Jafel 'Pastor' Filho
# Roybert 'The Unbroken' Echeverria
# Ikram Aliskerov
# Mario Filipe 'Coracao Valente' de Sousa
# Trevor Peek
# Malik 'Hard Knock' Lewis
# Bruna 'The Special One' Brasil
# Marnic 'The Sawed-Off Savage' Mann
# Daniel 'Soncora' Marcos
# Brandon 'Superman' Lewis
# Gabriel 'Marretinha' Bonfim
# Trey 'The Truth' Waters
# Karl Williams
# Jimmy 'Greedy' Lawson
# Ismael 'Marreta' Bonfim
# Nariman Abbasov
# Tereza Bleda
# Nayara Arnault Maia Correia
# Sedriques 'The Reaper' Dumas
# Matej 'Money' Penaz
# Mateusz 'Chinczyk' Rebecki
# Rodrigo 'The Dynamis' Lidio
# Victoria Dudakova
# Maria 'Viuva Negra' Silva
# Blake 'El Animal' Bilder
# Alex 'The Chess Master' Morgan
# Darrius 'Beast Mode' Flowers
# Amiran 'The Sniper' Gogoladze
# Jesus Santos Aguilar
# Erisson 'Gato' Ferreira
# Cameron Saaiman
# Josh Wang Kim
# Denise Gomes
# Rayanne dos Santos
# Claudio Ribeiro
# Ivan 'Bam Bam' Valenzuela
# Jose 'No Way' Johnson
# Jack Cartwright
# Hailey 'All Hail' Cowan
# Claudia Leite
# Nazim 'Black Wolf' Sadykhov
# Ahmad Sohail 'Lion of the Ring' Hassanzada
# Jamal 'The Stormtrooper' Pogues
# Paulo Renato Jr.
# Erik 'The King' Silva
# Anvar 'The Uzbek' Boynazarov
# Clayton Carpenter
# Edgar 'Puro Chicali' Chairez
# Karolina 'Polish Assassin' Wojcik
# Sandra 'Peruvian Zombie' Lavado
# Vinicius 'Fenomeno' Salvador
# Shannon 'The Turkish Delight' Ross
# Francis 'Fire' Marshall
# Connor 'Bad News' Matthews
# Waldo 'Salsa Boy' Cortes-Acosta
# Danilo 'Dan' Suzart
# Billy Goff
# Shimon 'Assassin' Smotritsky
# Anton 'The Pleasure Man' Turkalj
# Acacio 'Pequeno' dos Santos
# Dennis 'The Great' Buzukja
# Kaleio 'K.O.' Romero
# Alessandro 'Nono' Costa
# Juan Andres Luna Martinetti
# Yohan 'White Lion' Lainesse
# Justin Burlinson
# Erisson 'Gato' Ferreira
# Lun 'Tibetan Knight' Qiu
# Jonas 'Jake' Bilharinho
# Canaan Kawaihae
# Juan 'Leadfeather' Puerta
# Zhifa 'Dongbei Flying Tiger' Shang
# Cristian 'El Nino Problema' Quinonez
# Long Xiao
# Javid 'The Snow Leopard' Basharat
# Oron Kahlon
# Karine 'Killer' Silva
# Qihui 'Queen Kong' Yan
# Manuel 'El Loco' Torres
# Kolton 'The White Assassin' Englund
# Olivier 'Warrior of God' Murad
# Bin 'The Stalker' Xie
# Piera 'La Fiera' Rodriguez
# Valesca 'Tina Black' Machado
# Caio 'The Natural' Borralho
# Jesse 'Hollywood' Murray
# Armen 'Superman' Petrosyan
# Kaloyan Kolev
# Pedro 'Pedrinho' Falcao
# James 'Mooka' Barnes
# Martin 'Badys' Buday
# Lorenzo 'The Dream Killer' Hood
# Jake 'White Kong' Hadley
# Mitch Raposo
# Viacheslav 'Slava' Borshchev
# Chris 'The Problem' Duncan
# Maria 'Viuva Negra' Silva
# Kathryn Paprocki
# Carlos Hernandez
# Daniel Barez
# Fernie Garcia
# Joshua 'Wide Open' Weems
# Joseph 'Ugly Man' Holmes
# Shonte 'Shyne' Barnes
# Genaro 'Rayadito' Valdez
# Patrik 'Primetime' White
# Caio 'The Natural' Borralho
# Aaron Jeffery
# Daniel 'Golden Boy' Zellhuber
# Lucas Almeida
# Rizvan Kuniev
# Edivan 'Pe de Sapo' Santos
# Michael Morales
# Nikolay Veretennikov
# Steven 'The Ninja' Nguyen
# Theo Rlayang
# Kleydson 'K.R.' Rodrigues
# Santo Curatolo
# Victor 'The Brick' Martinez
# Jacob 'Lil' Badger' Rosales
# Mo 'Mo Show' Miller
# Brandon 'Superman' Lewis
# Albert 'Machete' Duraev
# Caio 'Leao' Bitencourt
# Lukasz Brzeski
# Dylan 'Big Poppa' Potter
# Jack Della Maddalena
# Ange 'The Last Ninja' Loosa
# Jasmine Jasudavicius
# Julia Polastri
# Chidi 'Chidi Bang Bang' Njokuani
# Mario Filipe 'Coracao Valente' de Sousa
# Saimon Oliveira
# Jose 'El Pochito' Alday
# C.J. Vergara
# Bruno 'Korea' Mesquita
# Chad 'The Monster' Anheliger
# Muin 'Tajik' Gafurov
# Joanderson 'Tubarao' Brito
# Diego Lopes
# Victor 'El Magnifico' Altamirano
# Carlos 'The Cannon' Candelario
# A.J. 'The Ghost' Fletcher
# Leonardo 'Ram' Damiani
# Nick Maximov
# Oscar 'Elevation' Cota
# Gloria 'Glorinha' de Paula
# Pauline 'Pita' Macias
# Tucker 'Top Gun' Lutz
# Sherrard 'The Savage' Blackledge
# Victoria 'Fury' Leonardo
# Chelsea 'Hammer' Hackett
# Natan 'Lethal' Levy
# Shaheen 'Shazam' Santana
# Nikolas 'Iron' Motta
# Joseph Lowry
# Luana Pinheiro
# Stephanie 'Macaquinha' Frausto
# Danny 'The Italian Gangster' Sabatello
# Taylor Moore
# Ignacio 'La Jaula' Bahamondes
# Edson Gomez
# Luis Saldana
# Vince Murdock
# Jared 'The Mountain' Vanderaa
# Harry 'The Hurricane' Hunsucker
# Collin Anglin
# Muhammadjon 'Hillman' Naimov
# Michael 'The Don' Lombardo
# Korey Kuppe
# Danyelle Wolf
# Taneisha 'Triple Threat' Tennant
# Kyle Driscoll
# Dinis 'Sweetbread' Paiva
# Sherrard 'The Savage' Blackledge
# Cameron Church
# Phil 'No Hype' Hawes
# Khadzhimurat Bestaev
# Drako 'The Great Drakolini' Rodriguez
# Leomana 'Manaboi' Martinez
# Aliaskhab Khizriev
# Henrique Shiguemoto
# Jimmy 'The Brick' Flick
# Nate 'The Savage' Smith
# Ronnie 'The Heat' Lawrence
# Jose 'No Way' Johnson
# William 'Knightmare' Knight
# Cody Brundage
# Tucker 'Top Gun' Lutz
# Chase 'El Guero' Gibson
# Rafael 'The Turn' Alves
# Alejandro 'El Gallito' Flores
# Jeff 'El Jefe' Molina
# Jacob 'Lil' Animal' Silva
# Anthony 'The Genius' Romero
# Mike 'Money' Breeden
# Collin 'Huck Wild' Huckbody
# Kyron 'Mamba' Bowen
# Cheyanne 'The Warrior Princess' Vlismas
# Hilarie Rose
# Orion 'Galaxy' Cosce
# Matt 'Magic' Dixon
# Josh Parisian
# Chad 'Big Rig' Johnson
# Kenneth 'The Boss' Cross
# Kevin 'El Nino Bala' Syler
# Adrian Yanez
# Brady 'The Kung Fu Warrior' Huang
# Cory 'Poppins' McKenna
# Vanessa 'Lil Monster' Demopoulos
# T.J. 'The Truth' Laramie
# Daniel 'Agent Orange' Swain
# Impa 'Tshilobo' Kasanganay
# Anthony 'Sugafoot' Adams
# Uros 'The Doctor' Medic
# Mikey 'Rolls' Gonzalez
# Jerome 'The Renegade' Rivera
# Ronaldo 'Lazy Boy' Rodriguez
# Jordan 'The Monkey King' Leavitt
# Jose 'Luke' Flores
# Impa 'Tshilobo' Kasanganay
# Kailan Hill
# Peter 'Slippery Pete' Barrett
# Sang Hoon 'The Korean Assassin' Yoo
# Ben 'Combat Wombat' Sosoli
# Dustin Joynson
# T.J. 'Downtown' Brown
# Dylan Lockard
# Jamal 'The Stormtrooper' Pogues
# Marcos 'Ironside' Brigagao
# Steve 'Mean Machine' Garcia
# Desmond 'The Tyrant' Torres
# Mallory Martin
# Micol DiSegni
# Ricky 'The Karate Kid' Steele
# Phil 'The Hitman' Caracappa
# Brok 'Chata Tuska' Weaver
# Devin 'The Prodigy' Smyth
# Sarah 'Too Sweet' Alpar
# Shanna 'The Shanimal' Young
# Tony Gravely
# Ray 'The Judge' Rodriguez
# Julius Anglickas
# Karl Reed
# Lucrezia Ria
# Marilia 'Chocolate' Santos
# Herbert 'The Blaze' Burns
# Darrick Minner
# Andre 'Sergipano' Muniz
# Taylor 'Tombstone' Johnson
# Dwight Joseph
# Jay 'The Joker' Perrin
# Aalon Cruz
# Steven 'The Ninja' Nguyen
# Tracy Cortez
# Mariya 'Money Mashka' Agapova
# Daniel 'D-Rod' Rodriguez
# Rico 'The Triggerman' Farrington
# Rodrigo 'Yogi Bear/Ze Colmeia' Nascimento
# Michal 'Blackbeard' Martinek
# Sean 'The Sniper' Woodson
# Terrance 'T.Wrecks' McKinney
# J.J. 'The Bosnian Bomber' Okanovich
# Christian 'Hollywood' Lohsen
# Jamahal 'Sweet Dreams' Hill
# Alexander 'Ironside' Poppeck
# Billy Quarantillo
# Kamuela 'The Jawaiian' Kirk
# Ode 'The Jamaican Sensation' Osbourne
# Armando 'La Lumbre' Villarreal
# Don'Tale 'Lord Kong' Mayes
# Ricardo 'Alemao' Prasel
# Kevin 'El Nino Bala' Syler
# Lance Lawrence
# Brendan 'All In' Allen
# Aaron Jeffery
# Antonio 'Malvado' Trocoli
# Kenneth Bergh
# Hunter Azure
# Chris Ocon
# Maki 'Coconut Bombz' Pitolo
# Justin 'The Fort' Sumter
# Jonathan 'JSP' Pearce
# Jacob 'Lil' Badger' Rosales
# Justin 'J-Train' Gonzales
# Zach 'God's Warrior' Zane
# Kyle 'The D'Arce Knight' Daukaus
# Michael 'The Don' Lombardo
# Miles 'Chapo' Johns
# Richie 'The Milford Mauler' Santiago
# Miguel 'Caramel Thunder' Baeza
# Victor 'Kelevra' Reyna
# Hannah '24K' Goldy
# Kali 'Pop Tart' Robbins
# Brendan Loughnane
# Bill 'Senor Perfecto' Algeo
# Yorgan 'The Mad Titan' De Castro
# Alton 'Murda' Meeks
# Luana 'Dread' Carolina
# Mabelly Lima
# Thiago Moises
# Gleidson 'Poney' Moraes Cutis
# Vinicius 'Mamute' Moreira
# John 'The Hunter' Allan
# Raulian Paiva
# Allan 'Puro Osso' Nascimento
# Marina Rodriguez
# Maria 'Spider-Girl' Oliveira
# Johnny Walker
# Henrique 'Frankenstein' da Silva
# Taila Santos
# Estefani Almeida
# Andre 'Sergipano' Muniz
# Bruno 'Brunao' Assis
# Antonio Arroyo
# Diego 'Gaucho' Henrique da Silva
# Augusto Sakai
# Marcos Conrado Jr.
# Rogerio Bontorin
# Gustavo Gabriel Silva
# Mayra 'Sheetara' Bueno Silva
# Mayana 'Kellen' Souza dos Santos
# Devonte 'King Kage' Smith
# Joseph Lowry
# Kennedy 'American Savage' Nzechukwu
# Dennis 'The Beard' Bryant
# Bobby 'The Wolfman' Moffett
# Jacob 'The Killer' Kilburn
# Alex Gilpin
# J.R. Coughran
# Don'Tale 'Lord Kong' Mayes
# Mitchell 'No Dice' Sipe
# Ian 'The Hurricane' Heinisch
# Justin 'The Fort' Sumter
# Jordan 'The Native Psycho' Griffin
# Maurice 'The AK Kid' Mitchell
# Juan 'The Kraken' Adams
# Shawn 'The Norwegian Nightmare' Teed
# Jimmy 'The Brute' Crute
# Chris 'The Big Buck' Birchler
# Sodiq 'Super' Yusuff
# Mike 'Beast Boy' Davis
# Jeff 'Lights Out' Hughes
# Josh 'The Juggernaut' Appelt
# Chase 'The Dream' Hooper
# Canaan Kawaihae
# Domingo 'Son of Fire' Pilarte
# Vince 'Vandetta' Morales
# Chibwikem Onyenegecha
# Anthony 'Sugafoot' Adams
# Austin 'The Gentleman' Vanderford
# Angelo 'Baby Monsta' Trevino
# Edmen 'The Golden Boy' Shahbazyan
# Antonio 'Doomsday' Jones
# Bevon 'The Extraordinary Gentleman' Lewis
# Alton 'The Bo-Man' Cunningham
# Ricky 'El Gallero' Palacios
# Toby '2 Quick' Misech
# Jordan Espinosa
# Riley 'The Perfect Storm' Dutro
# Jalin 'The Tarantula' Turner
# Max Mustaki
# Te 'T' Edwards
# Austin 'The Flash' Tweedy
# Josh Parisian
# Greg 'Ribz' Rebello
# Julian 'Juicy J' Erosa
# Jamall 'Prettyboy' Emmers
# Jordan 'Bomaye' Williams
# Tim 'The Bear' Caron
# Anthony 'Fluffy' Hernandez
# Jordan 'The Beverly Hills Ninja' Wright
# Austin Springer
# Giga 'Ninja' Chikadze
# Ryan 'Superman' Spann
# Emiliano 'He-Man' Sordi
# Dwight 'The Body Snatcher' Grant
# Tyler 'The Zombie' Hill
# Chris 'The Action Man' Curtis
# Sean 'The Unpredictable One' Lally
# Greg 'Prince of War' Hardy
# Austen Lane
# Montel 'Quik' Jackson
# Rico DiSciullo
# Kevin 'Trailblazer' Holland
# Will 'The Brown Bomber' Santiago Jr.
# Bevon 'The Extraordinary Gentleman' Lewis
# Elias Urbina
# Adam 'Captain Chaos' Antolin
# Casey Kenney
# Lauren 'Princess Tiger' Mueller
# Kelly 'Killer' McGill-Velasco
# Allen 'Pretty Boy' Crowder
# Don'Tale 'Lord Kong' Mayes
# Benito 'Golden Boy' Lopez
# Steven 'Ocho' Peterson
# Joby Sanchez
# J.P. 'Young Savage' Buys
# Mike Santiago
# Mark 'The Pride of Bloomfield' Cherico
# Jordan Espinosa
# Nick Urso
# Grant 'KGD' Dawson
# Adrian Diaz
# Cameron 'Captain Crunch' Olson
# Karl Reed
# Jaime Alvarez
# Martin 'The Spartan' Day
# Jamie 'Bad Mama' Colleen Miller
# Tiffany 'Rainbow Renegade' Masters
# Julio Arce
# Peter 'The Joker' Petties
# Alex Perez
# Kevin 'Pocket Herc' Gray
# Ricky Simon
# Donavon Frelow
# Shelton 'The Gravedigger' Graves
# Everett 'Wolverine' Sims
# Kyler 'Matrix' Phillips
# James 'The Phenom' Gray Jr.
# Carlos 'The Cannon' Candelario
# Ronaldo 'Pac-Man' Candido de Oliveira
# Brandon 'Killer B' Davis
# Austin 'The Golden Boy' Arnett
# John 'Sexi Mexi' Castaneda
# Cheyden 'Steadfast' Leialoha
# Kyle 'Gunz Up' Stewart
# Jason 'The Ass-Kicking Machine' Jackson
# Geoff 'Handz of Steel' Neal
# Chase Waldon
# Alonzo 'Atomic' Menifield
# Daniel 'The Werewolf of Texas' Jolly
# Dan '50K' Ige
# Luis 'El Tigre' Gomez
# Sean 'Suga' O'Malley
# Alfred 'The Fearless' Khashakyan
# Thanh Le
# Lazar Stojadinovic
# Sidney 'Da Gun' Outlaw
# Michael Cora
# Casey Kenney
# C.J. 'The Autobot' Hamilton
# Azunna 'Zu the 8th Wonder' Anyanwu
# Greg 'Ribz' Rebello
# Boston 'Boom Boom' Salmon
# Ricky 'Pretty' Turcios
# Charles 'Kid Dynamite' Byrd
# Jamie 'The Nightwolf' Pickett
# Joby Sanchez
# Manny Vazquez
# Navajo Sterling
# Phillip Latu
# Kody Steele
# Quemuel Ottoni
# Yousri 'Baby Face Assassin' Belgaroui
# Taiga Iwasaki
# Otari Tanzilov
# Josias 'The K.O. Wizard' Musasa
# Corinne Laframboise
# Nicolle Caliari

# %% [markdown]
# # Clean

# %%
# Delete empty columns

df = pd.read_csv('./data-dwcs/DWCS_Fighter_Info.csv')
columns_to_delete = ['Weight', 'Reach', 'Stance', 'Sherdog URL'] # 'Win_Dec', 'Loss_Dec'
df.drop(columns=columns_to_delete, inplace=True)
df.to_csv(file_path, index=False)
print(f"Deleted columns: {', '.join(columns_to_delete)}")
# Out:
# Deleted columns: Weight, Reach, Stance, Sherdog URL

# %%
# !open ./data-dwcs/DWCS_Fighter_Info.csv

# %%
# !open ./data-dwcs/DWCS_Event_Data_Sherdog.csv

# %% [markdown]
# # Fighters Fights

# %%
# !rm -rf ./data/fighters/

directory_path = './data-dwcs/fighters/'
if not os.path.exists(directory_path):
    os.makedirs(directory_path)

# %%
# # from concurrent.futures import ThreadPoolExecutor, as_completed

# # def scrape_fighter_fights_sherdog(fighter_name, fighter_id, fighter_url):
# #     headers = {
# #         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
# #     }
# #     response = requests.get(fighter_url, headers=headers, timeout=60)
    
# #     if response.status_code == 200:
# #         soup = BeautifulSoup(response.content, 'html.parser')
# #         table = soup.find('table', {'class': 'new_table fighter'})
# #         rows = table.find_all('tr')[1:]
# #         fight_data = []
# #         new_opponents = []

# #         for row in rows:
# #             cols = row.find_all('td')
# #             fight_dict = {
# #                 'Result': cols[0].text.strip(),
# #                 'Opponent': cols[1].find('a').text.strip() if cols[1].find('a') else '-',
# #                 'Event Date': cols[2].find_all('span')[-1].text.strip() if cols[2].find_all('span') else '-',
# #                 'Method/Referee': cols[3].text.strip().split('\n')[0],
# #                 'Rounds': cols[4].text.strip(),
# #                 'Time': cols[5].text.strip()
# #             }
# #             fight_data.append(fight_dict)
# #             opponent_link = cols[1].find('a')['href'] if cols[1].find('a') else None
# #             if opponent_link:
# #                 opponent_id = opponent_link.split('-')[-1]
# #                 new_opponents.append({'Fighter': fight_dict['Opponent'], 'Fighter_ID': opponent_id})
# #         return fighter_id, fighter_name, fight_data, new_opponents
# #     return fighter_id, fighter_name, [], []

# # df_fighter_id = pd.read_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv')
# # all_new_opponents = []

# # def process_fighter(row):
# #     fighter_url = f"https://www.sherdog.com/fighter/{row['Fighter'].replace(' ', '-')}-{row['Fighter_ID']}"
# #     return scrape_fighter_fights_sherdog(row['Fighter'], row['Fighter_ID'], fighter_url)

# # total_fighters = len(df_fighter_id)
# # fighters_processed = 0

# # with ThreadPoolExecutor(max_workers=10) as executor:
# #     futures = [executor.submit(process_fighter, row) for _, row in df_fighter_id.iterrows()]
# #     for future in as_completed(futures):
# #         fighter_id, fighter_name, fight_data, new_opponents = future.result()
# #         fighters_processed += 1
# #         print(f"Processed {fighters_processed}/{total_fighters} fighters.")
# #         if fight_data:
# #             pd.DataFrame(fight_data).to_csv(f"./data-dwcs/fighters/{fighter_name.replace(' ', '_')}_{fighter_id}.csv", index=False)
# #             all_new_opponents.extend(new_opponents)

# # if all_new_opponents:
# #     df_new_opponents = pd.DataFrame(all_new_opponents).drop_duplicates()
# #     df_fighter_id = pd.concat([df_fighter_id, df_new_opponents], ignore_index=True).drop_duplicates()
# #     df_fighter_id.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', index=False)
# from concurrent.futures import ThreadPoolExecutor, as_completed
# import os

# def scrape_fighter_fights_sherdog(fighter_name, fighter_id, fighter_url):
#     headers = {
#         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
#     }
#     response = requests.get(fighter_url, headers=headers, timeout=60)
    
#     if response.status_code == 200:
#         soup = BeautifulSoup(response.content, 'html.parser')
#         table = soup.find('table', {'class': 'new_table fighter'})
#         rows = table.find_all('tr')[1:]
#         fight_data = []
#         new_opponents = []

#         for row in rows:
#             cols = row.find_all('td')
#             fight_dict = {
#                 'Result': cols[0].text.strip(),
#                 'Opponent': cols[1].find('a').text.strip() if cols[1].find('a') else '-',
#                 'Event Date': cols[2].find_all('span')[-1].text.strip() if cols[2].find_all('span') else '-',
#                 'Method/Referee': cols[3].text.strip().split('\n')[0],
#                 'Rounds': cols[4].text.strip(),
#                 'Time': cols[5].text.strip()
#             }
#             fight_data.append(fight_dict)
#             opponent_link = cols[1].find('a')['href'] if cols[1].find('a') else None
#             if opponent_link:
#                 opponent_id = opponent_link.split('-')[-1]
#                 new_opponents.append({'Fighter': fight_dict['Opponent'], 'Fighter_ID': opponent_id})
#         return fighter_id, fighter_name, fight_data, new_opponents
#     return fighter_id, fighter_name, [], []

# df_fighter_id = pd.read_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv')
# all_new_opponents = []

# def process_fighter(row):
#     fighter_url = f"https://www.sherdog.com/fighter/{row['Fighter'].replace(' ', '-')}-{row['Fighter_ID']}"
#     return scrape_fighter_fights_sherdog(row['Fighter'], row['Fighter_ID'], fighter_url)

# total_fighters = len(df_fighter_id)
# fighters_processed = 0

# with ThreadPoolExecutor(max_workers=10) as executor:
#     futures = [executor.submit(process_fighter, row) for _, row in df_fighter_id.iterrows()]
#     for future in as_completed(futures):
#         fighter_id, fighter_name, fight_data, new_opponents = future.result()
#         fighters_processed += 1
#         print(f"Processed {fighters_processed}/{total_fighters} fighters.")
#         if fight_data:
#             # Cleaning the fighter_name inline to make it valid for filenames
#             clean_fighter_name = fighter_name.replace(' ', '_').replace("'", "").replace('"', '').replace("/", "_")
#             # Ensure the directory exists before saving the file
#             os.makedirs("./data-dwcs/fighters/", exist_ok=True)
#             pd.DataFrame(fight_data).to_csv(f"./data-dwcs/fighters/{clean_fighter_name}_{fighter_id}.csv", index=False)
#             all_new_opponents.extend(new_opponents)

# if all_new_opponents:
#     df_new_opponents = pd.DataFrame(all_new_opponents).drop_duplicates()
#     df_fighter_id = pd.concat([df_fighter_id, df_new_opponents], ignore_index=True).drop_duplicates()
#     df_fighter_id.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', index=False)

def scrape_fighter_fights_sherdog(fighter_name, fighter_id, fighter_url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    response = requests.get(fighter_url, headers=headers, timeout=60)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', {'class': 'new_table fighter'})
        rows = table.find_all('tr')[1:]
        fight_data = []
        new_opponents = []

        for row in rows:
            cols = row.find_all('td')
            
            # Extracting event name, event link, and event date
            event_element = cols[2].find('a')
            event_name = event_element.text.strip() if event_element else '-'
            event_link = event_element['href'] if event_element else '-'
            event_date_element = cols[2].find('span', {'class': 'sub_line'})
            event_date = event_date_element.text.strip() if event_date_element else '-'
            
            fight_dict = {
                'Result': cols[0].text.strip(),
                'Opponent': cols[1].find('a').text.strip() if cols[1].find('a') else '-',
                'Event Name': event_name,
                'Event Link': f"https://www.sherdog.com{event_link}" if event_link != '-' else '-',
                'Event Date': event_date,
                'Method/Referee': cols[3].text.strip().split('\n')[0],
                'Rounds': cols[4].text.strip(),
                'Time': cols[5].text.strip()
            }
            fight_data.append(fight_dict)
            opponent_link = cols[1].find('a')['href'] if cols[1].find('a') else None
            if opponent_link:
                opponent_id = opponent_link.split('-')[-1]
                new_opponents.append({'Fighter': fight_dict['Opponent'], 'Fighter_ID': opponent_id})
                
        return fighter_id, fighter_name, fight_data, new_opponents
    return fighter_id, fighter_name, [], []

df_fighter_id = pd.read_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv')
all_new_opponents = []

def process_fighter(row):
    fighter_url = f"https://www.sherdog.com/fighter/{row['Fighter'].replace(' ', '-')}-{row['Fighter_ID']}"
    return scrape_fighter_fights_sherdog(row['Fighter'], row['Fighter_ID'], fighter_url)

total_fighters = len(df_fighter_id)
fighters_processed = 0

with ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(process_fighter, row) for _, row in df_fighter_id.iterrows()]
    for future in as_completed(futures):
        fighter_id, fighter_name, fight_data, new_opponents = future.result()
        fighters_processed += 1
        print(f"Processed {fighters_processed}/{total_fighters} fighters.")
        if fight_data:
            # Cleaning the fighter_name inline to make it valid for filenames
            clean_fighter_name = fighter_name.replace(' ', '_').replace("'", "").replace('"', '').replace("/", "_")
            # Ensure the directory exists before saving the file
            os.makedirs("./data-dwcs/fighters/", exist_ok=True)
            pd.DataFrame(fight_data).to_csv(f"./data-dwcs/fighters/{clean_fighter_name}_{fighter_id}.csv", index=False)
            all_new_opponents.extend(new_opponents)

if all_new_opponents:
    df_new_opponents = pd.DataFrame(all_new_opponents).drop_duplicates()
    df_fighter_id = pd.concat([df_fighter_id, df_new_opponents], ignore_index=True).drop_duplicates()
    df_fighter_id.to_csv('./data-dwcs/DWCS_Fighter_ID_Sherdog.csv', index=False)
# Out:
# Processed 1/730 fighters.
# Processed 2/730 fighters.
# Processed 3/730 fighters.
# Processed 4/730 fighters.
# Processed 5/730 fighters.
# Processed 6/730 fighters.
# Processed 7/730 fighters.
# Processed 8/730 fighters.
# Processed 9/730 fighters.
# Processed 10/730 fighters.
# Processed 11/730 fighters.
# Processed 12/730 fighters.
# Processed 13/730 fighters.
# Processed 14/730 fighters.
# Processed 15/730 fighters.
# Processed 16/730 fighters.
# Processed 17/730 fighters.
# Processed 18/730 fighters.
# Processed 19/730 fighters.
# Processed 20/730 fighters.
# Processed 21/730 fighters.
# Processed 22/730 fighters.
# Processed 23/730 fighters.
# Processed 24/730 fighters.
# Processed 25/730 fighters.
# Processed 26/730 fighters.
# Processed 27/730 fighters.
# Processed 28/730 fighters.
# Processed 29/730 fighters.
# Processed 30/730 fighters.
# Processed 31/730 fighters.
# Processed 32/730 fighters.
# Processed 33/730 fighters.
# Processed 34/730 fighters.
# Processed 35/730 fighters.
# Processed 36/730 fighters.
# Processed 37/730 fighters.
# Processed 38/730 fighters.
# Processed 39/730 fighters.
# Processed 40/730 fighters.
# Processed 41/730 fighters.
# Processed 42/730 fighters.
# Processed 43/730 fighters.
# Processed 44/730 fighters.
# Processed 45/730 fighters.
# Processed 46/730 fighters.
# Processed 47/730 fighters.
# Processed 48/730 fighters.
# Processed 49/730 fighters.
# Processed 50/730 fighters.
# Processed 51/730 fighters.
# Processed 52/730 fighters.
# Processed 53/730 fighters.
# Processed 54/730 fighters.
# Processed 55/730 fighters.
# Processed 56/730 fighters.
# Processed 57/730 fighters.
# Processed 58/730 fighters.
# Processed 59/730 fighters.
# Processed 60/730 fighters.
# Processed 61/730 fighters.
# Processed 62/730 fighters.
# Processed 63/730 fighters.
# Processed 64/730 fighters.
# Processed 65/730 fighters.
# Processed 66/730 fighters.
# Processed 67/730 fighters.
# Processed 68/730 fighters.
# Processed 69/730 fighters.
# Processed 70/730 fighters.
# Processed 71/730 fighters.
# Processed 72/730 fighters.
# Processed 73/730 fighters.
# Processed 74/730 fighters.
# Processed 75/730 fighters.
# Processed 76/730 fighters.
# Processed 77/730 fighters.
# Processed 78/730 fighters.
# Processed 79/730 fighters.
# Processed 80/730 fighters.
# Processed 81/730 fighters.
# Processed 82/730 fighters.
# Processed 83/730 fighters.
# Processed 84/730 fighters.
# Processed 85/730 fighters.
# Processed 86/730 fighters.
# Processed 87/730 fighters.
# Processed 88/730 fighters.
# Processed 89/730 fighters.
# Processed 90/730 fighters.
# Processed 91/730 fighters.
# Processed 92/730 fighters.
# Processed 93/730 fighters.
# Processed 94/730 fighters.
# Processed 95/730 fighters.
# Processed 96/730 fighters.
# Processed 97/730 fighters.
# Processed 98/730 fighters.
# Processed 99/730 fighters.
# Processed 100/730 fighters.
# Processed 101/730 fighters.
# Processed 102/730 fighters.
# Processed 103/730 fighters.
# Processed 104/730 fighters.
# Processed 105/730 fighters.
# Processed 106/730 fighters.
# Processed 107/730 fighters.
# Processed 108/730 fighters.
# Processed 109/730 fighters.
# Processed 110/730 fighters.
# Processed 111/730 fighters.
# Processed 112/730 fighters.
# Processed 113/730 fighters.
# Processed 114/730 fighters.
# Processed 115/730 fighters.
# Processed 116/730 fighters.
# Processed 117/730 fighters.
# Processed 118/730 fighters.
# Processed 119/730 fighters.
# Processed 120/730 fighters.
# Processed 121/730 fighters.
# Processed 122/730 fighters.
# Processed 123/730 fighters.
# Processed 124/730 fighters.
# Processed 125/730 fighters.
# Processed 126/730 fighters.
# Processed 127/730 fighters.
# Processed 128/730 fighters.
# Processed 129/730 fighters.
# Processed 130/730 fighters.
# Processed 131/730 fighters.
# Processed 132/730 fighters.
# Processed 133/730 fighters.
# Processed 134/730 fighters.
# Processed 135/730 fighters.
# Processed 136/730 fighters.
# Processed 137/730 fighters.
# Processed 138/730 fighters.
# Processed 139/730 fighters.
# Processed 140/730 fighters.
# Processed 141/730 fighters.
# Processed 142/730 fighters.
# Processed 143/730 fighters.
# Processed 144/730 fighters.
# Processed 145/730 fighters.
# Processed 146/730 fighters.
# Processed 147/730 fighters.
# Processed 148/730 fighters.
# Processed 149/730 fighters.
# Processed 150/730 fighters.
# Processed 151/730 fighters.
# Processed 152/730 fighters.
# Processed 153/730 fighters.
# Processed 154/730 fighters.
# Processed 155/730 fighters.
# Processed 156/730 fighters.
# Processed 157/730 fighters.
# Processed 158/730 fighters.
# Processed 159/730 fighters.
# Processed 160/730 fighters.
# Processed 161/730 fighters.
# Processed 162/730 fighters.
# Processed 163/730 fighters.
# Processed 164/730 fighters.
# Processed 165/730 fighters.
# Processed 166/730 fighters.
# Processed 167/730 fighters.
# Processed 168/730 fighters.
# Processed 169/730 fighters.
# Processed 170/730 fighters.
# Processed 171/730 fighters.
# Processed 172/730 fighters.
# Processed 173/730 fighters.
# Processed 174/730 fighters.
# Processed 175/730 fighters.
# Processed 176/730 fighters.
# Processed 177/730 fighters.
# Processed 178/730 fighters.
# Processed 179/730 fighters.
# Processed 180/730 fighters.
# Processed 181/730 fighters.
# Processed 182/730 fighters.
# Processed 183/730 fighters.
# Processed 184/730 fighters.
# Processed 185/730 fighters.
# Processed 186/730 fighters.
# Processed 187/730 fighters.
# Processed 188/730 fighters.
# Processed 189/730 fighters.
# Processed 190/730 fighters.
# Processed 191/730 fighters.
# Processed 192/730 fighters.
# Processed 193/730 fighters.
# Processed 194/730 fighters.
# Processed 195/730 fighters.
# Processed 196/730 fighters.
# Processed 197/730 fighters.
# Processed 198/730 fighters.
# Processed 199/730 fighters.
# Processed 200/730 fighters.
# Processed 201/730 fighters.
# Processed 202/730 fighters.
# Processed 203/730 fighters.
# Processed 204/730 fighters.
# Processed 205/730 fighters.
# Processed 206/730 fighters.
# Processed 207/730 fighters.
# Processed 208/730 fighters.
# Processed 209/730 fighters.
# Processed 210/730 fighters.
# Processed 211/730 fighters.
# Processed 212/730 fighters.
# Processed 213/730 fighters.
# Processed 214/730 fighters.
# Processed 215/730 fighters.
# Processed 216/730 fighters.
# Processed 217/730 fighters.
# Processed 218/730 fighters.
# Processed 219/730 fighters.
# Processed 220/730 fighters.
# Processed 221/730 fighters.
# Processed 222/730 fighters.
# Processed 223/730 fighters.
# Processed 224/730 fighters.
# Processed 225/730 fighters.
# Processed 226/730 fighters.
# Processed 227/730 fighters.
# Processed 228/730 fighters.
# Processed 229/730 fighters.
# Processed 230/730 fighters.
# Processed 231/730 fighters.
# Processed 232/730 fighters.
# Processed 233/730 fighters.
# Processed 234/730 fighters.
# Processed 235/730 fighters.
# Processed 236/730 fighters.
# Processed 237/730 fighters.
# Processed 238/730 fighters.
# Processed 239/730 fighters.
# Processed 240/730 fighters.
# Processed 241/730 fighters.
# Processed 242/730 fighters.
# Processed 243/730 fighters.
# Processed 244/730 fighters.
# Processed 245/730 fighters.
# Processed 246/730 fighters.
# Processed 247/730 fighters.
# Processed 248/730 fighters.
# Processed 249/730 fighters.
# Processed 250/730 fighters.
# Processed 251/730 fighters.
# Processed 252/730 fighters.
# Processed 253/730 fighters.
# Processed 254/730 fighters.
# Processed 255/730 fighters.
# Processed 256/730 fighters.
# Processed 257/730 fighters.
# Processed 258/730 fighters.
# Processed 259/730 fighters.
# Processed 260/730 fighters.
# Processed 261/730 fighters.
# Processed 262/730 fighters.
# Processed 263/730 fighters.
# Processed 264/730 fighters.
# Processed 265/730 fighters.
# Processed 266/730 fighters.
# Processed 267/730 fighters.
# Processed 268/730 fighters.
# Processed 269/730 fighters.
# Processed 270/730 fighters.
# Processed 271/730 fighters.
# Processed 272/730 fighters.
# Processed 273/730 fighters.
# Processed 274/730 fighters.
# Processed 275/730 fighters.
# Processed 276/730 fighters.
# Processed 277/730 fighters.
# Processed 278/730 fighters.
# Processed 279/730 fighters.
# Processed 280/730 fighters.
# Processed 281/730 fighters.
# Processed 282/730 fighters.
# Processed 283/730 fighters.
# Processed 284/730 fighters.
# Processed 285/730 fighters.
# Processed 286/730 fighters.
# Processed 287/730 fighters.
# Processed 288/730 fighters.
# Processed 289/730 fighters.
# Processed 290/730 fighters.
# Processed 291/730 fighters.
# Processed 292/730 fighters.
# Processed 293/730 fighters.
# Processed 294/730 fighters.
# Processed 295/730 fighters.
# Processed 296/730 fighters.
# Processed 297/730 fighters.
# Processed 298/730 fighters.
# Processed 299/730 fighters.
# Processed 300/730 fighters.
# Processed 301/730 fighters.
# Processed 302/730 fighters.
# Processed 303/730 fighters.
# Processed 304/730 fighters.
# Processed 305/730 fighters.
# Processed 306/730 fighters.
# Processed 307/730 fighters.
# Processed 308/730 fighters.
# Processed 309/730 fighters.
# Processed 310/730 fighters.
# Processed 311/730 fighters.
# Processed 312/730 fighters.
# Processed 313/730 fighters.
# Processed 314/730 fighters.
# Processed 315/730 fighters.
# Processed 316/730 fighters.
# Processed 317/730 fighters.
# Processed 318/730 fighters.
# Processed 319/730 fighters.
# Processed 320/730 fighters.
# Processed 321/730 fighters.
# Processed 322/730 fighters.
# Processed 323/730 fighters.
# Processed 324/730 fighters.
# Processed 325/730 fighters.
# Processed 326/730 fighters.
# Processed 327/730 fighters.
# Processed 328/730 fighters.
# Processed 329/730 fighters.
# Processed 330/730 fighters.
# Processed 331/730 fighters.
# Processed 332/730 fighters.
# Processed 333/730 fighters.
# Processed 334/730 fighters.
# Processed 335/730 fighters.
# Processed 336/730 fighters.
# Processed 337/730 fighters.
# Processed 338/730 fighters.
# Processed 339/730 fighters.
# Processed 340/730 fighters.
# Processed 341/730 fighters.
# Processed 342/730 fighters.
# Processed 343/730 fighters.
# Processed 344/730 fighters.
# Processed 345/730 fighters.
# Processed 346/730 fighters.
# Processed 347/730 fighters.
# Processed 348/730 fighters.
# Processed 349/730 fighters.
# Processed 350/730 fighters.
# Processed 351/730 fighters.
# Processed 352/730 fighters.
# Processed 353/730 fighters.
# Processed 354/730 fighters.
# Processed 355/730 fighters.
# Processed 356/730 fighters.
# Processed 357/730 fighters.
# Processed 358/730 fighters.
# Processed 359/730 fighters.
# Processed 360/730 fighters.
# Processed 361/730 fighters.
# Processed 362/730 fighters.
# Processed 363/730 fighters.
# Processed 364/730 fighters.
# Processed 365/730 fighters.
# Processed 366/730 fighters.
# Processed 367/730 fighters.
# Processed 368/730 fighters.
# Processed 369/730 fighters.
# Processed 370/730 fighters.
# Processed 371/730 fighters.
# Processed 372/730 fighters.
# Processed 373/730 fighters.
# Processed 374/730 fighters.
# Processed 375/730 fighters.
# Processed 376/730 fighters.
# Processed 377/730 fighters.
# Processed 378/730 fighters.
# Processed 379/730 fighters.
# Processed 380/730 fighters.
# Processed 381/730 fighters.
# Processed 382/730 fighters.
# Processed 383/730 fighters.
# Processed 384/730 fighters.
# Processed 385/730 fighters.
# Processed 386/730 fighters.
# Processed 387/730 fighters.
# Processed 388/730 fighters.
# Processed 389/730 fighters.
# Processed 390/730 fighters.
# Processed 391/730 fighters.
# Processed 392/730 fighters.
# Processed 393/730 fighters.
# Processed 394/730 fighters.
# Processed 395/730 fighters.
# Processed 396/730 fighters.
# Processed 397/730 fighters.
# Processed 398/730 fighters.
# Processed 399/730 fighters.
# Processed 400/730 fighters.
# Processed 401/730 fighters.
# Processed 402/730 fighters.
# Processed 403/730 fighters.
# Processed 404/730 fighters.
# Processed 405/730 fighters.
# Processed 406/730 fighters.
# Processed 407/730 fighters.
# Processed 408/730 fighters.
# Processed 409/730 fighters.
# Processed 410/730 fighters.
# Processed 411/730 fighters.
# Processed 412/730 fighters.
# Processed 413/730 fighters.
# Processed 414/730 fighters.
# Processed 415/730 fighters.
# Processed 416/730 fighters.
# Processed 417/730 fighters.
# Processed 418/730 fighters.
# Processed 419/730 fighters.
# Processed 420/730 fighters.
# Processed 421/730 fighters.
# Processed 422/730 fighters.
# Processed 423/730 fighters.
# Processed 424/730 fighters.
# Processed 425/730 fighters.
# Processed 426/730 fighters.
# Processed 427/730 fighters.
# Processed 428/730 fighters.
# Processed 429/730 fighters.
# Processed 430/730 fighters.
# Processed 431/730 fighters.
# Processed 432/730 fighters.
# Processed 433/730 fighters.
# Processed 434/730 fighters.
# Processed 435/730 fighters.
# Processed 436/730 fighters.
# Processed 437/730 fighters.
# Processed 438/730 fighters.
# Processed 439/730 fighters.
# Processed 440/730 fighters.
# Processed 441/730 fighters.
# Processed 442/730 fighters.
# Processed 443/730 fighters.
# Processed 444/730 fighters.
# Processed 445/730 fighters.
# Processed 446/730 fighters.
# Processed 447/730 fighters.
# Processed 448/730 fighters.
# Processed 449/730 fighters.
# Processed 450/730 fighters.
# Processed 451/730 fighters.
# Processed 452/730 fighters.
# Processed 453/730 fighters.
# Processed 454/730 fighters.
# Processed 455/730 fighters.
# Processed 456/730 fighters.
# Processed 457/730 fighters.
# Processed 458/730 fighters.
# Processed 459/730 fighters.
# Processed 460/730 fighters.
# Processed 461/730 fighters.
# Processed 462/730 fighters.
# Processed 463/730 fighters.
# Processed 464/730 fighters.
# Processed 465/730 fighters.
# Processed 466/730 fighters.
# Processed 467/730 fighters.
# Processed 468/730 fighters.
# Processed 469/730 fighters.
# Processed 470/730 fighters.
# Processed 471/730 fighters.
# Processed 472/730 fighters.
# Processed 473/730 fighters.
# Processed 474/730 fighters.
# Processed 475/730 fighters.
# Processed 476/730 fighters.
# Processed 477/730 fighters.
# Processed 478/730 fighters.
# Processed 479/730 fighters.
# Processed 480/730 fighters.
# Processed 481/730 fighters.
# Processed 482/730 fighters.
# Processed 483/730 fighters.
# Processed 484/730 fighters.
# Processed 485/730 fighters.
# Processed 486/730 fighters.
# Processed 487/730 fighters.
# Processed 488/730 fighters.
# Processed 489/730 fighters.
# Processed 490/730 fighters.
# Processed 491/730 fighters.
# Processed 492/730 fighters.
# Processed 493/730 fighters.
# Processed 494/730 fighters.
# Processed 495/730 fighters.
# Processed 496/730 fighters.
# Processed 497/730 fighters.
# Processed 498/730 fighters.
# Processed 499/730 fighters.
# Processed 500/730 fighters.
# Processed 501/730 fighters.
# Processed 502/730 fighters.
# Processed 503/730 fighters.
# Processed 504/730 fighters.
# Processed 505/730 fighters.
# Processed 506/730 fighters.
# Processed 507/730 fighters.
# Processed 508/730 fighters.
# Processed 509/730 fighters.
# Processed 510/730 fighters.
# Processed 511/730 fighters.
# Processed 512/730 fighters.
# Processed 513/730 fighters.
# Processed 514/730 fighters.
# Processed 515/730 fighters.
# Processed 516/730 fighters.
# Processed 517/730 fighters.
# Processed 518/730 fighters.
# Processed 519/730 fighters.
# Processed 520/730 fighters.
# Processed 521/730 fighters.
# Processed 522/730 fighters.
# Processed 523/730 fighters.
# Processed 524/730 fighters.
# Processed 525/730 fighters.
# Processed 526/730 fighters.
# Processed 527/730 fighters.
# Processed 528/730 fighters.
# Processed 529/730 fighters.
# Processed 530/730 fighters.
# Processed 531/730 fighters.
# Processed 532/730 fighters.
# Processed 533/730 fighters.
# Processed 534/730 fighters.
# Processed 535/730 fighters.
# Processed 536/730 fighters.
# Processed 537/730 fighters.
# Processed 538/730 fighters.
# Processed 539/730 fighters.
# Processed 540/730 fighters.
# Processed 541/730 fighters.
# Processed 542/730 fighters.
# Processed 543/730 fighters.
# Processed 544/730 fighters.
# Processed 545/730 fighters.
# Processed 546/730 fighters.
# Processed 547/730 fighters.
# Processed 548/730 fighters.
# Processed 549/730 fighters.
# Processed 550/730 fighters.
# Processed 551/730 fighters.
# Processed 552/730 fighters.
# Processed 553/730 fighters.
# Processed 554/730 fighters.
# Processed 555/730 fighters.
# Processed 556/730 fighters.
# Processed 557/730 fighters.
# Processed 558/730 fighters.
# Processed 559/730 fighters.
# Processed 560/730 fighters.
# Processed 561/730 fighters.
# Processed 562/730 fighters.
# Processed 563/730 fighters.
# Processed 564/730 fighters.
# Processed 565/730 fighters.
# Processed 566/730 fighters.
# Processed 567/730 fighters.
# Processed 568/730 fighters.
# Processed 569/730 fighters.
# Processed 570/730 fighters.
# Processed 571/730 fighters.
# Processed 572/730 fighters.
# Processed 573/730 fighters.
# Processed 574/730 fighters.
# Processed 575/730 fighters.
# Processed 576/730 fighters.
# Processed 577/730 fighters.
# Processed 578/730 fighters.
# Processed 579/730 fighters.
# Processed 580/730 fighters.
# Processed 581/730 fighters.
# Processed 582/730 fighters.
# Processed 583/730 fighters.
# Processed 584/730 fighters.
# Processed 585/730 fighters.
# Processed 586/730 fighters.
# Processed 587/730 fighters.
# Processed 588/730 fighters.
# Processed 589/730 fighters.
# Processed 590/730 fighters.
# Processed 591/730 fighters.
# Processed 592/730 fighters.
# Processed 593/730 fighters.
# Processed 594/730 fighters.
# Processed 595/730 fighters.
# Processed 596/730 fighters.
# Processed 597/730 fighters.
# Processed 598/730 fighters.
# Processed 599/730 fighters.
# Processed 600/730 fighters.
# Processed 601/730 fighters.
# Processed 602/730 fighters.
# Processed 603/730 fighters.
# Processed 604/730 fighters.
# Processed 605/730 fighters.
# Processed 606/730 fighters.
# Processed 607/730 fighters.
# Processed 608/730 fighters.
# Processed 609/730 fighters.
# Processed 610/730 fighters.
# Processed 611/730 fighters.
# Processed 612/730 fighters.
# Processed 613/730 fighters.
# Processed 614/730 fighters.
# Processed 615/730 fighters.
# Processed 616/730 fighters.
# Processed 617/730 fighters.
# Processed 618/730 fighters.
# Processed 619/730 fighters.
# Processed 620/730 fighters.
# Processed 621/730 fighters.
# Processed 622/730 fighters.
# Processed 623/730 fighters.
# Processed 624/730 fighters.
# Processed 625/730 fighters.
# Processed 626/730 fighters.
# Processed 627/730 fighters.
# Processed 628/730 fighters.
# Processed 629/730 fighters.
# Processed 630/730 fighters.
# Processed 631/730 fighters.
# Processed 632/730 fighters.
# Processed 633/730 fighters.
# Processed 634/730 fighters.
# Processed 635/730 fighters.
# Processed 636/730 fighters.
# Processed 637/730 fighters.
# Processed 638/730 fighters.
# Processed 639/730 fighters.
# Processed 640/730 fighters.
# Processed 641/730 fighters.
# Processed 642/730 fighters.
# Processed 643/730 fighters.
# Processed 644/730 fighters.
# Processed 645/730 fighters.
# Processed 646/730 fighters.
# Processed 647/730 fighters.
# Processed 648/730 fighters.
# Processed 649/730 fighters.
# Processed 650/730 fighters.
# Processed 651/730 fighters.
# Processed 652/730 fighters.
# Processed 653/730 fighters.
# Processed 654/730 fighters.
# Processed 655/730 fighters.
# Processed 656/730 fighters.
# Processed 657/730 fighters.
# Processed 658/730 fighters.
# Processed 659/730 fighters.
# Processed 660/730 fighters.
# Processed 661/730 fighters.
# Processed 662/730 fighters.
# Processed 663/730 fighters.
# Processed 664/730 fighters.
# Processed 665/730 fighters.
# Processed 666/730 fighters.
# Processed 667/730 fighters.
# Processed 668/730 fighters.
# Processed 669/730 fighters.
# Processed 670/730 fighters.
# Processed 671/730 fighters.
# Processed 672/730 fighters.
# Processed 673/730 fighters.
# Processed 674/730 fighters.
# Processed 675/730 fighters.
# Processed 676/730 fighters.
# Processed 677/730 fighters.
# Processed 678/730 fighters.
# Processed 679/730 fighters.
# Processed 680/730 fighters.
# Processed 681/730 fighters.
# Processed 682/730 fighters.
# Processed 683/730 fighters.
# Processed 684/730 fighters.
# Processed 685/730 fighters.
# Processed 686/730 fighters.
# Processed 687/730 fighters.
# Processed 688/730 fighters.
# Processed 689/730 fighters.
# Processed 690/730 fighters.
# Processed 691/730 fighters.
# Processed 692/730 fighters.
# Processed 693/730 fighters.
# Processed 694/730 fighters.
# Processed 695/730 fighters.
# Processed 696/730 fighters.
# Processed 697/730 fighters.
# Processed 698/730 fighters.
# Processed 699/730 fighters.
# Processed 700/730 fighters.
# Processed 701/730 fighters.
# Processed 702/730 fighters.
# Processed 703/730 fighters.
# Processed 704/730 fighters.
# Processed 705/730 fighters.
# Processed 706/730 fighters.
# Processed 707/730 fighters.
# Processed 708/730 fighters.
# Processed 709/730 fighters.
# Processed 710/730 fighters.
# Processed 711/730 fighters.
# Processed 712/730 fighters.
# Processed 713/730 fighters.
# Processed 714/730 fighters.
# Processed 715/730 fighters.
# Processed 716/730 fighters.
# Processed 717/730 fighters.
# Processed 718/730 fighters.
# Processed 719/730 fighters.
# Processed 720/730 fighters.
# Processed 721/730 fighters.
# Processed 722/730 fighters.
# Processed 723/730 fighters.
# Processed 724/730 fighters.
# Processed 725/730 fighters.
# Processed 726/730 fighters.
# Processed 727/730 fighters.
# Processed 728/730 fighters.
# Processed 729/730 fighters.
# Processed 730/730 fighters.

# %%
directory_path = './data-dwcs/fighters/'
output_file = './data-dwcs/DWCS-Fighters-All-Fights.csv'
first_file = True

for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):  # Check if the file is a CSV
        file_path = os.path.join(directory_path, filename)
        df = pd.read_csv(file_path)
        df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)  # Use applymap for element-wise operation

        # Append to the output file, and only write the header for the first file
        df.to_csv(output_file, mode='a', header=first_file, index=False)
        first_file = False  # Ensure header is written only once

# %% [markdown]
# # Odds Scraping

# %%
# https://www.bestfightodds.com/archive
# https://www.bestfightodds.com/events/dana-white-s-contender-series-1-1330
# https://www.bestfightodds.com/events/dana-white-s-contender-series-3-1338

# https://fightodds.io/mma-events/4054/contender-series-2022-week-2/odds

# %%
# ### Loop through urls

# import requests

# # Base URL
# base_url = 'https://www.bestfightodds.com/events/dana-white-s-contender-series-'

# # Iterate over each URL
# for i in range(1, 100):
#     url = base_url + str(i)
    
#     # Send HTTP GET request
#     response = requests.get(url)
    
#     # Check if the request was successful
#     if response.status_code == 200:
#         # The request was successful, you can now parse the response.text
#         # with a library like BeautifulSoup if you need to extract information from the page
#         # ...
        
#         # Print or save the extracted information
#         # ...
#     else:
#         print(f'Failed to retrieve page {i}. Status code: {response.status_code}')

# print('Completed.')
