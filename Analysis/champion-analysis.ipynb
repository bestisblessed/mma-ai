# %%
import pandas as pd

# %%
# Load the dataset
master_df = pd.read_csv('data/github/master.csv')

# Function to get champions and their reigns for a specific weight class using the WEIGHTCLASS column
def get_champions_and_reigns(weight_class):
    # Filter the DataFrame for the specified weight class title bouts
    title_fights = master_df[
        master_df['WEIGHTCLASS'].str.contains(weight_class, case=False, na=False)
    ].sort_values(by='DATE')
    
    # Extract relevant information
    champions_opponents_dates = title_fights[['DATE', 'EVENT', 'BOUT', 'WINNING_FIGHTER', 'FIGHTER1', 'FIGHTER2']].copy()
    champions_opponents_dates = champions_opponents_dates.sort_values(by='DATE')
    
    # Initialize the list to store champions and reigns
    champions_list = []
    current_champion = None
    current_start_date = None
    
    for index, row in champions_opponents_dates.iterrows():
        opponent = row['FIGHTER2'] if row['WINNING_FIGHTER'] == row['FIGHTER1'] else row['FIGHTER1']
        if current_champion is None:
            current_champion = row['WINNING_FIGHTER']
            current_start_date = row['DATE']
        elif current_champion != row['WINNING_FIGHTER']:
            champions_list.append(f"{current_champion} - {current_start_date} to {row['DATE']} (Defeated {opponent})")
            current_champion = row['WINNING_FIGHTER']
            current_start_date = row['DATE']
    
    if current_champion is not None:
        champions_list.append(f"{current_champion} - {current_start_date} to Present")
    
    return champions_list

# Define all weight classes as per the dataset
weight_classes = [
    'UFC Featherweight Title Bout', 'UFC Interim Featherweight Title Bout', 'UFC Lightweight Title Bout', 'UFC Interim Lightweight Title Bout',
    'UFC Welterweight Title Bout', 'UFC Interim Welterweight Title Bout', 'UFC Middleweight Title Bout', 'UFC Interim Middleweight Title Bout',
    'UFC Light Heavyweight Title Bout', 'UFC Interim Light Heavyweight Title Bout', 'UFC Heavyweight Title Bout', 'UFC Interim Heavyweight Title Bout',
    'UFC Flyweight Title Bout', 'UFC Interim Flyweight Title Bout', 'UFC Bantamweight Title Bout', 'UFC Interim Bantamweight Title Bout'
]

# Get champions and their reigns for all weight classes
all_champions = {}
for wc in weight_classes:
    champions = get_champions_and_reigns(wc)
    all_champions[wc] = champions

# Print the champions and their reigns for all weight classes
champions_output = ""
for wc, champions in all_champions.items():
    champions_output += f"\n{wc} Champions and Reigns:\n"
    if champions:
        for champ in champions:
            champions_output += champ + "\n"
    else:
        champions_output += "No data available for this weight class.\n"

print(champions_output)
# Out:
# UFC Featherweight Title Bout Champions and Reigns:
# Jose Aldo - 2011-04-30 to 2015-12-12 (Defeated jose aldo)
# Conor McGregor - 2015-12-12 to 2017-06-03 (Defeated jose aldo)
# Max Holloway - 2017-06-03 to 2019-12-14 (Defeated max holloway)
# Alexander Volkanovski - 2019-12-14 to 2024-02-17 (Defeated alexander volkanovski)
# Ilia Topuria - 2024-02-17 to Present
#
# UFC Interim Featherweight Title Bout Champions and Reigns:
# Conor McGregor - 2015-07-11 to 2016-07-09 (Defeated jose aldo)
# Jose Aldo - 2016-07-09 to 2016-12-10 (Defeated max holloway)
# Max Holloway - 2016-12-10 to 2023-02-11 (Defeated yair rodriguez)
# Yair Rodriguez - 2023-02-11 to Present
#
# UFC Lightweight Title Bout Champions and Reigns:
# Sean Sherk - 2006-10-14 to 2008-01-19 (Defeated bj penn)
# BJ Penn - 2008-01-19 to 2010-04-10 (Defeated bj penn)
# Frankie Edgar - 2010-04-10 to 2011-01-01 (Defeated frankie edgar)
# Draw - 2011-01-01 to 2011-10-08 (Defeated frankie edgar)
# Frankie Edgar - 2011-10-08 to 2012-02-25 (Defeated frankie edgar)
# Benson Henderson - 2012-02-25 to 2013-08-31 (Defeated benson henderson)
# Anthony Pettis - 2013-08-31 to 2015-03-14 (Defeated anthony pettis)
# Rafael Dos Anjos - 2015-03-14 to 2016-07-07 (Defeated rafael dos anjos)
# Eddie Alvarez - 2016-07-07 to 2016-11-12 (Defeated eddie alvarez)
# Conor McGregor - 2016-11-12 to 2018-04-07 (Defeated khabib nurmagomedov)
# Khabib Nurmagomedov - 2018-04-07 to 2021-05-15 (Defeated charles oliveira)
# Charles Oliveira - 2021-05-15 to 2022-10-22 (Defeated charles oliveira)
# Islam Makhachev - 2022-10-22 to Present
#
# UFC Interim Lightweight Title Bout Champions and Reigns:
# Tony Ferguson - 2017-10-07 to 2019-04-13 (Defeated max holloway)
# Dustin Poirier - 2019-04-13 to 2020-05-09 (Defeated tony ferguson)
# Justin Gaethje - 2020-05-09 to Present
#
# UFC Welterweight Title Bout Champions and Reigns:
# Matt Hughes - 2005-04-16 to 2006-11-18 (Defeated georges stpierre)
# Georges St-Pierre - 2006-11-18 to 2007-04-07 (Defeated matt serra)
# Matt Serra - 2007-04-07 to 2008-04-19 (Defeated georges stpierre)
# Georges St-Pierre - 2008-04-19 to 2014-03-15 (Defeated johny hendricks)
# Johny Hendricks - 2014-03-15 to 2014-12-06 (Defeated johny hendricks)
# Robbie Lawler - 2014-12-06 to 2016-07-30 (Defeated robbie lawler)
# Tyron Woodley - 2016-07-30 to 2016-11-12 (Defeated tyron woodley)
# Draw - 2016-11-12 to 2017-03-04 (Defeated tyron woodley)
# Tyron Woodley - 2017-03-04 to 2019-03-02 (Defeated tyron woodley)
# Kamaru Usman - 2019-03-02 to 2022-08-20 (Defeated kamaru usman)
# Leon Edwards - 2022-08-20 to Present
#
# UFC Interim Welterweight Title Bout Champions and Reigns:
# Georges St-Pierre - 2007-12-29 to 2012-02-04 (Defeated nick diaz)
# Carlos Condit - 2012-02-04 to 2018-06-09 (Defeated rafael dos anjos)
# Colby Covington - 2018-06-09 to Present
#
# UFC Middleweight Title Bout Champions and Reigns:
# Evan Tanner - 2005-02-05 to 2005-06-04 (Defeated rich franklin)
# Rich Franklin - 2005-06-04 to 2006-10-14 (Defeated anderson silva)
# Anderson Silva - 2006-10-14 to 2013-07-06 (Defeated anderson silva)
# Chris Weidman - 2013-07-06 to 2015-12-12 (Defeated chris weidman)
# Luke Rockhold - 2015-12-12 to 2016-06-04 (Defeated luke rockhold)
# Michael Bisping - 2016-06-04 to 2017-11-04 (Defeated michael bisping)
# Georges St-Pierre - 2017-11-04 to 2019-10-05 (Defeated robert whittaker)
# Israel Adesanya - 2019-10-05 to 2022-11-12 (Defeated israel adesanya)
# Alex Pereira - 2022-11-12 to 2023-04-08 (Defeated alex pereira)
# Israel Adesanya - 2023-04-08 to 2023-09-09 (Defeated israel adesanya)
# Sean Strickland - 2023-09-09 to 2024-01-20 (Defeated sean strickland)
# Dricus Du Plessis - 2024-01-20 to Present
#
# UFC Interim Middleweight Title Bout Champions and Reigns:
# Robert Whittaker - 2017-07-08 to 2018-02-10 (Defeated yoel romero)
# Yoel Romero - 2018-02-10 to 2019-04-13 (Defeated kelvin gastelum)
# Israel Adesanya - 2019-04-13 to Present
#
# UFC Light Heavyweight Title Bout Champions and Reigns:
# Chuck Liddell - 2005-04-16 to 2007-05-26 (Defeated quinton jackson)
# Quinton Jackson - 2007-05-26 to 2008-07-05 (Defeated forrest griffin)
# Forrest Griffin - 2008-07-05 to 2008-12-27 (Defeated rashad evans)
# Rashad Evans - 2008-12-27 to 2009-05-23 (Defeated lyoto machida)
# Lyoto Machida - 2009-05-23 to 2010-05-08 (Defeated lyoto machida)
# Mauricio Rua - 2010-05-08 to 2011-03-19 (Defeated mauricio rua)
# Jon Jones - 2011-03-19 to 2015-05-23 (Defeated anthony johnson)
# Daniel Cormier - 2015-05-23 to 2017-07-29 (Defeated daniel cormier)
# No Contest - 2017-07-29 to 2018-01-20 (Defeated daniel cormier)
# Daniel Cormier - 2018-01-20 to 2018-12-29 (Defeated jon jones)
# Jon Jones - 2018-12-29 to 2020-09-26 (Defeated dominick reyes)
# Jan Blachowicz - 2020-09-26 to 2021-10-30 (Defeated jan blachowicz)
# Glover Teixeira - 2021-10-30 to 2022-06-11 (Defeated glover teixeira)
# Jiri Prochazka - 2022-06-11 to 2022-12-10 (Defeated jan blachowicz)
# Draw - 2022-12-10 to 2023-01-21 (Defeated glover teixeira)
# Jamahal Hill - 2023-01-21 to 2023-11-11 (Defeated jiri prochazka)
# Alex Pereira - 2023-11-11 to Present
#
# UFC Interim Light Heavyweight Title Bout Champions and Reigns:
# Jon Jones - 2016-04-23 to Present
#
# UFC Heavyweight Title Bout Champions and Reigns:
# Andrei Arlovski - 2005-10-07 to 2006-04-15 (Defeated tim sylvia)
# Tim Sylvia - 2006-04-15 to 2007-03-03 (Defeated randy couture)
# Randy Couture - 2007-03-03 to 2008-11-15 (Defeated brock lesnar)
# Brock Lesnar - 2008-11-15 to 2010-10-23 (Defeated brock lesnar)
# Cain Velasquez - 2010-10-23 to 2011-11-12 (Defeated cain velasquez)
# Junior Dos Santos - 2011-11-12 to 2012-12-29 (Defeated junior dos santos)
# Cain Velasquez - 2012-12-29 to 2015-06-13 (Defeated cain velasquez)
# Fabricio Werdum - 2015-06-13 to 2016-05-14 (Defeated fabricio werdum)
# Stipe Miocic - 2016-05-14 to 2018-07-07 (Defeated stipe miocic)
# Daniel Cormier - 2018-07-07 to 2019-08-17 (Defeated daniel cormier)
# Stipe Miocic - 2019-08-17 to 2021-03-27 (Defeated stipe miocic)
# Francis Ngannou - 2021-03-27 to 2023-03-04 (Defeated jon jones)
# Jon Jones - 2023-03-04 to Present
#
# UFC Interim Heavyweight Title Bout Champions and Reigns:
# Andrei Arlovski - 2005-02-05 to 2008-02-02 (Defeated antonio rodrigo nogueira)
# Antonio Rodrigo Nogueira - 2008-02-02 to 2008-12-27 (Defeated frank mir)
# Frank Mir - 2008-12-27 to 2010-03-27 (Defeated frank mir)
# Shane Carwin - 2010-03-27 to 2014-11-15 (Defeated fabricio werdum)
# Fabricio Werdum - 2014-11-15 to 2021-08-07 (Defeated derrick lewis)
# Ciryl Gane - 2021-08-07 to 2023-11-11 (Defeated sergei pavlovich)
# Tom Aspinall - 2023-11-11 to Present
#
# UFC Flyweight Title Bout Champions and Reigns:
# Demetrious Johnson - 2012-09-22 to 2018-08-04 (Defeated demetrious johnson)
# Henry Cejudo - 2018-08-04 to 2020-07-18 (Defeated deiveson figueiredo)
# Deiveson Figueiredo - 2020-07-18 to 2020-12-12 (Defeated deiveson figueiredo)
# Draw - 2020-12-12 to 2021-06-12 (Defeated deiveson figueiredo)
# Brandon Moreno - 2021-06-12 to 2022-01-22 (Defeated brandon moreno)
# Deiveson Figueiredo - 2022-01-22 to 2023-01-21 (Defeated deiveson figueiredo)
# Brandon Moreno - 2023-01-21 to 2023-07-08 (Defeated brandon moreno)
# Alexandre Pantoja - 2023-07-08 to Present
#
# UFC Interim Flyweight Title Bout Champions and Reigns:
# Brandon Moreno - 2022-07-30 to Present
#
# UFC Bantamweight Title Bout Champions and Reigns:
# Dominick Cruz - 2011-07-02 to 2014-02-01 (Defeated renan barao)
# Renan Barao - 2014-02-01 to 2014-05-24 (Defeated renan barao)
# TJ Dillashaw - 2014-05-24 to 2016-01-17 (Defeated tj dillashaw)
# Dominick Cruz - 2016-01-17 to 2016-12-30 (Defeated dominick cruz)
# Cody Garbrandt - 2016-12-30 to 2017-11-04 (Defeated cody garbrandt)
# TJ Dillashaw - 2017-11-04 to 2019-06-08 (Defeated henry cejudo)
# Henry Cejudo - 2019-06-08 to 2020-07-11 (Defeated petr yan)
# Petr Yan - 2020-07-11 to 2021-03-06 (Defeated petr yan)
# Aljamain Sterling - 2021-03-06 to 2023-08-19 (Defeated aljamain sterling)
# Sean O'Malley - 2023-08-19 to Present
#
# UFC Interim Bantamweight Title Bout Champions and Reigns:
# Renan Barao - 2012-07-21 to 2021-10-30 (Defeated petr yan)
# Petr Yan - 2021-10-30 to Present
